# %%
import pandas as pd
#pd.set_option('display.max_rows', None)

# %%
# https://nkinfo.unikorea.go.kr/nkp/theme/peopleList.do

nklist = pd.read_excel("../new data/NK elite new checklist.xlsx")
nklist
# Out:
#     Leader ID Name 성명(한글)                소속/직책  성별           생년월일       출생지  \
# 0         강관주  강관주    NaN                  NaN  남성  1930년 07월 05일  평안남도 대동군
# 1         강능수  강능수    NaN      (사망) 당 중앙위원회 위원  남성  1930년 02월 21일       평양시
# 2         강동윤  강동윤    NaN          당 중앙위원회 부부장  남성           연도미상       NaN
# 3         강련학  강련학    강연학     (사망) 민족화해협의회 부회장  남성           연도미상       NaN
# 4         강명철  강명철    NaN  조선그리스도교연맹 중앙위원회 위원장  남성           연도미상       NaN
# ..        ...  ...    ...                  ...  ..            ...       ...
# 600       황병서  황병서    NaN               인민군 차수  남성          1949년       NaN
# 601       황봉영  황봉영    NaN        조선올림픽위원회 부위원장  남성  1944년 08월 15일       NaN
# 602       황순희  황순희    NaN      (사망) 조선혁명박물관 관장  여성  1919년 05월 03일  북한지역외 중국
# 603       황철식  황철식    NaN                  NaN  미상           연도미상       NaN
# 604       황학원  황학원    NaN                  NaN  남성  1941년 01월 01일       NaN
#
#      사망여부           사망일자
# 0     NaN           연도미상
# ...

# %%
nklist.columns
# Out:
# Index(['Leader ID', 'Name', '성명(한글)', '소속/직책', '성별', '생년월일', '출생지', '사망여부',
#        '사망일자'],
#       dtype='object')

# %%
nklist=nklist.rename(columns={"Leader ID":"ID"})

# %%
nklist
# Out:
#       ID Name 성명(한글)                소속/직책  성별           생년월일       출생지  사망여부  \
# 0    강관주  강관주    NaN                  NaN  남성  1930년 07월 05일  평안남도 대동군   NaN
# 1    강능수  강능수    NaN      (사망) 당 중앙위원회 위원  남성  1930년 02월 21일       평양시  (사망)
# 2    강동윤  강동윤    NaN          당 중앙위원회 부부장  남성           연도미상       NaN   NaN
# 3    강련학  강련학    강연학     (사망) 민족화해협의회 부회장  남성           연도미상       NaN  (사망)
# 4    강명철  강명철    NaN  조선그리스도교연맹 중앙위원회 위원장  남성           연도미상       NaN   NaN
# ..   ...  ...    ...                  ...  ..            ...       ...   ...
# 600  황병서  황병서    NaN               인민군 차수  남성          1949년       NaN   NaN
# 601  황봉영  황봉영    NaN        조선올림픽위원회 부위원장  남성  1944년 08월 15일       NaN   NaN
# 602  황순희  황순희    NaN      (사망) 조선혁명박물관 관장  여성  1919년 05월 03일  북한지역외 중국  (사망)
# 603  황철식  황철식    NaN                  NaN  미상           연도미상       NaN   NaN
# 604  황학원  황학원    NaN                  NaN  남성  1941년 01월 01일       NaN   NaN
#
#               사망일자
# 0             연도미상
# ...

# %%
nklist[nklist["ID"].str.contains("a")]
# Out:
#        ID Name 성명(한글)                     소속/직책  성별           생년월일  \
# 47   김경호a  김경호    NaN      조선태권도위원회 국제태권도연맹 부총재  남성  1958년 12월 11일
# 53   김광철a  김광철    NaN                       NaN  남성           연도미상
# 57   김금철a  김금철    NaN                       NaN  남성           연도미상
# 72   김명길a  김명길    NaN                    외무성 대사  남성  1959년 03월 14일
# 110  김영일a  김영일    NaN            조선.일본우호친선협회 고문  남성  1947년 03월 17일
# 114  김영철a  김영철    NaN                당 통일전선부 부장  남성          1946년
# 119  김영훈a  김영훈    NaN                       NaN  미상           연도미상
# 136  김윤혁a  김윤혁    NaN                      (사망)  남성          1926년
# 144  김일철a  김일철    NaN                       NaN  남성          1930년
# 193  김형식a  김형식    NaN                       NaN  남성           연도미상
# 245  리성국a  리성국    NaN                      (사망)  남성           연도미상
# 260  리용철a  리용철    이용철                      (사망)  남성  1929년 03월 24일
# 329  박명철a  박명철    NaN             조국통일민주주의전선 의장  남성  1941년 09월 15일
# ...

# %%
nklist[nklist["ID"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Name, 성명(한글), 소속/직책, 성별, 생년월일, 출생지, 사망여부, 사망일자]
# Index: []

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1_compare elites in folder an list.ipynb',
#  '2_compare old and new elite names.ipynb',
#  '3_extract uncoded career strings from old data.ipynb',
#  'Checklist.docx']

# %%
fn=os.listdir('../new data/NK elite spreadsheets/')

# %%
fn
# Out:
# ['강관주 상세정보.xls',
#  '강능수 상세정보.xls',
#  '강동윤 상세정보.xls',
#  '강련학 상세정보.xls',
#  '강명철 상세정보.xls',
#  '강민철 상세정보.xls',
#  '강봉훈 상세정보.xls',
#  '강석숭 상세정보.xls',
#  '강석주 상세정보.xls',
#  '강성산 상세정보.xls',
#  '강수린 상세정보.xls',
#  '강순남 상세정보.xls',
#  '강양모 상세정보.xls',
#  '강영섭 상세정보.xls',
#  '강영수 상세정보.xls',
#  '강영철 상세정보.xls',
#  '강영호 상세정보.xls',
#  '강윤석 상세정보.xls',
#  '강종관 상세정보.xls',
#  '강지영 상세정보.xls',
#  '강창욱 상세정보.xls',
#  '강표영 상세정보.xls',
#  '강하국 상세정보.xls',
#  '강형봉 상세정보.xls',
#  '계명철 상세정보.xls',
#  '계영삼 상세정보.xls',
#  '계응태 상세정보.xls',
#  '고길선 상세정보.xls',
#  '고인호 상세정보.xls',
#  '고정범 상세정보.xls',
#  '고종덕 상세정보.xls',
#  '고철만 상세정보.xls',
#  '곽범기 상세정보.xls',
#  '곽창식 상세정보.xls',
#  '구본태 상세정보.xls',
#  '궁석웅 상세정보.xls',
#  '권성호 상세정보.xls',
#  '권영진 상세정보.xls',
#  '권춘학 상세정보.xls',
#  '권혁봉 상세정보.xls',
#  '권호웅 상세정보.xls',
#  '권희경 상세정보.xls',
#  '기광호 상세정보.xls',
#  '김격식 상세정보.xls',
#  '김경남 상세정보.xls',
#  '김경옥 상세정보.xls',
#  '김경준 상세정보.xls',
#  '김경호a 상세정보.xls',
#  '김경호b 상세정보 .xlsx',
#  '김경희 상세정보.xls',
#  '김계관 상세정보.xls',
#  '김광린 상세정보.xls',
# ...

# %%
nkfolder=pd.DataFrame(fn,columns=['fname'])

# %%
nkfolder
# Out:
#             fname
# 0    강관주 상세정보.xls
# 1    강능수 상세정보.xls
# 2    강동윤 상세정보.xls
# 3    강련학 상세정보.xls
# 4    강명철 상세정보.xls
# ..            ...
# 596  황병서 상세정보.xls
# 597  황봉영 상세정보.xls
# 598  황순희 상세정보.xls
# 599  황철식 상세정보.xls
# 600  황학원 상세정보.xls
#
# [601 rows x 1 columns]

# %%
nkfolder["ID"]=""
nkfolder
# Out:
#             fname ID
# 0    강관주 상세정보.xls
# 1    강능수 상세정보.xls
# 2    강동윤 상세정보.xls
# 3    강련학 상세정보.xls
# 4    강명철 상세정보.xls
# ..            ... ..
# 596  황병서 상세정보.xls
# 597  황봉영 상세정보.xls
# 598  황순희 상세정보.xls
# 599  황철식 상세정보.xls
# 600  황학원 상세정보.xls
#
# [601 rows x 2 columns]

# %%
nkfolder.fname.str.split(" ").str[0]
# Out:
# 0      강관주
# 1      강능수
# 2      강동윤
# 3      강련학
# 4      강명철
#       ...
# 596    황병서
# 597    황봉영
# 598    황순희
# 599    황철식
# 600    황학원
# Name: fname, Length: 601, dtype: object

# %%
nkfolder.ID = nkfolder.fname.str.split(" ").str[0]

# %%
nkfolder
# Out:
#             fname   ID
# 0    강관주 상세정보.xls  강관주
# 1    강능수 상세정보.xls  강능수
# 2    강동윤 상세정보.xls  강동윤
# 3    강련학 상세정보.xls  강련학
# 4    강명철 상세정보.xls  강명철
# ..            ...  ...
# 596  황병서 상세정보.xls  황병서
# 597  황봉영 상세정보.xls  황봉영
# 598  황순희 상세정보.xls  황순희
# 599  황철식 상세정보.xls  황철식
# 600  황학원 상세정보.xls  황학원
#
# [601 rows x 2 columns]

# %%
nkmerge=nklist.merge(nkfolder,on="ID",how="outer")

# %%
nkmerge
# Out:
#       ID Name 성명(한글)                소속/직책  성별           생년월일       출생지  사망여부  \
# 0    강관주  강관주    NaN                  NaN  남성  1930년 07월 05일  평안남도 대동군   NaN
# 1    강능수  강능수    NaN      (사망) 당 중앙위원회 위원  남성  1930년 02월 21일       평양시  (사망)
# 2    강동윤  강동윤    NaN          당 중앙위원회 부부장  남성           연도미상       NaN   NaN
# 3    강련학  강련학    강연학     (사망) 민족화해협의회 부회장  남성           연도미상       NaN  (사망)
# 4    강명철  강명철    NaN  조선그리스도교연맹 중앙위원회 위원장  남성           연도미상       NaN   NaN
# ..   ...  ...    ...                  ...  ..            ...       ...   ...
# 600  황병서  황병서    NaN               인민군 차수  남성          1949년       NaN   NaN
# 601  황봉영  황봉영    NaN        조선올림픽위원회 부위원장  남성  1944년 08월 15일       NaN   NaN
# 602  황순희  황순희    NaN      (사망) 조선혁명박물관 관장  여성  1919년 05월 03일  북한지역외 중국  (사망)
# 603  황철식  황철식    NaN                  NaN  미상           연도미상       NaN   NaN
# 604  황학원  황학원    NaN                  NaN  남성  1941년 01월 01일       NaN   NaN
#
#               사망일자         fname
# ...

# %%
# check for items in folder, not in checklist
nkmerge[nkmerge["Name"].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Name, 성명(한글), 소속/직책, 성별, 생년월일, 출생지, 사망여부, 사망일자, fname]
# Index: []

# %%
# check for items in checklist, not in folder
nkmerge[nkmerge["fname"].isnull()]
# Out:
#       ID Name 성명(한글)            소속/직책  성별   생년월일  출생지 사망여부  사망일자 fname
# 241  리상관  리상관    이상관              NaN  남성   연도미상  NaN  NaN  연도미상   NaN
# 242  리상원  리상원    이상원  최고인민회의 제14기 대의원  남성  1951년  NaN  NaN  연도미상   NaN
# 243  리선권  리선권    NaN            외무성 상  남성   연도미상  NaN  NaN  연도미상   NaN
# 482  정경일  정경일    NaN              NaN  미상   연도미상  NaN  NaN  연도미상   NaN

# %%
nkmerge[nkmerge["fname"].notnull() & nkmerge["Name"].notnull()]
# Out:
#       ID Name 성명(한글)                소속/직책  성별           생년월일       출생지  사망여부  \
# 0    강관주  강관주    NaN                  NaN  남성  1930년 07월 05일  평안남도 대동군   NaN
# 1    강능수  강능수    NaN      (사망) 당 중앙위원회 위원  남성  1930년 02월 21일       평양시  (사망)
# 2    강동윤  강동윤    NaN          당 중앙위원회 부부장  남성           연도미상       NaN   NaN
# 3    강련학  강련학    강연학     (사망) 민족화해협의회 부회장  남성           연도미상       NaN  (사망)
# 4    강명철  강명철    NaN  조선그리스도교연맹 중앙위원회 위원장  남성           연도미상       NaN   NaN
# ..   ...  ...    ...                  ...  ..            ...       ...   ...
# 600  황병서  황병서    NaN               인민군 차수  남성          1949년       NaN   NaN
# 601  황봉영  황봉영    NaN        조선올림픽위원회 부위원장  남성  1944년 08월 15일       NaN   NaN
# 602  황순희  황순희    NaN      (사망) 조선혁명박물관 관장  여성  1919년 05월 03일  북한지역외 중국  (사망)
# 603  황철식  황철식    NaN                  NaN  미상           연도미상       NaN   NaN
# 604  황학원  황학원    NaN                  NaN  남성  1941년 01월 01일       NaN   NaN
#
#               사망일자         fname
# ...

# %%
nkmerge[nkmerge["Name"].str.match("리상관")]
# Out:
#       ID Name 성명(한글) 소속/직책  성별  생년월일  출생지 사망여부  사망일자 fname
# 241  리상관  리상관    이상관   NaN  남성  연도미상  NaN  NaN  연도미상   NaN

# %%
nkmerge[nkmerge["Name"].str.match("리상원")]
# Out:
#       ID Name 성명(한글)            소속/직책  성별   생년월일  출생지 사망여부  사망일자 fname
# 242  리상원  리상원    이상원  최고인민회의 제14기 대의원  남성  1951년  NaN  NaN  연도미상   NaN

# %%
nkmerge[nkmerge["Name"].str.match("리선권")]
# Out:
#       ID Name 성명(한글)  소속/직책  성별  생년월일  출생지 사망여부  사망일자 fname
# 243  리선권  리선권    NaN  외무성 상  남성  연도미상  NaN  NaN  연도미상   NaN

# %%
nkmerge[nkmerge["Name"].str.match("정경일")]
# Out:
#       ID Name 성명(한글) 소속/직책  성별  생년월일  출생지 사망여부  사망일자 fname
# 482  정경일  정경일    NaN   NaN  미상  연도미상  NaN  NaN  연도미상   NaN
