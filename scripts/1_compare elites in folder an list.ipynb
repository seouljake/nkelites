# %%
import pandas as pd

df = pd.read_excel ('NK elite download checklist.xlsx')
print (df)
# Out:
#     Assignment Completed Name Leader ID 성명(한글)                소속/직책  성별  \
# 0      Zhandos         x  강관주       강관주    NaN                  NaN  남성
# 1      Zhandos         x  강능수       강능수    NaN      (사망) 당 중앙위원회 위원  남성
# 2      Zhandos         x  강동윤       강동윤    NaN          당 중앙위원회 부부장  남성
# 3      Zhandos         x  강련학       강련학    강연학     (사망) 민족화해협의회 부회장  남성
# 4      Zhandos         x  강명철       강명철    NaN  조선그리스도교연맹 중앙위원회 위원장  남성
# ..         ...       ...  ...       ...    ...                  ...  ..
# 600      Jacob         x  황병서       황병서    NaN               인민군 차수  남성
# 601      Jacob         x  황봉영       황봉영    NaN        조선올림픽위원회 부위원장  남성
# 602      Jacob         x  황순희       황순희    NaN      (사망) 조선혁명박물관 관장  여성
# 603      Jacob         x  황철식       황철식    NaN                  NaN  미상
# 604      Jacob         x  황학원       황학원    NaN                  NaN  남성
#
#               생년월일       출생지  사망여부           사망일자
# 0    1930년 07월 05일  평안남도 대동군   NaN           연도미상
# ...

# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  'nkproject.ipynb',
#  'NK elite download checklist.xlsx',
#  'sources',
#  '.ipynb_checkpoints']

# %%
fn=os.listdir('sources')

# %%
fn
# Out:
# ['박광호 상세정보.xls',
#  '허광욱 상세정보.xls',
#  '리택건 상세정보.xls',
#  '김석준 상세정보.xls',
#  '림경만 상세정보.xls',
#  '김성룡 상세정보.xls',
#  '전종수 상세정보.xls',
#  '김조국 상세정보.xls',
#  '장창하 상세정보.xls',
#  '김지선 상세정보.xls',
#  '임경재 상세정보.xls',
#  '리용철b 상세정보.xls',
#  '김봉영 상세정보.xls',
#  '김경호b 상세정보 .xlsx',
#  '오춘복 상세정보.xls',
#  '장준상 상세정보.xls',
#  '리병삼 상세정보.xls',
#  '최상려 상세정보.xls',
#  '장병규 상세정보.xls',
#  '정승일 상세정보.xls',
#  '전창복 상세정보.xls',
#  '주용일 상세정보.xls',
#  '류미영 상세정보.xls',
#  '장성우 상세정보.xls',
#  '김형준 상세정보.xls',
#  '리춘삼 상세정보.xls',
#  '최부일 상세정보.xls',
#  '구본태 상세정보.xls',
#  '김금철a 상세정보.xls',
#  '자성남 상세정보.xls',
#  '최승호 상세정보.xls',
#  '조연준 상세정보.xls',
#  '전희정 상세정보.xls',
#  '손철주 상세정보.xls',
#  '정영수 상세정보.xls',
#  '김정기 상세정보.xls',
#  '김광영 상세정보.xls',
#  '김덕훈 상세정보.xls',
#  '리학철 상세정보.xls',
#  '김국태 상세정보.xls',
#  '김영철a 상세정보.xls',
#  '최영일 상세정보.xls',
#  '정인철 상세정보.xls',
#  '조정호 상세정보.xls',
#  '최희정 상세정보.xls',
#  '엄정철 상세정보.xls',
#  '차승수 상세정보.xls',
#  '김창섭 상세정보.xls',
#  '최동명 상세정보.xls',
#  '강형봉 상세정보.xls',
#  '박춘남 상세정보.xls',
#  '리종무 상세정보.xls',
# ...

# %%
nl=pd.DataFrame(fn,columns=['Leader ID'])

# %%
nl
# Out:
#          filename
# 0    박광호 상세정보.xls
# 1    허광욱 상세정보.xls
# 2    리택건 상세정보.xls
# 3    김석준 상세정보.xls
# 4    림경만 상세정보.xls
# ..            ...
# 597  박광웅 상세정보.xls
# 598  리태일 상세정보.xls
# 599  림동옥 상세정보.xls
# 600  전경남 상세정보.xls
# 601  원응희 상세정보.xls
#
# [602 rows x 1 columns]

# %%
result=pd.concat([df, nl], axis=1, join='outer')

# %%
result
# Out:
#     Assignment Completed Name Leader ID 성명(한글)                소속/직책  성별  \
# 0      Zhandos         x  강관주       강관주    NaN                  NaN  남성
# 1      Zhandos         x  강능수       강능수    NaN      (사망) 당 중앙위원회 위원  남성
# 2      Zhandos         x  강동윤       강동윤    NaN          당 중앙위원회 부부장  남성
# 3      Zhandos         x  강련학       강련학    강연학     (사망) 민족화해협의회 부회장  남성
# 4      Zhandos         x  강명철       강명철    NaN  조선그리스도교연맹 중앙위원회 위원장  남성
# ..         ...       ...  ...       ...    ...                  ...  ..
# 600      Jacob         x  황병서       황병서    NaN               인민군 차수  남성
# 601      Jacob         x  황봉영       황봉영    NaN        조선올림픽위원회 부위원장  남성
# 602      Jacob         x  황순희       황순희    NaN      (사망) 조선혁명박물관 관장  여성
# 603      Jacob         x  황철식       황철식    NaN                  NaN  미상
# 604      Jacob         x  황학원       황학원    NaN                  NaN  남성
#
#               생년월일       출생지  사망여부           사망일자     Leader ID
# ...
