# %% [markdown]
# # libraries & global vars

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)

# %% [markdown]
# # io orgtree & org codes

# %%
path_orgtree = "C:/Users/seoul/Dropbox/00 technical/github/nkelites/data/combined data/combined data - 1 cleaning/cleaning step 2 - career/2.4 orgtree/"

# %%
filein_orgtree = "orgtree1_3.xlsx"

# %%
path_joborglink = "C:/Users/seoul/Dropbox/00 technical/github/nkelites/data/combined data/combined data - 1 cleaning/cleaning step 2 - career/2.3 joborglink/"

# %%
filein_joborglink = "joborglink_5_1tocode_1_Jeongsu.xlsx"

# %%
fileout_joborglink_prefix = "joborglink_5_2_"

# %%
fileout_orgtree = "orgtree1_4.xlsx"

# %% [markdown]
# # import orgtree

# %%
orgtree = pd.read_excel(path_orgtree+filein_orgtree)

# %%
orgtree.shape
# Out:
# (1162, 8)

# %%
orgtree[0:10]
# Out:
#    InsideGov PrimaryInstitution             OrgName ImmediateSuperiorOrg  \
# 0       True              최고재판소                 NaN                  NaN
# 1       True             최고인민회의  황해북도인민위원회_서흥군인민위원회            황해북도인민위원회
# 2       True             최고인민회의  황해북도인민위원회_개성시인민위원회            황해북도인민위원회
# 3       True             최고인민회의           황해북도인민위원회                  NaN
# 4       True             최고인민회의           황해남도인민위원회                  NaN
# 5       True             최고인민회의           함경북도인민위원회                  NaN
# 6       True             최고인민회의            함경도인민위원회                  NaN
# 7       True             최고인민회의           함경남도인민위원회                  NaN
# 8       True             최고인민회의            평양시인민위원회                  NaN
# 9       True             최고인민회의           평안북도인민위원회                  NaN
#
#    SupervisesParent LinkToCurrent_PrimaryInstitution LinkToCurrent_OrgName  \
# 0               0.0                           최고인민회의                 중앙재판소
# 1               0.0                    Please_Revise         Please_Revise
# 2               0.0                    Please_Revise         Please_Revise
# 3               0.0                    Please_Revise         Please_Revise
# 4               0.0                    Please_Revise         Please_Revise
# 5               0.0                    Please_Revise         Please_Revise
# 6               0.0                    Please_Revise         Please_Revise
# 7               0.0                    Please_Revise         Please_Revise
# 8               0.0                    Please_Revise         Please_Revise
# 9               0.0                    Please_Revise         Please_Revise
#
#     비고
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN

# %% [markdown]
# # import joborglink

# %%
joborglink_dtypes = {"OrgString":"str","PrimaryInstitution":"str","OrgName":"str","LinkToCurrent_PrimaryInstitution":"str","LintToCurrent_OrgName":"str","Notes":"str","InOrgTree":"bool"}
joborglink = pd.read_excel(path_joborglink+filein_joborglink,dtype=joborglink_dtypes)
joborglink.shape
# Out:
# (9463, 7)

# %%
joborglink.columns
# Out:
# Index(['OrgString', 'PrimaryInstitution', 'OrgName',
#        'LinkToCurrent_PrimaryInstitution', 'LintToCurrent_OrgName', 'Notes',
#        'InOrgTree'],
#       dtype='object')

# %%
joborglink.dropna()
joborglink.shape
# Out:
# (9463, 7)

# %%
joborglink = joborglink.drop_duplicates()
joborglink.shape
# Out:
# (2322, 7)

# %%
# joborglink.loc["InOrgTree"] = False

# %%
joborglink[0:2]
# Out:
#        OrgString PrimaryInstitution OrgName LinkToCurrent_PrimaryInstitution  \
# 0  ｢아시아태평양평화위원회｣      조선아시아태평양평화위원회     NaN                              NaN
# 1  ｢조국전선｣ 중앙위원회          조국통일민주주의전선   중앙위원회                          Current
#
#   LintToCurrent_OrgName       Notes  InOrgTree
# 0                   NaN        외곽단체      False
# 1               Current  외곽단체 -> 정당      False

# %% [markdown]
# # joborglink - filter out "uncertain" & "error" rows

# %%
joborglink_uncertain = joborglink[
    (joborglink.PrimaryInstitution.str.lower() == "uncertain") |
    (joborglink.OrgName.str.lower() == "uncertain") | 
    (joborglink.LinkToCurrent_PrimaryInstitution.str.lower() == "uncertain") | 
    (joborglink.LintToCurrent_OrgName.str.lower() == "uncertain")]

joborglink_uncertain.shape
# Out:
# (539, 7)

# %%
joborglink_uncertain.drop_duplicates().shape
# Out:
# (539, 7)

# %%
joborglink_error = joborglink[
    (joborglink.PrimaryInstitution.str.lower() == "error") |
    (joborglink.OrgName.str.lower() == "error") | 
    (joborglink.LinkToCurrent_PrimaryInstitution.str.lower() == "error") | 
    (joborglink.LintToCurrent_OrgName.str.lower() == "error")]

joborglink_error.shape
# Out:
# (211, 7)

# %%
joborglink = joborglink[
    (joborglink.PrimaryInstitution.str.lower() != "uncertain") &
    (joborglink.OrgName.str.lower() != "uncertain") &
    (joborglink.LinkToCurrent_PrimaryInstitution.str.lower() != "uncertain") &
    (joborglink.LintToCurrent_OrgName.str.lower() != "uncertain") &
    (joborglink.PrimaryInstitution.str.lower() != "error") &
    (joborglink.OrgName.str.lower() != "error") &
    (joborglink.LinkToCurrent_PrimaryInstitution.str.lower() != "error") &
    (joborglink.LintToCurrent_OrgName.str.lower() != "error")]

joborglink.shape
# Out:
# (1573, 7)

# %%
# 2322 - 1 overlapping job string
joborglink_uncertain.shape[0] + joborglink_error.shape[0] + joborglink.shape[0]
# Out:
# 2323

# %% [markdown]
# # export joborglink_ files to excel

# %%
joborglink_uncertain.to_excel(path_joborglink + fileout_joborglink_prefix + "uncertain.xlsx")

# %%
joborglink_error.to_excel(path_joborglink + fileout_joborglink_prefix + "error.xlsx")

# %% [markdown]
# # update joborglink InOrgTree

# %%
joborglink[0:2]
# Out:
#        OrgString PrimaryInstitution OrgName LinkToCurrent_PrimaryInstitution  \
# 0  ｢아시아태평양평화위원회｣      조선아시아태평양평화위원회     NaN                              NaN
# 1  ｢조국전선｣ 중앙위원회          조국통일민주주의전선   중앙위원회                          Current
#
#   LintToCurrent_OrgName       Notes  InOrgTree
# 0                   NaN        외곽단체      False
# 1               Current  외곽단체 -> 정당      False

# %%
orgtree[0:2]
# Out:
#    InsideGov PrimaryInstitution             OrgName ImmediateSuperiorOrg  \
# 0       True              최고재판소                 NaN                  NaN
# 1       True             최고인민회의  황해북도인민위원회_서흥군인민위원회            황해북도인민위원회
#
#    SupervisesParent LinkToCurrent_PrimaryInstitution LinkToCurrent_OrgName  \
# 0               0.0                           최고인민회의                 중앙재판소
# 1               0.0                    Please_Revise         Please_Revise
#
#     비고
# 0  NaN
# 1  NaN

# %%
orgtreemerge = orgtree[["PrimaryInstitution","OrgName"]]

# %%
joborglink = joborglink.merge(orgtreemerge,how="left",on=["PrimaryInstitution","OrgName"],indicator=True)
joborglink.shape
# Out:
# (1573, 8)

# %%
joborglink[0:2]
# Out:
#        OrgString PrimaryInstitution OrgName LinkToCurrent_PrimaryInstitution  \
# 0  ｢아시아태평양평화위원회｣      조선아시아태평양평화위원회     NaN                              NaN
# 1  ｢조국전선｣ 중앙위원회          조국통일민주주의전선   중앙위원회                          Current
#
#   LintToCurrent_OrgName       Notes  InOrgTree     _merge
# 0                   NaN        외곽단체      False       both
# 1               Current  외곽단체 -> 정당      False  left_only

# %%
joborglink[["_merge","InOrgTree","OrgName"]].groupby(["_merge","InOrgTree"]).count()
# Out:
#                       OrgName
# _merge     InOrgTree
# left_only  False          454
#            True           128
# right_only False            0
#            True             0
# both       False          161
#            True           575

# %%
# InOrgTree = True if both appear
joborglink.loc[joborglink._merge == "both","InOrgTree"] = True

# %%
joborglink[["_merge","InOrgTree","OrgName"]].groupby(["_merge","InOrgTree"]).count()
# Out:
#                       OrgName
# _merge     InOrgTree
# left_only  False          454
#            True           128
# right_only False            0
#            True             0
# both       False            0
#            True           736

# %%
# double check orgs which are supposedly InOrgTree, but didn't match in the merge
joborglink["DoubleCheck_InOrgTree"] = False
joborglink.loc[(joborglink._merge == "left_only") & (joborglink.InOrgTree == True),"DoubleCheck_InOrgTree"] = True

# %%
joborglink[["_merge","InOrgTree","DoubleCheck_InOrgTree","OrgName"]].groupby(["_merge","InOrgTree","DoubleCheck_InOrgTree"]).count()
# Out:
#                                             OrgName
# _merge     InOrgTree DoubleCheck_InOrgTree
# left_only  False     False                      454
#                      True                         0
#            True      False                        0
#                      True                       128
# right_only False     False                        0
#                      True                         0
#            True      False                        0
#                      True                         0
# both       False     False                        0
#                      True                         0
#            True      False                      736
#                      True                         0

# %%
#
joborglink[joborglink.DoubleCheck_InOrgTree==True]
# Out:
#                       OrgString PrimaryInstitution              OrgName  \
# 879              국방위원회 총정치국 선전부              국방위원회             총정치국_선전부
# 880                       호위사령부              국방위원회                호위사령부
# 881                 인민무력부 호위사령부              국방위원회                호위사령부
# 882                 국방위원회 호위사령부              국방위원회                호위사령부
# 883                   당 중앙위 정치위                노동당          중앙위원회_정치위원회
# 885                       중앙인민위                노동당              중앙인민위원회
# 894                         건설성                 내각                  건설성
# 898                       공보위원회                 내각                공보위원회
# 901                   내각 교육성 X국                 내각               교육성_X국
# 910                     국가건설위원회                 내각              국가건설위원회
# 927               금속공업부 금속생산지도국                 내각        금속공업부_금속생산지도국
# 930                  내각 금속기계공업성                 내각              금속기계공업성
# 931                     금속기계공업성                 내각              금속기계공업성
# 932                      금속기계공업                 내각              금속기계공업성
# 948                 대외경제협력추진위원회                 내각  대외경제위원회_대외경제협력추진위원회
# 951                      무역부 3국                 내각               무역부_3국
# 1109                              NaN                   NaN
# 1110                              NaN                   NaN
# 1131                              NaN                   NaN
# 1132                              NaN                   NaN
# 1133                              NaN                   NaN
# 1134                              NaN                   NaN
# 1135                              NaN                   NaN
# 1140                              NaN                   NaN
# 1141                              NaN                   NaN
# 1142                              NaN                   NaN
# 1143                              NaN                   NaN
# 1158                              NaN                   NaN
# 1163                              NaN                   NaN
# 1164                              NaN                   NaN
# 1166                              NaN                   NaN
# 1167                              NaN                   NaN
# 1168                              NaN                   NaN
# 1177                              NaN                   NaN
# 1200                              NaN                   NaN
# 1203                              NaN                   NaN
# 1211                              NaN                   NaN
# 1231                              NaN                   NaN
# 1243                              NaN                   NaN
# 1246                              NaN                   NaN
# 1266                              NaN                   NaN
# 1270                              NaN                   NaN
# 1285                              NaN                   NaN
# 1286                              NaN                   NaN
# 1287                              NaN                   NaN
# 1337                              NaN                   NaN
# 1338                              NaN                   NaN
# 1342                              NaN                   NaN
# 1345                              NaN                   NaN
# 1346                              NaN                   NaN
# 1347                              NaN                   NaN
# 1355                              NaN                   NaN
# 1386                              NaN                   NaN
# 1387                              NaN                   NaN
# 1396                              NaN                   NaN
# 1397                              NaN                   NaN
# 1407                              NaN                   NaN
# 1417                              NaN                   NaN
# 1424                              NaN                   NaN
# 1425                              NaN                   NaN
# 1426                              NaN                   NaN
# 1427                              NaN                   NaN
# 1428                              NaN                   NaN
# 1429                              NaN                   NaN
# 1432                              NaN                   NaN
# 1433                              NaN                   NaN
# 1434                              NaN                   NaN
# 1438                              NaN                   NaN
# 1447                              NaN                   NaN
# 1449                              NaN                   NaN
# 1450                              NaN                   NaN
# 1452                              NaN                   NaN
# 1453                              NaN                   NaN
# 1455                              NaN                   NaN
# 1458                              NaN                   NaN
# 1463                              NaN                   NaN
# 1464                              NaN                   NaN
# 1467                              NaN                   NaN
# 1468                              NaN                   NaN
# 1471                              NaN                   NaN
# 1479                              NaN                   NaN
# 1485                              NaN                   NaN
# 1487                              NaN                   NaN
# 1488                              NaN                   NaN
# 1489                              NaN                   NaN
# 1491                              NaN                   NaN
# 1497                              NaN                   NaN
# 1498                              NaN                   NaN
# 1499                              NaN                   NaN
# 1500                              NaN                   NaN
# 1501                              NaN                   NaN
# 1502                              NaN                   NaN
# 1506                              NaN                   NaN
# 1507                              NaN                   NaN
# 1509                              NaN                   NaN
# 1510                              NaN                   NaN
# 1516                              NaN                   NaN
# 1563                              NaN                   NaN
#
#                   Notes  InOrgTree     _merge  DoubleCheck_InOrgTree
# 879                 NaN       True  left_only                   True
# 880              국방위 산하       True  left_only                   True
# 881        multiple org       True  left_only                   True
# 882                 NaN       True  left_only                   True
# 883                 NaN       True  left_only                   True
# 885              노동당 산하       True  left_only                   True
# 894               내각 산하       True  left_only                   True
# 898               내각 산하       True  left_only                   True
# 901                 NaN       True  left_only                   True
# 910               내각 산하       True  left_only                   True
# 927               내각 산하       True  left_only                   True
# 930                 NaN       True  left_only                   True
# 931                 NaN       True  left_only                   True
# 932                 NaN       True  left_only                   True
# 948          대외경제위원회 산하       True  left_only                   True
# 951               내각 산하       True  left_only                   True
# 956                 NaN       True  left_only                   True
# 980       내각-수도건설위원회 산하       True  left_only                   True
# 997                 NaN       True  left_only                   True
# 1000                NaN       True  left_only                   True
# 1001                NaN       True  left_only                   True
# 1002                NaN       True  left_only                   True
# 1003                NaN       True  left_only                   True
# 1005                NaN       True  left_only                   True
# 1006            외무성 제9국       True  left_only                   True
# 1019              내각 산하       True  left_only                   True
# 1020                NaN       True  left_only                   True
# 1027                NaN       True  left_only                   True
# 1030              내각 산하       True  left_only                   True
# 1031              내각 산하       True  left_only                   True
# 1032                NaN       True  left_only                   True
# 1033                NaN       True  left_only                   True
# 1037              내각 산하       True  left_only                   True
# 1046                NaN       True  left_only                   True
# 1047                NaN       True  left_only                   True
# 1049                NaN       True  left_only                   True
# 1056                NaN       True  left_only                   True
# 1065                NaN       True  left_only                   True
# 1067                NaN       True  left_only                   True
# 1070                NaN       True  left_only                   True
# 1071                NaN       True  left_only                   True
# 1083                NaN       True  left_only                   True
# 1084                NaN       True  left_only                   True
# 1097                NaN       True  left_only                   True
# 1098                NaN       True  left_only                   True
# 1101                NaN       True  left_only                   True
# 1109          최고인민회의 산하       True  left_only                   True
# 1110                NaN       True  left_only                   True
# 1131                NaN       True  left_only                   True
# 1132                NaN       True  left_only                   True
# 1133                NaN       True  left_only                   True
# 1134                NaN       True  left_only                   True
# 1135                NaN       True  left_only                   True
# 1140                NaN       True  left_only                   True
# 1141                NaN       True  left_only                   True
# 1142                NaN       True  left_only                   True
# 1143                NaN       True  left_only                   True
# 1158                NaN       True  left_only                   True
# 1163          중앙선거지도위원회       True  left_only                   True
# 1164                NaN       True  left_only                   True
# 1166                NaN       True  left_only                   True
# 1167                NaN       True  left_only                   True
# 1168                NaN       True  left_only                   True
# 1177                NaN       True  left_only                   True
# 1200                NaN       True  left_only                   True
# 1203                NaN       True  left_only                   True
# 1211                NaN       True  left_only                   True
# 1231                NaN       True  left_only                   True
# 1243                NaN       True  left_only                   True
# 1246                NaN       True  left_only                   True
# 1266      정무원 Not found       True  left_only                   True
# 1270                NaN       True  left_only                   True
# 1285       1부 Not found       True  left_only                   True
# 1286      기술국 Not found       True  left_only                   True
# 1287                NaN       True  left_only                   True
# 1337                NaN       True  left_only                   True
# 1338                NaN       True  left_only                   True
# 1342                NaN       True  left_only                   True
# 1345    아태평화위 Not found       True  left_only                   True
# 1346                NaN       True  left_only                   True
# 1347                NaN       True  left_only                   True
# 1355            서해함대사령부       True  left_only                   True
# 1386            동해함대사령부       True  left_only                   True
# 1387                NaN       True  left_only                   True
# 1396                NaN       True  left_only                   True
# 1397                NaN       True  left_only                   True
# 1407                NaN       True  left_only                   True
# 1417                NaN       True  left_only                   True
# 1424                NaN       True  left_only                   True
# 1425                NaN       True  left_only                   True
# 1426                NaN       True  left_only                   True
# 1427                NaN       True  left_only                   True
# 1428                NaN       True  left_only                   True
# 1429                NaN       True  left_only                   True
# 1432                NaN       True  left_only                   True
# 1433                NaN       True  left_only                   True
# 1434                NaN       True  left_only                   True
# 1438                NaN       True  left_only                   True
# 1447                NaN       True  left_only                   True
# 1449       1부 Not found       True  left_only                   True
# 1450                NaN       True  left_only                   True
# 1452       1부 Not found       True  left_only                   True
# 1453                NaN       True  left_only                   True
# 1455                NaN       True  left_only                   True
# 1458                NaN       True  left_only                   True
# 1463                NaN       True  left_only                   True
# 1464                NaN       True  left_only                   True
# 1467                NaN       True  left_only                   True
# 1468                NaN       True  left_only                   True
# 1471     중앙위원회->중앙인민위원회       True  left_only                   True
# 1479                NaN       True  left_only                   True
# 1485                NaN       True  left_only                   True
# 1487                NaN       True  left_only                   True
# 1488              기계공업부       True  left_only                   True
# 1489                NaN       True  left_only                   True
# 1491                NaN       True  left_only                   True
# 1497                NaN       True  left_only                   True
# 1498                NaN       True  left_only                   True
# 1499                NaN       True  left_only                   True
# 1500     내각-교육위원회-고등교육성       True  left_only                   True
# 1501                NaN       True  left_only                   True
# 1502                NaN       True  left_only                   True
# 1506          금속기계공업위원회       True  left_only                   True
# 1507                NaN       True  left_only                   True
# 1509  전기기계관리국 Not found       True  left_only                   True
# 1510                NaN       True  left_only                   True
# 1516                NaN       True  left_only                   True
# 1563                NaN       True  left_only                   True

# %%
# extract records to update in orgtree
merge_columns = ["PrimaryInstitution","OrgName","LinkToCurrent_PrimaryInstitution","LintToCurrent_OrgName"]
joborglink_toupdate = joborglink.loc[(joborglink["_merge"] == "left_only") & (joborglink["InOrgTree"] == False),merge_columns]
# joborglink_toupdate = joborglink.loc[(joborglink["_merge"] == "left_only"),merge_columns]
#joborglink_toupdate = joborglink.loc[(joborglink["_merge"] == "left_only") & (joborglink["InOrgTree"] == False),merge_columns]
joborglink_toupdate.shape
# Out:
# (742, 4)

# %%
joborglink.drop(columns=["_merge"],inplace=True,axis=1)

# %%
joborglink.to_excel(path_joborglink + fileout_joborglink_prefix + "correct.xlsx")

# %% [markdown]
# # update and export orgtree

# %%
joborglink_toupdate.shape
# Out:
# (614, 4)

# %%
joborglink_toupdate.columns
# Out:
# Index(['PrimaryInstitution', 'OrgName', 'LinkToCurrent_PrimaryInstitution',
#        'LintToCurrent_OrgName'],
#       dtype='object')

# %%
orgtree.columns
# Out:
# Index(['InsideGov', 'PrimaryInstitution', 'OrgName', 'ImmediateSuperiorOrg',
#        'SupervisesParent', 'LinkToCurrent_PrimaryInstitution',
#        'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [91], line 3
#       1 # records to update in orgtree
#       2 merge_columns = ["PrimaryInstitution","OrgName","LinkToCurrent_PrimaryInstitution","LintToCurrent_OrgName"]
# ----> 3 joborglink_toupdate = joborglink.loc[(joborglink._merge == "left_only") & (joborglink.InOrgTree == False),merge_columns]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_merge'

# %%
orglink.to_excel(path_joborglink+fileout_joborglink,index=False)
