# %%
import pandas as pd
import numpy as np
from datetime import date

# %% [markdown]
# # combined data - 2 tables

# %%
path_tables = "C:/Users/seoul/Dropbox/00 technical/github/nkelites/data/combined data/combined data - 2 tables/"

# %%
filename_careers = "careers.xlsx"
careers = pd.read_excel(path_tables + filename_careers,dtype="str")
careers.shape
# Out:
# (9001, 12)

# %%
careers.columns
# Out:
# Index(['CareerString', 'CareerDateString_2022', 'IsJob', 'MultipleSubstrings',
#        'CareerStartYear', 'CareerStartMonth', 'CareerSubstring', 'OrgString',
#        'PrimaryInstitution', 'OrgName', 'Position', 'Notes'],
#       dtype='object')

# %%
filename_orgtree = "orgtree.xlsx"
ot = pd.read_excel(path_tables + filename_orgtree,dtype="str")
ot.shape
# Out:
# (1742, 9)

# %%
filename_leadercareerlink = "leadercareerlink.xlsx"
lclink = pd.read_excel(path_tables + filename_leadercareerlink,dtype="str")
lclink.shape
# Out:
# (12617, 3)

# %%
filename_positions_elected = "positions_elected.xlsx"
elected = pd.read_excel(path_tables + filename_positions_elected,dtype="str")
elected.shape
# Out:
# (105, 4)

# %%
elected[elected.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [PrimaryInstitution, OrgName, Position, IsElected]
# Index: []

# %%
# position hierarchy table

# %%
# filename_leaderjoblink = "leaderjoblink.xlsx"

# %%
# filename_joborglink = "joborglink.xlsx"

# %% [markdown]
# # combined data - 3 queries

# %%
path_queries = "C:/Users/seoul/Dropbox/00 technical/github/nkelites/data/combined data/combined data - 3 queries/"

# %%
filename_leaderjobtransition = "leaderjobtransition.xlsx"
# ljt = pd.read_excel(path_queries + filename_leaderjobtransition,dtype="str")

# %%
today = date.today()
print(today)
# Out:
# 2023-07-21

# %% [markdown]
# # functions

# %%
def merge_results(m):
    
    print("\nMerge Results...")
    print("")
    print("\tshape     :",m.shape)
    print("\tleft_only :",m[m["_merge"]=="left_only"].shape)
    print("\tboth      :",m[m["_merge"]=="both"].shape)
    print("\tright_only:",m[m["_merge"]=="right_only"].shape)

# %%
# using this on (PI,OrgName) will ensure unique & non-null keys
# using this on a larger df will ensure unique rows and non-null keys, but not unique keys

def unique_non_null_rows(olddf):
    
    df = olddf.copy()
    
    
    ### drop duplicates
    df = df.drop_duplicates(keep="first",ignore_index=True)

    ### drop null rows
    df.dropna(how="all",axis=0,inplace=True)
    
    # drop rows with null PI
    df = df[~(df["PrimaryInstitution"].isna())]
        
    ### drop rows where PI contains stop words
    stop_words_lower = ["uncertain","current","deprecated","please_revise"]
    df = df[ ~ df["PrimaryInstitution"].str.lower().isin(stop_words_lower)]
            

    print("\nUnique Non-null Rows...")
    print("")
    print("\tNon-unique rows:",olddf.shape)
    print("\tUnique rows    :",df.shape)

    ### sort
    df = df.sort_values(["PrimaryInstitution","OrgName"])
    
    return df

# %% [markdown]
# # 1. deprecate old version

# %%
table_name = "leaderjobtransition"
table_name
# Out:
# 'leaderjobtransition'

# %%
filename_leaderjobtransition
# Out:
# 'leaderjobtransition.xlsx'

# %%
filename_deprecated = table_name + "_deprecated_"+str(today)+".xlsx"
filename_deprecated
# Out:
# 'leaderjobtransition_deprecated_2023-07-21.xlsx'

# %%
# deprecate old query
# oldtable = pd.read_excel(path_queries + filename_careers,dtype="str")
# oldtable.to_excel(path_queries + filename_deprecated,index=False)

# %% [markdown]
# # 2. select on careers: IsJob=True, remove elected positions

# %%
# get jobs from careers
jobs = careers[(careers["IsJob"]=="True") & (careers["CareerStartYear"].notna())]

# %%
jobs.shape
# Out:
# (6397, 12)

# %%
elected.shape
# Out:
# (105, 4)

# %%
elected = unique_non_null_rows(elected)
elected.shape
# Out:
# Unique Non-null Rows...
#
# 	Non-unique rows: (105, 4)
# 	Unique rows    : (105, 4)
# (105, 4)

# %%
# remove elected positions
key_columns = ["PrimaryInstitution","OrgName","Position"]
jobs2 = jobs.merge(elected,on=key_columns,how="outer",indicator=True)
jobs2.shape
# Out:
# (6397, 14)

# %%
merge_results(jobs2)
# Out:
# Merge Results...
#
# 	shape     : (6397, 14)
# 	left_only : (4678, 14)
# 	both      : (1719, 14)
# 	right_only: (0, 14)

# %%
jobs2.IsElected.unique()
# Out:
# array([nan, '1'], dtype=object)

# %%
jobs2.drop(columns=["_merge"],inplace=True)

# %%
jobs2.head(5)
# Out:
#        CareerString CareerDateString_2022 IsJob MultipleSubstrings  \
# 0  1996. 3 외교부 10국장                   NaN  True                  1
# 1    1973.12 외교부 국장                   NaN  True                  1
# 2    1983. 3 외교부 국장                   NaN  True                  1
# 3    1990. 3 외교부 국장                   NaN  True                  1
# 4            외교부 국장               1973.12  True                  1
#
#   CareerStartYear CareerStartMonth CareerSubstring OrgString  \
# 0            1996                3             NaN       외교부
# 1            1973               12             NaN       외교부
# 2            1983                3             NaN       외교부
# 3            1990                3             NaN       외교부
# 4            1973               12             NaN       외교부
#
#   PrimaryInstitution OrgName Position Notes IsElected
# 0                정무원     외교부       국장   NaN       NaN
# 1                정무원     외교부       국장   NaN       NaN
# 2                정무원     외교부       국장   NaN       NaN
# 3                정무원     외교부       국장   NaN       NaN
# 4                정무원     외교부       국장   NaN       NaN

# %%
jobs2 = jobs2[jobs2["IsElected"].isna()]
jobs2.shape
# Out:
# (4678, 13)

# %% [markdown]
# # 3. merge leadercareerlink & careers tables

# %%
lclink.head(2)
# Out:
#   LeaderID                CareerString CareerDateString_2022
# 0      리선권   개성공단 남북공동위원회 통행통신통관 분과위원회     2013.09 ~ 2014.01
# 1      조경철            故 김정일 국가장의위원회 위원               2011.12

# %%
# leader-job query - left join - includes IsJob True & False
key_columns = ["CareerString","CareerDateString_2022"]
lc = lclink.merge(jobs2,on=key_columns,how="left",indicator=True)
lc.shape
# Out:
# (12857, 15)

# %%
merge_results(lc)
# Out:
# Merge Results...
#
# 	shape     : (12857, 15)
# 	left_only : (8032, 15)
# 	both      : (4825, 15)
# 	right_only: (0, 15)

# %%
# no "left-only" cases when IsJob=True
lc[(lc["IsJob"]=="True") & (lc["_merge"]=="left_only")]
# Out:
# Empty DataFrame
# Columns: [LeaderID, CareerString, CareerDateString_2022, IsJob, MultipleSubstrings, CareerStartYear, CareerStartMonth, CareerSubstring, OrgString, PrimaryInstitution, OrgName, Position, Notes, IsElected, _merge]
# Index: []

# %%
# leader-job query - inner join - only includes IsJob = True
key_columns = ["CareerString","CareerDateString_2022"]
lc = lclink.merge(jobs2,on=key_columns,how="inner",indicator=False)
lc = lc.sort_values("LeaderID",ignore_index=True)
lc.shape
# Out:
# (4825, 14)

# %%
# instantiate CareerStartDate
lc["CareerStartDate"]=np.nan
lc.loc[lc["CareerStartMonth"].isna(),"CareerStartDate"] = lc[lc["CareerStartMonth"].isna()].apply(lambda x: str(x["CareerStartYear"]) + "00",axis=1)
lc.loc[(lc["CareerStartMonth"].notna()) & (lc.apply(lambda x: len(str(x["CareerStartMonth"])),axis=1)==2),"CareerStartDate"] = lc[(lc["CareerStartMonth"].notna()) & (lc.apply(lambda x: len(str(x["CareerStartMonth"])),axis=1)==2)].apply(lambda x: str(x["CareerStartYear"]) + str(x["CareerStartMonth"]),axis=1)
lc.loc[(lc["CareerStartMonth"].notna()) & (lc.apply(lambda x: len(str(x["CareerStartMonth"])),axis=1)==1),"CareerStartDate"] = lc[(lc["CareerStartMonth"].notna()) & (lc.apply(lambda x: len(str(x["CareerStartMonth"])),axis=1)==1)].apply(lambda x: str(x["CareerStartYear"]) + "0" + str(x["CareerStartMonth"]),axis=1)

# %%
lc.shape
# Out:
# (4825, 15)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# # 4. calculate temporally adjacent transitions for each leader

# %%
def calculate_resume_transitions(lc,leaderid):

    t = lc[(lc["LeaderID"]==leaderid) & (lc["CareerStartYear"].notna())]
    t = t.drop_duplicates(["CareerStartYear","PrimaryInstitution","OrgName"],keep="first")
    t = t.sort_values("CareerStartDate",ignore_index=True)
    print("resume:",t.shape)
    
    tr = t.merge(t,on="LeaderID",how="inner",suffixes=("_1","_2"))
    # sort based on CareerStartDates
    tr = tr.sort_values(["CareerStartDate_1","CareerStartDate_2"])
    
    # drop keys where CareerStartDate_1 <= CareerStartDate_2
    tr = tr[tr.apply(lambda x: x["CareerStartDate_1"] < x["CareerStartDate_2"],axis=1)]
    #tr.shape
    
    # smallest next startdate
    dates = tr[["CareerStartDate_1","CareerStartDate_2"]]
    #dates
    mindate = dates.groupby("CareerStartDate_1",as_index=False).agg({"CareerStartDate_2":"min"})
    mindate.columns = ["CareerStartDate_1","CareerStartDate_2_min"]
    #mindate
    
    tr2 = tr.merge(mindate,on="CareerStartDate_1",how="left")
    #tr2.shape
    
    tr3 = tr2[tr2.apply(lambda x: x["CareerStartDate_2"] == x["CareerStartDate_2_min"],axis=1)]
    print("transitions:",tr3.shape)
    
    #print(tr3[some_columns])

    return tr3

# %%
leaderid = "강관주"
lct = calculate_resume_transitions(lc,leaderid)
# Out:
# resume: (17, 15)
# transitions: (21, 30)

# %%
some_columns = ["LeaderID","CareerStartDate_1","PrimaryInstitution_1","OrgName_1","Position_1","CareerStartDate_2","PrimaryInstitution_2","OrgName_2","Position_2"]
lct[some_columns]
# Out:
#     LeaderID CareerStartDate_1 PrimaryInstitution_1           OrgName_1  \
# 0        강관주            196100                체육연구원             체육과학연구소
# 1        강관주            196100                체육연구원             체육과학연구소
# 16       강관주            197300             평양만경대예술단                 섭외부
# 17       강관주            197300                  노동당               문화예술부
# 44       강관주            197505           조선대외문화연락협회                 NaN
# 57       강관주            198600                  노동당        당중앙위원회_조직지도부
# 58       강관주            198600                  노동당        당중앙위원회_조직지도부
# 69       강관주            198800                  노동당  당중앙위원회_통일전선부_문화교류국
# 70       강관주            198800                  노동당        당중앙위원회_통일전선부
# 89       강관주            198903                  노동당        당중앙위원회_통일전선부
# 90       강관주            198903                  노동당        당중앙위원회_통일전선부
# 98       강관주            199008                  정무원           조국평화통일위원회
# 99       강관주            199008                   내각           조국평화통일위원회
# 112      강관주            199109              보천보전자악단                 NaN
# 113      강관주            199109              보천보전자악단                 NaN
# 118      강관주            199301                  노동당  당중앙위원회_통일전선부_문화교류국
# 119      강관주            199301                  노동당        당중앙위원회_통일전선부
# 126      강관주            199310          조선해외동포원호위원회                 NaN
# 127      강관주            199310          조선해외동포원호위원회                 NaN
# 129      강관주            199702                  노동당        당중앙위원회_대외연락부
# 130      강관주            199702                  노동당  당중앙위원회_대외연락부_사회문화부
#
#     Position_1 CareerStartDate_2 PrimaryInstitution_2           OrgName_2  \
# 0          연구원            197300             평양만경대예술단                 섭외부
# 1          연구원            197300                  노동당               문화예술부
# 16         부부장            197505           조선대외문화연락협회                 NaN
# 17          과장            197505           조선대외문화연락협회                 NaN
# 44          국장            198600                  노동당        당중앙위원회_조직지도부
# 57         부부장            198800                  노동당  당중앙위원회_통일전선부_문화교류국
# 58         부부장            198800                  노동당        당중앙위원회_통일전선부
# 69         부부장            198903                  노동당        당중앙위원회_통일전선부
# 70         부부장            198903                  노동당        당중앙위원회_통일전선부
# 89          부장            199008                  정무원           조국평화통일위원회
# 90          부장            199008                   내각           조국평화통일위원회
# 98        부위원장            199109              보천보전자악단                 NaN
# 99        부위원장            199109              보천보전자악단                 NaN
# 112         고문            199301                  노동당  당중앙위원회_통일전선부_문화교류국
# 113         고문            199301                  노동당        당중앙위원회_통일전선부
# 118         부장            199310          조선해외동포원호위원회                 NaN
# 119         부장            199310          조선해외동포원호위원회                 NaN
# 126        위원장            199702                  노동당        당중앙위원회_대외연락부
# 127        위원장            199702                  노동당  당중앙위원회_대외연락부_사회문화부
# 129         부장            200900                   내각                225국
# 130         부장            200900                   내각                225국
#
#     Position_2
# 0          부부장
# 1           과장
# 16          국장
# 17          국장
# 44         부부장
# 57         부부장
# 58         부부장
# 69          부장
# 70          부장
# 89        부위원장
# 90        부위원장
# 98          고문
# 99          고문
# 112         부장
# 113         부장
# 118        위원장
# 119        위원장
# 126         부장
# 127         부장
# 129         국장
# 130         국장

# %%
leaderids = list(lc["LeaderID"].unique())

# %%
len(leaderids)
# Out:
# 554

# %%
def compile_leader_transitions(lc):
    
    leaderids = list(lc["LeaderID"].unique())
    
    leader_resumes = []
    
    for leaderid in leaderids:
        leader_resume = calculate_resume_transitions(lc,leaderid)
        leader_resumes.append(leader_resume)
        
    lct = pd.concat(leader_resumes,ignore_index=True)
    
    return lct

# %%
ljt = compile_leader_transitions(lc)
# Out:
# resume: (17, 15)
# transitions: (21, 30)
# resume: (12, 15)
# transitions: (13, 30)
# resume: (5, 15)
# transitions: (5, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (5, 15)
# transitions: (5, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (14, 15)
# transitions: (16, 30)
# resume: (8, 15)
# transitions: (7, 30)
# resume: (15, 15)
# transitions: (17, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (15, 15)
# transitions: (22, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (5, 15)
# transitions: (5, 30)
# resume: (19, 15)
# transitions: (23, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (14, 15)
# transitions: (14, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (10, 15)
# transitions: (10, 30)
# resume: (7, 15)
# transitions: (8, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (8, 15)
# transitions: (7, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (8, 15)
# transitions: (7, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (9, 15)
# transitions: (8, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (12, 15)
# transitions: (12, 30)
# resume: (9, 15)
# transitions: (8, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (14, 15)
# transitions: (14, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (22, 15)
# transitions: (26, 30)
# resume: (10, 15)
# transitions: (11, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (11, 15)
# transitions: (10, 30)
# resume: (11, 15)
# transitions: (16, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (10, 15)
# transitions: (12, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (18, 15)
# transitions: (21, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (19, 15)
# transitions: (30, 30)
# resume: (15, 15)
# transitions: (17, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (17, 15)
# transitions: (21, 30)
# resume: (10, 15)
# transitions: (16, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (15, 15)
# transitions: (17, 30)
# resume: (9, 15)
# transitions: (11, 30)
# resume: (14, 15)
# transitions: (19, 30)
# resume: (14, 15)
# transitions: (13, 30)
# resume: (10, 15)
# transitions: (13, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (22, 15)
# transitions: (34, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (22, 15)
# transitions: (26, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (13, 15)
# transitions: (13, 30)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (13, 15)
# transitions: (12, 30)
# resume: (11, 15)
# transitions: (12, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (14, 15)
# transitions: (13, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (16, 15)
# transitions: (17, 30)
# resume: (23, 15)
# transitions: (30, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (5, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (6, 15)
# transitions: (7, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (20, 15)
# transitions: (32, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (14, 15)
# transitions: (16, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (11, 15)
# transitions: (12, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (13, 15)
# transitions: (17, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (37, 15)
# transitions: (48, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (11, 15)
# transitions: (12, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (11, 15)
# transitions: (11, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (17, 15)
# transitions: (20, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (5, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (13, 15)
# transitions: (15, 30)
# resume: (9, 15)
# transitions: (17, 30)
# resume: (7, 15)
# transitions: (8, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (13, 15)
# transitions: (16, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (11, 15)
# transitions: (14, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (13, 15)
# transitions: (19, 30)
# resume: (11, 15)
# transitions: (12, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (14, 15)
# transitions: (16, 30)
# resume: (7, 15)
# transitions: (8, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (8, 15)
# transitions: (9, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (16, 15)
# transitions: (17, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (11, 15)
# transitions: (15, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (10, 15)
# transitions: (10, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (10, 15)
# transitions: (11, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (17, 15)
# transitions: (18, 30)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (11, 15)
# transitions: (12, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (27, 15)
# transitions: (33, 30)
# resume: (19, 15)
# transitions: (25, 30)
# resume: (12, 15)
# transitions: (11, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (8, 15)
# transitions: (7, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (11, 15)
# transitions: (12, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (5, 15)
# transitions: (5, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (22, 15)
# transitions: (37, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (9, 15)
# transitions: (11, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (14, 15)
# transitions: (16, 30)
# resume: (9, 15)
# transitions: (8, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (17, 15)
# transitions: (18, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (10, 15)
# transitions: (9, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (14, 15)
# transitions: (14, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (10, 15)
# transitions: (9, 30)
# resume: (33, 15)
# transitions: (42, 30)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (12, 15)
# transitions: (12, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (18, 15)
# transitions: (23, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (8, 15)
# transitions: (7, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (9, 15)
# transitions: (8, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (11, 15)
# transitions: (10, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (14, 15)
# transitions: (17, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (27, 15)
# transitions: (54, 30)
# resume: (12, 15)
# transitions: (13, 30)
# resume: (21, 15)
# transitions: (25, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (16, 15)
# transitions: (20, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (12, 15)
# transitions: (18, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (10, 15)
# transitions: (10, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (18, 15)
# transitions: (20, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (5, 15)
# transitions: (5, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (22, 15)
# transitions: (27, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (12, 15)
# transitions: (13, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (8, 15)
# transitions: (7, 30)
# resume: (9, 15)
# transitions: (10, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (12, 15)
# transitions: (15, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (13, 15)
# transitions: (13, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (8, 15)
# transitions: (7, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (9, 15)
# transitions: (8, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (10, 15)
# transitions: (11, 30)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (9, 15)
# transitions: (8, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (8, 15)
# transitions: (7, 30)
# resume: (16, 15)
# transitions: (18, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (5, 15)
# transitions: (6, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (14, 15)
# transitions: (16, 30)
# resume: (8, 15)
# transitions: (7, 30)
# resume: (29, 15)
# transitions: (36, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (10, 15)
# transitions: (13, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (11, 15)
# transitions: (11, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (14, 15)
# transitions: (15, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (2, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (10, 15)
# transitions: (17, 30)
# resume: (12, 15)
# transitions: (12, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (5, 15)
# transitions: (5, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (0, 0)
# resume: (14, 15)
# transitions: (18, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (10, 15)
# transitions: (15, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (20, 15)
# transitions: (24, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (14, 15)
# transitions: (15, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (17, 15)
# transitions: (23, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (23, 15)
# transitions: (29, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (9, 15)
# transitions: (10, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (14, 15)
# transitions: (15, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (18, 15)
# transitions: (21, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (11, 15)
# transitions: (11, 30)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (6, 15)
# transitions: (5, 30)
# resume: (14, 15)
# transitions: (14, 30)
# resume: (14, 15)
# transitions: (16, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (20, 15)
# transitions: (27, 30)
# resume: (17, 15)
# transitions: (16, 30)
# resume: (9, 15)
# transitions: (9, 30)
# resume: (11, 15)
# transitions: (10, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (6, 15)
# transitions: (6, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (10, 15)
# transitions: (12, 30)
# resume: (13, 15)
# transitions: (17, 30)
# resume: (11, 15)
# transitions: (10, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (14, 15)
# transitions: (18, 30)
# resume: (2, 15)
# transitions: (1, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (8, 15)
# transitions: (8, 30)
# resume: (5, 15)
# transitions: (5, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (13, 15)
# transitions: (15, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (10, 15)
# transitions: (12, 30)
# resume: (7, 15)
# transitions: (6, 30)
# resume: (23, 15)
# transitions: (34, 30)
# resume: (19, 15)
# transitions: (26, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (5, 15)
# transitions: (4, 30)
# resume: (4, 15)
# transitions: (4, 30)
# resume: (1, 15)
# transitions: (0, 0)
# resume: (4, 15)
# transitions: (3, 30)
# resume: (3, 15)
# transitions: (2, 30)
# resume: (7, 15)
# transitions: (7, 30)
# resume: (13, 15)
# transitions: (18, 30)
# resume: (5, 15)
# transitions: (4, 30)

# %%
ljt.shape
# Out:
# (3337, 30)

# %%
ljt.head(25)
# Out:
#    LeaderID                  CareerString_1 CareerDateString_2022_1 IsJob_1  \
# 0       강관주               1961. 체육과학연구소 연구원                     NaN    True
# 1       강관주               1961. 체육과학연구소 연구원                     NaN    True
# 2       강관주  1973. 만경대예술단 섭외부 부부장, 당 문화부 과장                     NaN    True
# 3       강관주                        당 문화부 과장                    1973    True
# 4       강관주                     대외문화연락협회 국장                 1975.05    True
# 5       강관주               1986. 당 조직지도부 부부장                     NaN    True
# 6       강관주               1986. 당 조직지도부 부부장                     NaN    True
# 7       강관주      1988. 당 통일전선부 #조총련# 담당 부부장                     NaN    True
# 8       강관주      조선노동당 통일전선부 조선인총연합회 담당 부부장                    1988    True
# 9       강관주               조선노동당 통일전선부 제1부부장                 1989.03    True
# 10      강관주               조선노동당 통일전선부 제1부부장                 1989.03    True
# 11      강관주                  조국평화통일위원회 부위원장                 1990.08    True
# 12      강관주          1990. 8 조국평화통일위원회 부위원장                     NaN    True
# 13      강관주              1991. 9 보천보전자악단 고문                     NaN    True
# 14      강관주              1991. 9 보천보전자악단 고문                     NaN    True
# 15      강관주              1993. 1 당 통일전선부 부장                     NaN    True
# 16      강관주                  조선노동당 통일전선부 부장                 1993.01    True
# 17      강관주           1993.10 해외동포원호위원회 위원장                     NaN    True
# 18      강관주           1993.10 해외동포원호위원회 위원장                     NaN    True
# 19      강관주         조선노동당 대외연락부(구 사회문화부) 부장                 1997.02    True
# 20      강관주     1997. 2 당 대외연락부(舊 사회문화부) 부장                     NaN    True
# 21      강능수       1973. 3 조선작가동맹 중앙위원회 부위원장                     NaN    True
# 22      강능수             1986. 2 조선문학창작사 부사장                     NaN    True
# 23      강능수             1986. 2 조선문학창작사 부사장                     NaN    True
# 24      강능수                    4.15문학창작단 단장                 1989.04    True
#
#    MultipleSubstrings_1 CareerStartYear_1 CareerStartMonth_1  \
# 0                     1              1961                NaN
# 1                     1              1961                NaN
# 2                     2              1973                NaN
# 3                     1              1973                NaN
# 4                     1              1975                  5
# 5                     1              1986                NaN
# 6                     1              1986                NaN
# 7                     1              1988                NaN
# 8                     1              1988                NaN
# 9                     1              1989                  3
# 10                    1              1989                  3
# 11                    1              1990                  8
# 12                    1              1990                  8
# 13                    1              1991                  9
# 14                    1              1991                  9
# 15                    1              1993                  1
# 16                    1              1993                  1
# 17                    1              1993                 10
# 18                    1              1993                 10
# 19                    1              1997                  2
# 20                    1              1997                  2
# 21                    1              1973                  3
# 22                    1              1986                  2
# 23                    1              1986                  2
# 24                    1              1989                  4
#
#    CareerSubstring_1       OrgString_1 PrimaryInstitution_1  ...  \
# 0                NaN           체육과학연구소                체육연구원  ...
# 1                NaN           체육과학연구소                체육연구원  ...
# 2     만경대예술단 섭외부 부부장        만경대예술단 섭외부             평양만경대예술단  ...
# 3                NaN             당 문화부                  노동당  ...
# 4                NaN          대외문화연락협회           조선대외문화연락협회  ...
# 5                NaN         노동당 조직지도부                  노동당  ...
# 6                NaN         노동당 조직지도부                  노동당  ...
# 7                NaN   노동당 중앙위원회 통일전선부                  노동당  ...
# 8                NaN       조선노동당 통일전선부                  노동당  ...
# 9                NaN   조선노동당 통일전선부 제1부                  노동당  ...
# 10               NaN   조선노동당 통일전선부 제1부                  노동당  ...
# 11               NaN         조국통일평화위원회                  정무원  ...
# 12               NaN         조국평화통일위원회                   내각  ...
# 13               NaN           보전보전자악단              보천보전자악단  ...
# 14               NaN           보전보전자악단              보천보전자악단  ...
# 15               NaN   노동당 중앙위원회 통일전선부                  노동당  ...
# 16               NaN       조선노동당 통일전선부                  노동당  ...
# 17               NaN         해외동포원호위원회          조선해외동포원호위원회  ...
# 18               NaN         해외동포원호위원회          조선해외동포원호위원회  ...
# 19               NaN       조선노동당 대외연락부                  노동당  ...
# 20               NaN   노동당 대외연락부 사회문화부                  노동당  ...
# 21               NaN  노동당 조선작가동맹 중앙위원회            조선문학예술총동맹  ...
# 22               NaN           조선문학창작사              조선문학창작사  ...
# 23               NaN           조선문학창작사              조선문학창작사  ...
# 24               NaN         4.15문학창작단            4.15문화창작단  ...
#
#    CareerStartMonth_2   CareerSubstring_2      OrgString_2  \
# 0                 NaN      만경대예술단 섭외부 부부장       만경대예술단 섭외부
# 1                 NaN                 NaN            당 문화부
# 2                   5                 NaN         대외문화연락협회
# 3                   5                 NaN         대외문화연락협회
# 4                 NaN                 NaN        노동당 조직지도부
# 5                 NaN                 NaN  노동당 중앙위원회 통일전선부
# 6                 NaN                 NaN      조선노동당 통일전선부
# 7                   3                 NaN  조선노동당 통일전선부 제1부
# 8                   3                 NaN  조선노동당 통일전선부 제1부
# 9                   8                 NaN        조국통일평화위원회
# 10                  8                 NaN        조국평화통일위원회
# 11                  9                 NaN          보전보전자악단
# 12                  9                 NaN          보전보전자악단
# 13                  1                 NaN  노동당 중앙위원회 통일전선부
# 14                  1                 NaN      조선노동당 통일전선부
# 15                 10                 NaN        해외동포원호위원회
# 16                 10                 NaN        해외동포원호위원회
# 17                  2                 NaN      조선노동당 대외연락부
# 18                  2                 NaN  노동당 대외연락부 사회문화부
# 19                NaN                 NaN          내각 225국
# 20                NaN                 NaN          내각 225국
# 21                  2                 NaN          조선문학창작사
# 22                  4                 NaN        4.15문학창작단
# 23                  4  조선작가동맹 통일문학담당 부위원장    조선작가동맹 통일문학담당
# 24                  9                 NaN               문화
#
#    PrimaryInstitution_2           OrgName_2 Position_2 Notes_2 IsElected_2  \
# 0              평양만경대예술단                 섭외부        부부장     NaN         NaN
# 1                   노동당               문화예술부         과장     NaN         NaN
# 2            조선대외문화연락협회                 NaN         국장     NaN         NaN
# 3            조선대외문화연락협회                 NaN         국장     NaN         NaN
# 4                   노동당        당중앙위원회_조직지도부        부부장     NaN         NaN
# 5                   노동당  당중앙위원회_통일전선부_문화교류국        부부장     NaN         NaN
# 6                   노동당        당중앙위원회_통일전선부        부부장     NaN         NaN
# 7                   노동당        당중앙위원회_통일전선부         부장     NaN         NaN
# 8                   노동당        당중앙위원회_통일전선부         부장     NaN         NaN
# 9                   정무원           조국평화통일위원회       부위원장     NaN         NaN
# 10                   내각           조국평화통일위원회       부위원장     NaN         NaN
# 11              보천보전자악단                 NaN         고문     NaN         NaN
# 12              보천보전자악단                 NaN         고문     NaN         NaN
# 13                  노동당  당중앙위원회_통일전선부_문화교류국         부장     NaN         NaN
# 14                  노동당        당중앙위원회_통일전선부         부장     NaN         NaN
# 15          조선해외동포원호위원회                 NaN        위원장     NaN         NaN
# 16          조선해외동포원호위원회                 NaN        위원장     NaN         NaN
# 17                  노동당        당중앙위원회_대외연락부         부장     NaN         NaN
# 18                  노동당  당중앙위원회_대외연락부_사회문화부         부장     NaN         NaN
# 19                   내각                225국         국장     NaN         NaN
# 20                   내각                225국         국장     NaN         NaN
# 21              조선문학창작사                 NaN        부사장     NaN         NaN
# 22            4.15문화창작단                 NaN         단장     NaN         NaN
# 23            조선문학예술총동맹              조선작가동맹       부위원장     NaN         NaN
# 24                   내각                 문화성          상     NaN         NaN
#
#    CareerStartDate_2 CareerStartDate_2_min
# 0             197300                197300
# 1             197300                197300
# 2             197505                197505
# 3             197505                197505
# 4             198600                198600
# 5             198800                198800
# 6             198800                198800
# 7             198903                198903
# 8             198903                198903
# 9             199008                199008
# 10            199008                199008
# 11            199109                199109
# 12            199109                199109
# 13            199301                199301
# 14            199301                199301
# 15            199310                199310
# 16            199310                199310
# 17            199702                199702
# 18            199702                199702
# 19            200900                200900
# 20            200900                200900
# 21            198602                198602
# 22            198904                198904
# 23            198904                198904
# 24            199909                199909
#
# [25 rows x 30 columns]

# %% [markdown]
# # 5. export new query

# %%
# refresh leaderjobtransition with new data
ljt.to_excel(path_tables + filename_leaderjobtransition,index=False)
