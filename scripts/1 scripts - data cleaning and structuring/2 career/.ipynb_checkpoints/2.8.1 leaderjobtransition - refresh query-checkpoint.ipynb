# %%
import pandas as pd
import numpy as np
from datetime import date

# %% [markdown]
# # combined data - 2 tables

# %%
path_tables = "C:/Users/seoul/Dropbox/00 technical/github/nkelites/data/combined data/combined data - 2 tables/"

# %%
filename_careers = "careers.xlsx"
careers = pd.read_excel(path_tables + filename_careers,dtype="str")
careers.shape
# Out:
# (9001, 12)

# %%
careers.columns
# Out:
# Index(['CareerString', 'CareerDateString_2022', 'IsJob', 'MultipleSubstrings',
#        'CareerStartYear', 'CareerStartMonth', 'CareerSubstring', 'OrgString',
#        'PrimaryInstitution', 'OrgName', 'Position', 'Notes'],
#       dtype='object')

# %%
filename_orgtree = "orgtree.xlsx"
ot = pd.read_excel(path_tables + filename_orgtree,dtype="str")
ot.shape
# Out:
# (1742, 9)

# %%
filename_leadercareerlink = "leadercareerlink.xlsx"
lclink = pd.read_excel(path_tables + filename_leadercareerlink,dtype="str")
lclink.shape
# Out:
# (12617, 3)

# %%
filename_pop = "pi_org_pos.xlsx"
pop = pd.read_excel(path_tables + filename_pop,dtype="str")
pop.shape
# Out:
# (2611, 7)

# %%
# filename_leaderjoblink = "leaderjoblink.xlsx"

# %%
# filename_joborglink = "joborglink.xlsx"

# %% [markdown]
# # combined data - 3 queries

# %%
path_queries = "C:/Users/seoul/Dropbox/00 technical/github/nkelites/data/combined data/combined data - 3 queries/"

# %%
filename_leaderjobtransition = "leaderjobtransition.xlsx"
# ljt = pd.read_excel(path_queries + filename_leaderjobtransition,dtype="str")

# %%
today = date.today()
print(today)
# Out:
# 2023-07-20

# %% [markdown]
# # functions

# %%
def merge_results(m):
    
    print("\nMerge Results...")
    print("")
    print("\tshape     :",m.shape)
    print("\tleft_only :",m[m["_merge"]=="left_only"].shape)
    print("\tboth      :",m[m["_merge"]=="both"].shape)
    print("\tright_only:",m[m["_merge"]=="right_only"].shape)

# %%
# using this on (PI,OrgName) will ensure unique & non-null keys
# using this on a larger df will ensure unique rows and non-null keys, but not unique keys

def unique_non_null_rows(olddf):
    
    df = olddf.copy()
    
    
    ### drop duplicates
    df = df.drop_duplicates(keep="first",ignore_index=True)

    ### drop null rows
    df.dropna(how="all",axis=0,inplace=True)
    
    # drop rows with null PI
    df = df[~(df["PrimaryInstitution"].isna())]
        
    ### drop rows where PI contains stop words
    stop_words_lower = ["uncertain","current","deprecated","please_revise"]
    df = df[ ~ df["PrimaryInstitution"].str.lower().isin(stop_words_lower)]
            

    print("\nUnique Non-null Rows...")
    print("")
    print("\tNon-unique rows:",olddf.shape)
    print("\tUnique rows    :",df.shape)

    ### sort
    df = df.sort_values(["PrimaryInstitution","OrgName"])
    
    return df

# %% [markdown]
# # 0. prepare pop table: ElectedPositions, PositionHierarchy, OrgHierarchy

# %% [markdown]
# ### Elected Postions from PI-OrgName-Position

# %%
key_columns = ["PrimaryInstitution","OrgName"]
keyorg = ot[key_columns].drop_duplicates(keep="first")
keyorg.shape
# Out:
# (1742, 2)

# %%
keyorg = unique_non_null_rows(keyorg)
# Out:
# Unique Non-null Rows...
#
# 	Non-unique rows: (1742, 2)
# 	Unique rows    : (1742, 2)

# %%
jobs = careers[(careers["IsJob"]=="True") & (careers["CareerStartYear"].notna())]

# %%
key_columns2 = ["PrimaryInstitution","OrgName","Position"]
keyjobs = jobs[key_columns2].drop_duplicates(keep="first")
keyjobs.shape
# Out:
# (1954, 3)

# %%
keyjobs = unique_non_null_rows(keyjobs)
# Out:
# Unique Non-null Rows...
#
# 	Non-unique rows: (1954, 3)
# 	Unique rows    : (1902, 3)

# %%
pop_pre = keyorg.merge(keyjobs,how="outer",on=key_columns,indicator=True)
pop_pre.shape
# Out:
# (2626, 4)

# %%
merge_results(pop_pre)
# Out:
# Merge Results...
#
# 	shape     : (2626, 4)
# 	left_only : (724, 4)
# 	both      : (1902, 4)
# 	right_only: (0, 4)

# %%
pop_pre[pop_pre["_merge"]=="left_only"]
# Out:
#           PrimaryInstitution       OrgName Position     _merge
# 3     6.15공동선언실천남북공동위원회북측위원회         교직원분과      NaN  left_only
# 4     6.15공동선언실천남북공동위원회북측위원회         노동자분과      NaN  left_only
# 5     6.15공동선언실천남북공동위원회북측위원회       농업근로자분과      NaN  left_only
# 6     6.15공동선언실천남북공동위원회북측위원회        문학예술분과      NaN  left_only
# 7     6.15공동선언실천남북공동위원회북측위원회          보건분과      NaN  left_only
# ...                      ...           ...      ...        ...
# 2606                   호위사령부  호위총국_평양경비사령부      NaN  left_only
# 2613                  화학공업협회           NaN      NaN  left_only
# 2615                   활쏘기협회           NaN      NaN  left_only
# 2621     흥남가스화건설장함경남도지구계획위원회           NaN      NaN  left_only
# 2623                  희천기계공장           NaN      NaN  left_only
#
# [724 rows x 4 columns]

# %%
pop_pre["IsElected"]=np.nan
pop_pre["PositionRank"]=np.nan
pop_pre["OrgRank"]=np.nan

# %%
# populate PositionRank

# %%
# populate OrgRank

# %%
# pop_pre.to_excel(path_tables + "pi_org_pos.xlsx",index=False)

# %% [markdown]
# # 1. evaluate pop table: ElectedPositions, PositionHierarchy, OrgHierarchy

# %%
pop.shape
# Out:
# (2611, 7)

# %%
position_list = pop["Position"].drop_duplicates().to_frame()
type(position_list)
# Out:
# pandas.core.frame.DataFrame

# %%
position_list.sort_values("Position",inplace=True,ignore_index=True)
position_list
# Out:
#      Position
# 0        10국장
# 1       1등서기관
# 2        1부국장
# 3         1비서
# 4        2군단장
# ..        ...
# 290     후방총국장
# 291        후보
# 292      후보위원
# 293  후보위원(보선)
# 294       NaN
#
# [295 rows x 1 columns]

# %%
position_list.to_excel(path_tables + "position_list.xlsx",index=False)

# %% [markdown]
# ### PositionHierarchy

# %% [markdown]
# ### OrgTransition Hierarchy

# %% [markdown]
# # 1. deprecate old version

# %%
table_name = "leaderjobtransition"
table_name
# Out:
# 'leaderjobtransition'

# %%
filename_leaderjobtransition
# Out:
# 'leaderjobtransition.xlsx'

# %%
filename_deprecated = table_name + "_deprecated_"+str(today)+".xlsx"
filename_deprecated
# Out:
# 'leaderjobtransition_deprecated_2023-07-19.xlsx'

# %%
# deprecate old query
# oldtable = pd.read_excel(path_queries + filename_careers,dtype="str")
# oldtable.to_excel(path_queries + filename_deprecated,index=False)

# %% [markdown]
# # 2. select on careers: IsJob=True, remove elected positions

# %%
# get jobs from careers
jobs = careers[(careers["IsJob"]=="True") & (careers["CareerStartYear"].notna())]

# %%
jobs.shape
# Out:
# (6397, 12)

# %%
# remove elected positions
key_columns = ["PrimaryInstitution","OrgName","Position"]
jobs = jobs.merge(pop,on=key_columns,how="left")
jobs.shape
# Out:
# (6397, 16)

# %%
jobs.drop(columns=["_merge"],inplace=True)

# %%
jobs.head(5)
# Out:
#      CareerString CareerDateString_2022 IsJob MultipleSubstrings  \
# 0       노동성 상(유임)               1999.02  True                  1
# 3    인민무력부 작전국 국장                  1975  True                  1
# 11     ｢근로자｣사 부주필               1972.04  True                  1
# 12    ｢근로자｣사 책임주필               1974.12  True                  1
# 13  ｢민족화해협의회｣ 부회장               1999.10  True                  1
#
#    CareerStartYear CareerStartMonth CareerSubstring   OrgString  \
# 0             1999                2             NaN         노동성
# 3             1975              NaN             NaN   인민무력부 작전국
# 11            1972                4             NaN     ｢근로자｣사
# 12            1974               12             NaN     ｢근로자｣사
# 13            1999               10             NaN  ｢민족화해협의회｣
#
#    PrimaryInstitution            OrgName Position Notes IsElected  \
# 0                  내각                노동성        상   NaN       NaN
# 3                 정무원         인민무력부A_작전국       국장   NaN       NaN
# 11                노동당  당중앙위원회_선전선동부_근로자사      부주필   NaN       NaN
# 12                노동당  당중앙위원회_선전선동부_근로자사     책임주필   NaN       NaN
# 13            민족화해협의회                NaN      부회장   NaN       NaN
#
#    PositionRank OrgRank
# 0           NaN     NaN
# 3           NaN     NaN
# 11          NaN     NaN
# 12          NaN     NaN
# 13          NaN     NaN

# %%
jobs.IsElected.unique()
# Out:
# array([nan], dtype=object)

# %%
jobs = jobs[jobs["IsElected"].isna()]
jobs.shape
# Out:
# (4753, 15)

# %% [markdown]
# # 3. merge leadercareerlink & careers tables

# %%
lclink.head(2)
# Out:
#   LeaderID                CareerString CareerDateString_2022
# 0      리선권   개성공단 남북공동위원회 통행통신통관 분과위원회     2013.09 ~ 2014.01
# 1      조경철            故 김정일 국가장의위원회 위원               2011.12

# %%
# leader-job query - left join - includes IsJob True & False
key_columns = ["CareerString","CareerDateString_2022"]
lc = lclink.merge(jobs,on=key_columns,how="left",indicator=True)
lc.shape
# Out:
# (12883, 17)

# %%
merge_results(lc)
# Out:
# Merge Results...
#
# 	shape     : (12883, 17)
# 	left_only : (7968, 17)
# 	both      : (4915, 17)
# 	right_only: (0, 17)

# %%
# no "left-only" cases when IsJob=True
lc[(lc["IsJob"]=="True") & (lc["_merge"]=="left_only")]
# Out:
# Empty DataFrame
# Columns: [LeaderID, CareerString, CareerDateString_2022, IsJob, MultipleSubstrings, CareerStartYear, CareerStartMonth, CareerSubstring, OrgString, PrimaryInstitution, OrgName, Position, Notes, IsElected, PositionRank, OrgRank, _merge]
# Index: []

# %%
# leader-job query - inner join - only includes IsJob = True
key_columns = ["CareerString","CareerDateString_2022"]
lc = lclink.merge(jobs,on=key_columns,how="inner",indicator=False)
lc = lc.sort_values("LeaderID",ignore_index=True)
lc.shape
# Out:
# (4915, 16)

# %%
# instantiate CareerStartDate
lc["CareerStartDate"]=np.nan
lc.loc[lc["CareerStartMonth"].isna(),"CareerStartDate"] = lc[lc["CareerStartMonth"].isna()].apply(lambda x: str(x["CareerStartYear"]) + "00",axis=1)
lc.loc[(lc["CareerStartMonth"].notna()) & (lc.apply(lambda x: len(str(x["CareerStartMonth"])),axis=1)==2),"CareerStartDate"] = lc[(lc["CareerStartMonth"].notna()) & (lc.apply(lambda x: len(str(x["CareerStartMonth"])),axis=1)==2)].apply(lambda x: str(x["CareerStartYear"]) + str(x["CareerStartMonth"]),axis=1)
lc.loc[(lc["CareerStartMonth"].notna()) & (lc.apply(lambda x: len(str(x["CareerStartMonth"])),axis=1)==1),"CareerStartDate"] = lc[(lc["CareerStartMonth"].notna()) & (lc.apply(lambda x: len(str(x["CareerStartMonth"])),axis=1)==1)].apply(lambda x: str(x["CareerStartYear"]) + "0" + str(x["CareerStartMonth"]),axis=1)

# %%
lc.shape
# Out:
# (4915, 17)

# %%
pd.set_option('display.max_rows', None)

# %%
choigo = lc[lc["PrimaryInstitution"]=="최고인민회의"]
po_columns = ["PrimaryInstitution","OrgName","Position"]
choigo[po_columns].drop_duplicates(po_columns,keep="first").sort_values(po_columns)
# Out:
#      PrimaryInstitution               OrgName Position
# 256              최고인민회의               법안심의위원회       원장
# 980              최고인민회의                 상임위원회   명예부위원장
# 590              최고인민회의                 상임위원회       참사
# 1396             최고인민회의                 상임위원회     책임주필
# 1390             최고인민회의           상임위원회_민주조선사     책임주필
# 927              최고인민회의               외교분과위원회       고문
# 4683             최고인민회의                 외교위원회     자문위원
# 4392             최고인민회의                 중앙검찰소        장
# 660              최고인민회의                 중앙재판소   중앙재판소장
# 667              최고인민회의                 최고재판소   최고재판소장
# 2326             최고인민회의               통일정책위원회     책임참사
# 77               최고인민회의             평안남도인민위원회     내무국장
# 1648             최고인민회의             평안북도인민위원회    인민위원장
# 3628             최고인민회의              평양시인민위원회    건설총국장
# 1199             최고인민회의        평양시인민위원회_건설지도국       국장
# 4097             최고인민회의    평양시인민위원회_력포구역인민위원회      지도원
# 2968             최고인민회의  함경남도인민위원회_먼바다어업연합기업소     책임비서
# 4680             최고인민회의    함경북도인민위원회_청진시인민위원회    인민위원장
# 172              최고인민회의             황해북도인민위원회      위원장
# 1811             최고인민회의             황해북도인민위원회    인민위원장
# 4476             최고인민회의                   NaN        대
# 25               최고인민회의                   NaN      대위원

# %%
# remove 최고인민회의
# lc = lc[~((lc["PrimaryInstitution"]=="최고인민회의") & (lc["OrgName"].isna()))]
lc.shape
# Out:
# (4915, 17)

# %%
# remove 노동당, 당중앙위원회
# lc = lc[~((lc["PrimaryInstitution"]=="노동당") & (lc["OrgName"]=="당중앙위원회"))]
lc.shape
# Out:
# (4915, 17)

# %%
t = lc[(lc["LeaderID"]=="강관주") & (lc["CareerStartYear"].notna())]
t = t.drop_duplicates(["CareerStartYear","PrimaryInstitution","OrgName"],keep="first")
t = t.sort_values("CareerStartDate",ignore_index=True)
t.shape
# Out:
# (17, 17)

# %%
t
# Out:
#    LeaderID                    CareerString CareerDateString_2022 IsJob  \
# 0       강관주               1961. 체육과학연구소 연구원                   NaN  True
# 1       강관주  1973. 만경대예술단 섭외부 부부장, 당 문화부 과장                   NaN  True
# 2       강관주  1973. 만경대예술단 섭외부 부부장, 당 문화부 과장                   NaN  True
# 3       강관주             1975. 5 대외문화연락협회 국장                   NaN  True
# 4       강관주               1986. 당 조직지도부 부부장                   NaN  True
# 5       강관주      1988. 당 통일전선부 #조총련# 담당 부부장                   NaN  True
# 6       강관주      조선노동당 통일전선부 조선인총연합회 담당 부부장                  1988  True
# 7       강관주               조선노동당 통일전선부 제1부부장               1989.03  True
# 8       강관주                  조국평화통일위원회 부위원장               1990.08  True
# 9       강관주          1990. 8 조국평화통일위원회 부위원장                   NaN  True
# 10      강관주              1991. 9 보천보전자악단 고문                   NaN  True
# 11      강관주                  조선노동당 통일전선부 부장               1993.01  True
# 12      강관주              1993. 1 당 통일전선부 부장                   NaN  True
# 13      강관주           1993.10 해외동포원호위원회 위원장                   NaN  True
# 14      강관주     1997. 2 당 대외연락부(舊 사회문화부) 부장                   NaN  True
# 15      강관주         조선노동당 대외연락부(구 사회문화부) 부장               1997.02  True
# 16      강관주                2009. 내각 225국 국장                   NaN  True
#
#    MultipleSubstrings CareerStartYear CareerStartMonth CareerSubstring  \
# 0                   1            1961              NaN             NaN
# 1                   2            1973              NaN  만경대예술단 섭외부 부부장
# 2                   2            1973              NaN        당 문화부 과장
# 3                   1            1975                5             NaN
# 4                   1            1986              NaN             NaN
# 5                   1            1988              NaN             NaN
# 6                   1            1988              NaN             NaN
# 7                   1            1989                3             NaN
# 8                   1            1990                8             NaN
# 9                   1            1990                8             NaN
# 10                  1            1991                9             NaN
# 11                  1            1993                1             NaN
# 12                  1            1993                1             NaN
# 13                  1            1993               10             NaN
# 14                  1            1997                2             NaN
# 15                  1            1997                2             NaN
# 16                  1            2009              NaN             NaN
#
#           OrgString PrimaryInstitution             OrgName Position Notes  \
# 0           체육과학연구소              체육연구원             체육과학연구소      연구원   NaN
# 1        만경대예술단 섭외부           평양만경대예술단                 섭외부      부부장   NaN
# 2             당 문화부                노동당               문화예술부       과장   NaN
# 3          대외문화연락협회         조선대외문화연락협회                 NaN       국장   NaN
# 4         노동당 조직지도부                노동당        당중앙위원회_조직지도부      부부장   NaN
# 5   노동당 중앙위원회 통일전선부                노동당  당중앙위원회_통일전선부_문화교류국      부부장   NaN
# 6       조선노동당 통일전선부                노동당        당중앙위원회_통일전선부      부부장   NaN
# 7   조선노동당 통일전선부 제1부                노동당        당중앙위원회_통일전선부       부장   NaN
# 8         조국통일평화위원회                정무원           조국평화통일위원회     부위원장   NaN
# 9         조국평화통일위원회                 내각           조국평화통일위원회     부위원장   NaN
# 10          보전보전자악단            보천보전자악단                 NaN       고문   NaN
# 11      조선노동당 통일전선부                노동당        당중앙위원회_통일전선부       부장   NaN
# 12  노동당 중앙위원회 통일전선부                노동당  당중앙위원회_통일전선부_문화교류국       부장   NaN
# 13        해외동포원호위원회        조선해외동포원호위원회                 NaN      위원장   NaN
# 14  노동당 대외연락부 사회문화부                노동당  당중앙위원회_대외연락부_사회문화부       부장   NaN
# 15      조선노동당 대외연락부                노동당        당중앙위원회_대외연락부       부장   NaN
# 16          내각 225국                 내각                225국       국장   NaN
#
#    IsElected PositionRank OrgRank CareerStartDate
# 0        NaN          NaN     NaN          196100
# 1        NaN          NaN     NaN          197300
# 2        NaN          NaN     NaN          197300
# 3        NaN          NaN     NaN          197505
# 4        NaN          NaN     NaN          198600
# 5        NaN          NaN     NaN          198800
# 6        NaN          NaN     NaN          198800
# 7        NaN          NaN     NaN          198903
# 8        NaN          NaN     NaN          199008
# 9        NaN          NaN     NaN          199008
# 10       NaN          NaN     NaN          199109
# 11       NaN          NaN     NaN          199301
# 12       NaN          NaN     NaN          199301
# 13       NaN          NaN     NaN          199310
# 14       NaN          NaN     NaN          199702
# 15       NaN          NaN     NaN          199702
# 16       NaN          NaN     NaN          200900

# %%
tr = t.merge(t,on="LeaderID",how="inner",suffixes=("_1","_2"))

# %%
# sort based on CareerStartDates
tr = tr.sort_values(["CareerStartDate_1","CareerStartDate_2"])
tr.shape
# Out:
# (289, 33)

# %%
# drop keys where CareerStartDate_1 <= CareerStartDate_2
tr = tr[tr.apply(lambda x: x["CareerStartDate_1"] < x["CareerStartDate_2"],axis=1)]
tr.shape
# Out:
# (131, 33)

# %%
# smallest next startdate
dates = tr[["CareerStartDate_1","CareerStartDate_2"]]

# %%
dates
# Out:
#     CareerStartDate_1 CareerStartDate_2
# 1              196100            197300
# 2              196100            197300
# 3              196100            197505
# 4              196100            198600
# 5              196100            198800
# 6              196100            198800
# 7              196100            198903
# 8              196100            199008
# 9              196100            199008
# 10             196100            199109
# 11             196100            199301
# 12             196100            199301
# 13             196100            199310
# 14             196100            199702
# 15             196100            199702
# 16             196100            200900
# 20             197300            197505
# 37             197300            197505
# 21             197300            198600
# 38             197300            198600
# 22             197300            198800
# 23             197300            198800
# 39             197300            198800
# 40             197300            198800
# 24             197300            198903
# 41             197300            198903
# 25             197300            199008
# 26             197300            199008
# 42             197300            199008
# 43             197300            199008
# 27             197300            199109
# 44             197300            199109
# 28             197300            199301
# 29             197300            199301
# 45             197300            199301
# 46             197300            199301
# 30             197300            199310
# 47             197300            199310
# 31             197300            199702
# 32             197300            199702
# 48             197300            199702
# 49             197300            199702
# 33             197300            200900
# 50             197300            200900
# 55             197505            198600
# 56             197505            198800
# 57             197505            198800
# 58             197505            198903
# 59             197505            199008
# 60             197505            199008
# 61             197505            199109
# 62             197505            199301
# 63             197505            199301
# 64             197505            199310
# 65             197505            199702
# 66             197505            199702
# 67             197505            200900
# 73             198600            198800
# 74             198600            198800
# 75             198600            198903
# 76             198600            199008
# 77             198600            199008
# 78             198600            199109
# 79             198600            199301
# 80             198600            199301
# 81             198600            199310
# 82             198600            199702
# 83             198600            199702
# 84             198600            200900
# 92             198800            198903
# 109            198800            198903
# 93             198800            199008
# 94             198800            199008
# 110            198800            199008
# 111            198800            199008
# 95             198800            199109
# 112            198800            199109
# 96             198800            199301
# 97             198800            199301
# 113            198800            199301
# 114            198800            199301
# 98             198800            199310
# 115            198800            199310
# 99             198800            199702
# 100            198800            199702
# 116            198800            199702
# 117            198800            199702
# 101            198800            200900
# 118            198800            200900
# 127            198903            199008
# 128            198903            199008
# 129            198903            199109
# 130            198903            199301
# 131            198903            199301
# 132            198903            199310
# 133            198903            199702
# 134            198903            199702
# 135            198903            200900
# 146            199008            199109
# 163            199008            199109
# 147            199008            199301
# 148            199008            199301
# 164            199008            199301
# 165            199008            199301
# 149            199008            199310
# 166            199008            199310
# 150            199008            199702
# 151            199008            199702
# 167            199008            199702
# 168            199008            199702
# 152            199008            200900
# 169            199008            200900
# 181            199109            199301
# 182            199109            199301
# 183            199109            199310
# 184            199109            199702
# 185            199109            199702
# 186            199109            200900
# 200            199301            199310
# 217            199301            199310
# 201            199301            199702
# 202            199301            199702
# 218            199301            199702
# 219            199301            199702
# 203            199301            200900
# 220            199301            200900
# 235            199310            199702
# 236            199310            199702
# 237            199310            200900
# 254            199702            200900
# 271            199702            200900

# %%
mindate = dates.groupby("CareerStartDate_1",as_index=False).agg({"CareerStartDate_2":"min"})
mindate.shape
# Out:
# (11, 2)

# %%
mindate
# Out:
#    CareerStartDate_1 CareerStartDate_2
# 0             196100            197300
# 1             197300            197505
# 2             197505            198600
# 3             198600            198800
# 4             198800            198903
# 5             198903            199008
# 6             199008            199109
# 7             199109            199301
# 8             199301            199310
# 9             199310            199702
# 10            199702            200900

# %%
mindate.columns = ["CareerStartDate_1","CareerStartDate_2_min"]

# %%
tr2 = tr.merge(mindate,on="CareerStartDate_1",how="left")
tr2.shape
# Out:
# (131, 34)

# %%
tr3 = tr2[tr2.apply(lambda x: x["CareerStartDate_2"] == x["CareerStartDate_2_min"],axis=1)]
tr3.shape
# Out:
# (21, 34)

# %%
tr3
# Out:
#     LeaderID                  CareerString_1 CareerDateString_2022_1 IsJob_1  \
# 0        강관주               1961. 체육과학연구소 연구원                     NaN    True
# 1        강관주               1961. 체육과학연구소 연구원                     NaN    True
# 16       강관주  1973. 만경대예술단 섭외부 부부장, 당 문화부 과장                     NaN    True
# 17       강관주  1973. 만경대예술단 섭외부 부부장, 당 문화부 과장                     NaN    True
# 44       강관주             1975. 5 대외문화연락협회 국장                     NaN    True
# 57       강관주               1986. 당 조직지도부 부부장                     NaN    True
# 58       강관주               1986. 당 조직지도부 부부장                     NaN    True
# 69       강관주      1988. 당 통일전선부 #조총련# 담당 부부장                     NaN    True
# 70       강관주      조선노동당 통일전선부 조선인총연합회 담당 부부장                    1988    True
# 89       강관주               조선노동당 통일전선부 제1부부장                 1989.03    True
# 90       강관주               조선노동당 통일전선부 제1부부장                 1989.03    True
# 98       강관주                  조국평화통일위원회 부위원장                 1990.08    True
# 99       강관주          1990. 8 조국평화통일위원회 부위원장                     NaN    True
# 112      강관주              1991. 9 보천보전자악단 고문                     NaN    True
# 113      강관주              1991. 9 보천보전자악단 고문                     NaN    True
# 118      강관주                  조선노동당 통일전선부 부장                 1993.01    True
# 119      강관주              1993. 1 당 통일전선부 부장                     NaN    True
# 126      강관주           1993.10 해외동포원호위원회 위원장                     NaN    True
# 127      강관주           1993.10 해외동포원호위원회 위원장                     NaN    True
# 129      강관주     1997. 2 당 대외연락부(舊 사회문화부) 부장                     NaN    True
# 130      강관주         조선노동당 대외연락부(구 사회문화부) 부장                 1997.02    True
#
#     MultipleSubstrings_1 CareerStartYear_1 CareerStartMonth_1  \
# 0                      1              1961                NaN
# 1                      1              1961                NaN
# 16                     2              1973                NaN
# 17                     2              1973                NaN
# 44                     1              1975                  5
# 57                     1              1986                NaN
# 58                     1              1986                NaN
# 69                     1              1988                NaN
# 70                     1              1988                NaN
# 89                     1              1989                  3
# 90                     1              1989                  3
# 98                     1              1990                  8
# 99                     1              1990                  8
# 112                    1              1991                  9
# 113                    1              1991                  9
# 118                    1              1993                  1
# 119                    1              1993                  1
# 126                    1              1993                 10
# 127                    1              1993                 10
# 129                    1              1997                  2
# 130                    1              1997                  2
#
#     CareerSubstring_1      OrgString_1 PrimaryInstitution_1  ...  \
# 0                 NaN          체육과학연구소                체육연구원  ...
# 1                 NaN          체육과학연구소                체육연구원  ...
# 16     만경대예술단 섭외부 부부장       만경대예술단 섭외부             평양만경대예술단  ...
# 17           당 문화부 과장            당 문화부                  노동당  ...
# 44                NaN         대외문화연락협회           조선대외문화연락협회  ...
# 57                NaN        노동당 조직지도부                  노동당  ...
# 58                NaN        노동당 조직지도부                  노동당  ...
# 69                NaN  노동당 중앙위원회 통일전선부                  노동당  ...
# 70                NaN      조선노동당 통일전선부                  노동당  ...
# 89                NaN  조선노동당 통일전선부 제1부                  노동당  ...
# 90                NaN  조선노동당 통일전선부 제1부                  노동당  ...
# 98                NaN        조국통일평화위원회                  정무원  ...
# 99                NaN        조국평화통일위원회                   내각  ...
# 112               NaN          보전보전자악단              보천보전자악단  ...
# 113               NaN          보전보전자악단              보천보전자악단  ...
# 118               NaN      조선노동당 통일전선부                  노동당  ...
# 119               NaN  노동당 중앙위원회 통일전선부                  노동당  ...
# 126               NaN        해외동포원호위원회          조선해외동포원호위원회  ...
# 127               NaN        해외동포원호위원회          조선해외동포원호위원회  ...
# 129               NaN  노동당 대외연락부 사회문화부                  노동당  ...
# 130               NaN      조선노동당 대외연락부                  노동당  ...
#
#          OrgString_2 PrimaryInstitution_2           OrgName_2 Position_2  \
# 0         만경대예술단 섭외부             평양만경대예술단                 섭외부        부부장
# 1              당 문화부                  노동당               문화예술부         과장
# 16          대외문화연락협회           조선대외문화연락협회                 NaN         국장
# 17          대외문화연락협회           조선대외문화연락협회                 NaN         국장
# 44         노동당 조직지도부                  노동당        당중앙위원회_조직지도부        부부장
# 57   노동당 중앙위원회 통일전선부                  노동당  당중앙위원회_통일전선부_문화교류국        부부장
# 58       조선노동당 통일전선부                  노동당        당중앙위원회_통일전선부        부부장
# 69   조선노동당 통일전선부 제1부                  노동당        당중앙위원회_통일전선부         부장
# 70   조선노동당 통일전선부 제1부                  노동당        당중앙위원회_통일전선부         부장
# 89         조국통일평화위원회                  정무원           조국평화통일위원회       부위원장
# 90         조국평화통일위원회                   내각           조국평화통일위원회       부위원장
# 98           보전보전자악단              보천보전자악단                 NaN         고문
# 99           보전보전자악단              보천보전자악단                 NaN         고문
# 112      조선노동당 통일전선부                  노동당        당중앙위원회_통일전선부         부장
# 113  노동당 중앙위원회 통일전선부                  노동당  당중앙위원회_통일전선부_문화교류국         부장
# 118        해외동포원호위원회          조선해외동포원호위원회                 NaN        위원장
# 119        해외동포원호위원회          조선해외동포원호위원회                 NaN        위원장
# 126  노동당 대외연락부 사회문화부                  노동당  당중앙위원회_대외연락부_사회문화부         부장
# 127      조선노동당 대외연락부                  노동당        당중앙위원회_대외연락부         부장
# 129          내각 225국                   내각                225국         국장
# 130          내각 225국                   내각                225국         국장
#
#     Notes_2 IsElected_2 PositionRank_2 OrgRank_2 CareerStartDate_2  \
# 0       NaN         NaN            NaN       NaN            197300
# 1       NaN         NaN            NaN       NaN            197300
# 16      NaN         NaN            NaN       NaN            197505
# 17      NaN         NaN            NaN       NaN            197505
# 44      NaN         NaN            NaN       NaN            198600
# 57      NaN         NaN            NaN       NaN            198800
# 58      NaN         NaN            NaN       NaN            198800
# 69      NaN         NaN            NaN       NaN            198903
# 70      NaN         NaN            NaN       NaN            198903
# 89      NaN         NaN            NaN       NaN            199008
# 90      NaN         NaN            NaN       NaN            199008
# 98      NaN         NaN            NaN       NaN            199109
# 99      NaN         NaN            NaN       NaN            199109
# 112     NaN         NaN            NaN       NaN            199301
# 113     NaN         NaN            NaN       NaN            199301
# 118     NaN         NaN            NaN       NaN            199310
# 119     NaN         NaN            NaN       NaN            199310
# 126     NaN         NaN            NaN       NaN            199702
# 127     NaN         NaN            NaN       NaN            199702
# 129     NaN         NaN            NaN       NaN            200900
# 130     NaN         NaN            NaN       NaN            200900
#
#     CareerStartDate_2_min
# 0                  197300
# 1                  197300
# 16                 197505
# 17                 197505
# 44                 198600
# 57                 198800
# 58                 198800
# 69                 198903
# 70                 198903
# 89                 199008
# 90                 199008
# 98                 199109
# 99                 199109
# 112                199301
# 113                199301
# 118                199310
# 119                199310
# 126                199702
# 127                199702
# 129                200900
# 130                200900
#
# [21 rows x 34 columns]

# %%
some_columns = ["LeaderID","CareerStartDate_1","PrimaryInstitution_1","OrgName_1","Position_1","CareerStartDate_2","PrimaryInstitution_2","OrgName_2","Position_2"]
tr3[some_columns]
# Out:
#     LeaderID CareerStartDate_1 PrimaryInstitution_1           OrgName_1  \
# 0        강관주            196100                체육연구원             체육과학연구소
# 1        강관주            196100                체육연구원             체육과학연구소
# 16       강관주            197300             평양만경대예술단                 섭외부
# 17       강관주            197300                  노동당               문화예술부
# 44       강관주            197505           조선대외문화연락협회                 NaN
# 57       강관주            198600                  노동당        당중앙위원회_조직지도부
# 58       강관주            198600                  노동당        당중앙위원회_조직지도부
# 69       강관주            198800                  노동당  당중앙위원회_통일전선부_문화교류국
# 70       강관주            198800                  노동당        당중앙위원회_통일전선부
# 89       강관주            198903                  노동당        당중앙위원회_통일전선부
# 90       강관주            198903                  노동당        당중앙위원회_통일전선부
# 98       강관주            199008                  정무원           조국평화통일위원회
# 99       강관주            199008                   내각           조국평화통일위원회
# 112      강관주            199109              보천보전자악단                 NaN
# 113      강관주            199109              보천보전자악단                 NaN
# 118      강관주            199301                  노동당        당중앙위원회_통일전선부
# 119      강관주            199301                  노동당  당중앙위원회_통일전선부_문화교류국
# 126      강관주            199310          조선해외동포원호위원회                 NaN
# 127      강관주            199310          조선해외동포원호위원회                 NaN
# 129      강관주            199702                  노동당  당중앙위원회_대외연락부_사회문화부
# 130      강관주            199702                  노동당        당중앙위원회_대외연락부
#
#     Position_1 CareerStartDate_2 PrimaryInstitution_2           OrgName_2  \
# 0          연구원            197300             평양만경대예술단                 섭외부
# 1          연구원            197300                  노동당               문화예술부
# 16         부부장            197505           조선대외문화연락협회                 NaN
# 17          과장            197505           조선대외문화연락협회                 NaN
# 44          국장            198600                  노동당        당중앙위원회_조직지도부
# 57         부부장            198800                  노동당  당중앙위원회_통일전선부_문화교류국
# 58         부부장            198800                  노동당        당중앙위원회_통일전선부
# 69         부부장            198903                  노동당        당중앙위원회_통일전선부
# 70         부부장            198903                  노동당        당중앙위원회_통일전선부
# 89          부장            199008                  정무원           조국평화통일위원회
# 90          부장            199008                   내각           조국평화통일위원회
# 98        부위원장            199109              보천보전자악단                 NaN
# 99        부위원장            199109              보천보전자악단                 NaN
# 112         고문            199301                  노동당        당중앙위원회_통일전선부
# 113         고문            199301                  노동당  당중앙위원회_통일전선부_문화교류국
# 118         부장            199310          조선해외동포원호위원회                 NaN
# 119         부장            199310          조선해외동포원호위원회                 NaN
# 126        위원장            199702                  노동당  당중앙위원회_대외연락부_사회문화부
# 127        위원장            199702                  노동당        당중앙위원회_대외연락부
# 129         부장            200900                   내각                225국
# 130         부장            200900                   내각                225국
#
#     Position_2
# 0          부부장
# 1           과장
# 16          국장
# 17          국장
# 44         부부장
# 57         부부장
# 58         부부장
# 69          부장
# 70          부장
# 89        부위원장
# 90        부위원장
# 98          고문
# 99          고문
# 112         부장
# 113         부장
# 118        위원장
# 119        위원장
# 126         부장
# 127         부장
# 129         국장
# 130         국장

# %% [markdown]
# # 3. export new query

# %%
# refresh leaderjobtransition with new data
ljt_new.to_excel(path_tables + filename_careers,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [56], line 2
#       1 # refresh leaderjobtransition with new data
# ----> 2 ljt_new.to_excel(path_tables + filename_careers,index=False)
#
# NameError: name 'ljt_new' is not defined
