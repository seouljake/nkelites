# %% [markdown]
# # libraries & global vars

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)

# %% [markdown]
# # io orgtree & org paths

# %%
path_orgtree = "C:/Users/seoul/Dropbox/00 technical/github/nkelites/data/combined data/combined data - 1 cleaning/cleaning step 2 - career/2.4 orgtree/"

# %%
filein_orgtree = "orgtree_3.xlsx"

# %%
fileout_orgtree = "orgtree_4_1_jeongsu.xlsx"

# %%
path_joborglink = "C:/Users/seoul/Dropbox/00 technical/github/nkelites/data/combined data/combined data - 1 cleaning/cleaning step 2 - career/2.3 joborglink/"

# %%
# right: update existing keys in orgtree
filein_joborglink_right = "joborglink_6_1_inorgtree_right_tocode_1_jeongsu.xlsx"

# %%
# left1: add to orgtree
filein_joborglink_left1 = "joborglink_6_1_left_2_add_to_orgtree.xlsx"

# %%
# left2: update jol & orgtree
filein_joborglink_left2 = "joborglink_6_1_left_2_tocode_jeongsu_x.xlsx"

# %%
# both: update jol & orgtree
filein_joborglink_both = "joborglink_6_1_inorgtree_both_tocode_1_jeongsu_x.xlsx"

# %%
fileout_joborglink = "joborglink_6_2.xlsx"

# %%
fileout_joborglink_2 = "joborglink_7_1.xlsx"

# %%
fileout_joborglink_3 = "joborglink_7_2.xlsx"

# %% [markdown]
# # import orgtree

# %%
orgtree = pd.read_excel(path_orgtree+filein_orgtree)

# %%
orgtree.shape
# Out:
# (1162, 8)

# %%
orgtree[0:10]
# Out:
#    InsideGov      PrimaryInstitution  OrgName ImmediateSuperiorOrg  \
# 0      False  6.15공동선언실천남북공동위원회북측위원회    교직원분과                  NaN
# 1      False  6.15공동선언실천남북공동위원회북측위원회    노동자분과                  NaN
# 2      False  6.15공동선언실천남북공동위원회북측위원회  농업근로자분과                  NaN
# 3      False  6.15공동선언실천남북공동위원회북측위원회   문학예술분과                  NaN
# 4      False  6.15공동선언실천남북공동위원회북측위원회     보건분과                  NaN
# 5      False  6.15공동선언실천남북공동위원회북측위원회      사무국                  NaN
# 6      False  6.15공동선언실천남북공동위원회북측위원회     언론분과                  NaN
# 7      False  6.15공동선언실천남북공동위원회북측위원회     여성분과                  NaN
# 8      False  6.15공동선언실천남북공동위원회북측위원회     종교분과                  NaN
# 9      False  6.15공동선언실천남북공동위원회북측위원회   청년학생분과                  NaN
#
#    SupervisesParent LinkToCurrent_PrimaryInstitution LinkToCurrent_OrgName  \
# 0               NaN                          Current               Current
# 1               NaN                          Current               Current
# 2               NaN                          Current               Current
# 3               NaN                          Current               Current
# 4               NaN                          Current               Current
# 5               NaN                          Current               Current
# 6               NaN                          Current               Current
# 7               NaN                          Current               Current
# 8               NaN                          Current               Current
# 9               NaN                          Current               Current
#
#     비고
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN

# %%
# use orgtree_columns to select orgtree columns from merged files below
orgtree_columns = list(orgtree.columns)
orgtree_columns
# Out:
# ['InsideGov',
#  'PrimaryInstitution',
#  'OrgName',
#  'ImmediateSuperiorOrg',
#  'SupervisesParent',
#  'LinkToCurrent_PrimaryInstitution',
#  'LinkToCurrent_OrgName',
#  '비고']

# %%
orgtree.shape
# Out:
# (1162, 8)

# %%
orgtree.dropna()
orgtree.shape
# Out:
# (1162, 8)

# %%
orgtree[orgtree.duplicated()]
# Out:
# Empty DataFrame
# Columns: [InsideGov, PrimaryInstitution, OrgName, ImmediateSuperiorOrg, SupervisesParent, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName, 비고]
# Index: []

# %%
orgtree[orgtree.duplicated(["PrimaryInstitution","OrgName"])]
# Out:
# Empty DataFrame
# Columns: [InsideGov, PrimaryInstitution, OrgName, ImmediateSuperiorOrg, SupervisesParent, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName, 비고]
# Index: []

# %%
orgtree[orgtree.OrgName=="2군단"]
# Out:
#      InsideGov PrimaryInstitution OrgName ImmediateSuperiorOrg  \
# 598       True            인민군총참모부     2군단                  NaN
# 965       True               총참모부     2군단                  NaN
#
#      SupervisesParent LinkToCurrent_PrimaryInstitution LinkToCurrent_OrgName  \
# 598               NaN                             총참모부                   2군단
# 965               NaN                          Current               Current
#
#       비고
# 598  NaN
# 965  NaN

# %% [markdown]
# # right: prep joborglink_right

# %%
# joborglink_dtypes = {"OrgString":"str","_merged":"str","InOrgTree":"str","InsideGov":"str","PrimaryInstitution":"str","OrgName":"str","Orgtree_NeedToModify_PI":"str","Orgtree_NeedToModify_Orgname":"str","LinkToCurrent_PrimaryInstitution":"str","LinkToCurrent_OrgName":"str","Modify_LinkToCurrent_PrimaryInstitution":"str","Modify_LinkToCurrent_OrgName":"str","비고":"str"}
# joborglink = pd.read_excel(path_joborglink+filein_joborglink_right,dtype=joborglink_dtypes)
joborglink_right = pd.read_excel(path_joborglink+filein_joborglink_right)
joborglink_right.shape
# Out:
# (843, 14)

# %%
# list(joborglink_dtypes.keys())

# %%
joborglink_right.columns
# Out:
# Index(['OrgString', 'Notes', '_merged', 'InOrgTree', 'InsideGov',
#        'PrimaryInstitution', 'OrgName', 'Orgtree_NeedToModify_PI',
#        'Orgtree_NeedToModify_Orgname', 'LinkToCurrent_PrimaryInstitution',
#        'LinkToCurrent_OrgName', 'Modify_LinkToCurrent_PrimaryInstitution',
#        'Modify_LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
joborglink_right.dropna()
joborglink_right.shape
# Out:
# (843, 14)

# %%
joborglink_right[joborglink_right.duplicated()]
# Out:
# Empty DataFrame
# Columns: [OrgString, Notes, _merged, InOrgTree, InsideGov, PrimaryInstitution, OrgName, Orgtree_NeedToModify_PI, Orgtree_NeedToModify_Orgname, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName, Modify_LinkToCurrent_PrimaryInstitution, Modify_LinkToCurrent_OrgName, 비고]
# Index: []

# %%
joborglink_right = joborglink_right.drop_duplicates()
joborglink_right.shape
# Out:
# (843, 14)

# %%
# check that the the joborglink primary key is unique: ["OrgString","PrimaryInstitution","OrgName"] 
joborglink_right[joborglink_right.duplicated(["OrgString","PrimaryInstitution","OrgName"])]
# Out:
# Empty DataFrame
# Columns: [OrgString, Notes, _merged, InOrgTree, InsideGov, PrimaryInstitution, OrgName, Orgtree_NeedToModify_PI, Orgtree_NeedToModify_Orgname, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName, Modify_LinkToCurrent_PrimaryInstitution, Modify_LinkToCurrent_OrgName, 비고]
# Index: []

# %%
columns_processing = ["PrimaryInstitution","OrgName","Orgtree_NeedToModify_PI","Orgtree_NeedToModify_Orgname",
                     "LinkToCurrent_PrimaryInstitution","LinkToCurrent_OrgName",
                     "Modify_LinkToCurrent_PrimaryInstitution","Modify_LinkToCurrent_OrgName"]
jol_right_process = joborglink_right[columns_processing]
jol_right_process.shape
# Out:
# (843, 8)

# %%
# select rows in which at least one change is recommended
jol_right_process = jol_right_process[
    jol_right_process.Orgtree_NeedToModify_PI.notna() | 
    jol_right_process.Orgtree_NeedToModify_Orgname.notna() |
    jol_right_process.Modify_LinkToCurrent_PrimaryInstitution.notna() | 
    jol_right_process.Modify_LinkToCurrent_OrgName.notna()
]
jol_right_process.shape
# Out:
# (422, 8)

# %%
jol_right_process[0:2]
# Out:
#    PrimaryInstitution  OrgName Orgtree_NeedToModify_PI  \
# 39              국무위원회  국방성_장비국                   국무위원회
# 40              국무위원회  국방성_적공국                   국무위원회
#
#    Orgtree_NeedToModify_Orgname LinkToCurrent_PrimaryInstitution  \
# 39                 국방성_참모부_장비총국                          Current
# 40                  국방성_참모부_적공국                          Current
#
#    LinkToCurrent_OrgName Modify_LinkToCurrent_PrimaryInstitution  \
# 39               Current                                     NaN
# 40               Current                                     NaN
#
#    Modify_LinkToCurrent_OrgName
# 39                          NaN
# 40                          NaN

# %%
# Check 1: NAs
jol_right_process.dropna()
jol_right_process.shape
# Out:
# (422, 8)

# %%
# Check 2: duplicate rows
jol_right_process[jol_right_process.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PrimaryInstitution, OrgName, Orgtree_NeedToModify_PI, Orgtree_NeedToModify_Orgname, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName, Modify_LinkToCurrent_PrimaryInstitution, Modify_LinkToCurrent_OrgName]
# Index: []

# %%
# Check 3: duplicate primary keys
jol_right_process[jol_right_process.duplicated(["PrimaryInstitution","OrgName"])]
# Out:
# Empty DataFrame
# Columns: [PrimaryInstitution, OrgName, Orgtree_NeedToModify_PI, Orgtree_NeedToModify_Orgname, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName, Modify_LinkToCurrent_PrimaryInstitution, Modify_LinkToCurrent_OrgName]
# Index: []

# %% [markdown]
# # right: update orgtree using joborglink_right edits

# %%
# modifications to OrgTree.PrimaryInstitution
jol_right_process[jol_right_process.Orgtree_NeedToModify_PI.notna()].shape
# Out:
# (422, 8)

# %%
# modifications to OrgTree.OrgName
jol_right_process[jol_right_process.Orgtree_NeedToModify_Orgname.notna()].shape
# Out:
# (395, 8)

# %%
# modifications to OrgTree.LinkToCurrent_PrimaryInstitution
jol_right_process[jol_right_process.Modify_LinkToCurrent_PrimaryInstitution.notna()].shape
# Out:
# (45, 8)

# %%
# modifications to OrgTree.LinkToCurrent_OrgName
jol_right_process[jol_right_process.Modify_LinkToCurrent_OrgName.notna()].shape
# Out:
# (45, 8)

# %%
# merge and update
merged = orgtree.merge(jol_right_process,how="left",on=["PrimaryInstitution","OrgName"],suffixes=("","_y"),indicator=True)

# %%
orgtree.shape
# Out:
# (1162, 8)

# %%
# merged rows > orgtree rows
merged.shape
# Out:
# (1162, 15)

# %%
merged["_merge"].unique()
# Out:
# ['left_only', 'both']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
merged[merged["_merge"]=="left_only"].shape
# Out:
# (740, 15)

# %%
merged[merged["_merge"]=="right_only"].shape
# Out:
# (0, 15)

# %%
merged[merged["_merge"]=="both"].shape
# Out:
# (422, 15)

# %%
merged[merged["_merge"]=="left_only"][0:2]
# Out:
#    InsideGov      PrimaryInstitution OrgName ImmediateSuperiorOrg  \
# 0      False  6.15공동선언실천남북공동위원회북측위원회   교직원분과                  NaN
# 1      False  6.15공동선언실천남북공동위원회북측위원회   노동자분과                  NaN
#
#    SupervisesParent LinkToCurrent_PrimaryInstitution LinkToCurrent_OrgName  \
# 0               NaN                          Current               Current
# 1               NaN                          Current               Current
#
#     비고 Orgtree_NeedToModify_PI Orgtree_NeedToModify_Orgname  \
# 0  NaN                     NaN                          NaN
# 1  NaN                     NaN                          NaN
#
#   LinkToCurrent_PrimaryInstitution_y LinkToCurrent_OrgName_y  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
#
#   Modify_LinkToCurrent_PrimaryInstitution Modify_LinkToCurrent_OrgName  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
#
#       _merge
# 0  left_only
# 1  left_only

# %%
# verify no duplicates
merged.loc[merged.duplicated(["PrimaryInstitution","OrgName"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [InsideGov, PrimaryInstitution, OrgName, ImmediateSuperiorOrg, SupervisesParent, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName, 비고, Orgtree_NeedToModify_PI, Orgtree_NeedToModify_Orgname, LinkToCurrent_PrimaryInstitution_y, LinkToCurrent_OrgName_y, Modify_LinkToCurrent_PrimaryInstitution, Modify_LinkToCurrent_OrgName, _merge]
# Index: []

# %%
# replace PrimaryInstitution
merged.loc[merged.Orgtree_NeedToModify_PI.notna(),"PrimaryInstitution"] = merged.loc[merged.Orgtree_NeedToModify_PI.notna(),"Orgtree_NeedToModify_PI"]

# %%
# replace OrgName
merged.loc[merged.Orgtree_NeedToModify_Orgname.notna(),"OrgName"] = merged.loc[merged.Orgtree_NeedToModify_Orgname.notna(),"Orgtree_NeedToModify_Orgname"]

# %%
# replace LinkToCurrent_PrimaryInstitution
merged.loc[merged.Modify_LinkToCurrent_PrimaryInstitution.notna(),"LinkToCurrent_PrimaryInstitution"] = merged.loc[merged.Modify_LinkToCurrent_PrimaryInstitution.notna(),"Modify_LinkToCurrent_PrimaryInstitution"]

# %%
# replace LinkToCurrent_OrgName
merged.loc[merged.Modify_LinkToCurrent_OrgName.notna(),"LinkToCurrent_OrgName"] = merged.loc[merged.Modify_LinkToCurrent_OrgName.notna(),"Modify_LinkToCurrent_OrgName"]

# %%
merged[merged.Modify_LinkToCurrent_OrgName.notna()][1:3]
# Out:
#      InsideGov PrimaryInstitution                     OrgName  \
# 235       True                 내각           외무성_아시아2국_싱가포르대사관
# 241       True                 내각  외무성_아프리카-라틴아메리카-아랍국_우간다대사관
#
#     ImmediateSuperiorOrg  SupervisesParent LinkToCurrent_PrimaryInstitution  \
# 235               외무성_X국               NaN                          Current
# 241               외무성_X국               NaN                          Current
#
#     LinkToCurrent_OrgName   비고 Orgtree_NeedToModify_PI  \
# 235               Current  NaN                      내각
# 241               Current  NaN                      내각
#
#     Orgtree_NeedToModify_Orgname LinkToCurrent_PrimaryInstitution_y  \
# 235            외무성_아시아2국_싱가포르대사관                                 내각
# 241   외무성_아프리카-라틴아메리카-아랍국_우간다대사관                                 내각
#
#         LinkToCurrent_OrgName_y Modify_LinkToCurrent_PrimaryInstitution  \
# 235           외무성_아시아2국_싱가포르대사관                                 Current
# 241  외무성_아프리카-라틴아메리카-아랍국_우간다대사관                                 Current
#
#     Modify_LinkToCurrent_OrgName _merge
# 235                      Current   both
# 241                      Current   both

# %%
# double check the changes, before & after, both files
merged.shape
# Out:
# (1162, 15)

# %%
# Check 1: NAs
merged.dropna()
merged.shape
# Out:
# (1162, 15)

# %%
# Check 2: duplicate rows
merged[merged.duplicated()].shape
# Out:
# (129, 15)

# %%
### 129 rows in joborglink_right for which 2+ incorrect key existed in orgtree, whose rows were otherwise identical
### We can remove these duplicates.

# %%
merged = merged.drop_duplicates()
merged.shape
# Out:
# (1033, 15)

# %%
# Check 3: duplicate primary keys
merged[merged.duplicated(["PrimaryInstitution","OrgName"],keep=False)].shape
# Out:
#
# 1052                         Current
# 1059                         Current
# 1063                         Current
# 1064                         Current
# 1094                   Please_Revise
# 1102                   Please_Revise
# 1112                   Please_Revise
# 1115                   Please_Revise
# 1116                   Please_Revise
# 1117                   Please_Revise
# 1131                   Please_Revise
# 1132                         Current
# 1133                            육해운성
# 1134                         Current
# 1135                         Current
# 1136                         Current
# 1137                   Please_Revise
# 1138                         Current
# 1139                         Current
# 1140                         Current
# 1141                         Current
# 1142                         Current
# 1144                         평양건설위원회
# 1145                             NAN
# 1146                   Please_Revise
# 1147                         Current
# 1148                         Current
# 1149                         Current
# 1151                         Current
# 1152                           석탄공업성
# 1153                         Current
# 1154                         Current
# 1156                         Current
# 1157                             체육성
# 1158                   Please_Revise
# 1159                   Please_Revise
# 1160                   Please_Revise
# 1161                   Please_Revise
#
#                                                      비고  \
# 17                                                  NaN
# 20                                                  NaN
# 43                                                  NaN
# 44                                               제258부대
# 91    조선인민군 방첩 및 군 감찰기관 (보위국 혹은 보위사령부로 불림)\n- 총정치국 산...
# 92                                                  NaN
# 112                                                 NaN
# 113                                                 NaN
# 116                                                 NaN
# 120                                                 NaN
# 121                                                 NaN
# 126                                                 NaN
# 131                                                 NaN
# 132                                                 NaN
# 137                                                 NaN
# 138                                                 NaN
# 139                                                 NaN
# 146                                                 NaN
# 148                                                 NaN
# 207                                                 NaN
# 210                                                 NaN
# 213                                                 NaN
# 214                                                 NaN
# 217                                                 NaN
# 218                                                 NaN
# 219                                                 NaN
# 220                                                 NaN
# 221                                                 NaN
# 222                                                 NaN
# 223                                                 NaN
# 224                                                 NaN
# 229                                                 NaN
# 230                                                 NaN
# 231                                                 NaN
# 232                                                 NaN
# 233                                                 NaN
# 234                                                 NaN
# 235                                                 NaN
# 236                                                 NaN
# 237                                                 NaN
# 238                                                 NaN
# 239                                                 NaN
# 240                                                 NaN
# 241                                                 NaN
# 242                                                 NaN
# 243                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 246                                                 NaN
# 248                                                 NaN
# 249                                                 NaN
# 250                                                 NaN
# 251                                                 NaN
# 252                                                 NaN
# 259                                          *org4 확인필요
# 262                                                 NaN
# 265                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# 272                                                 NaN
# 277                                                 NaN
# 284                                                 NaN
# 285   참고 : https://www.mofa.go.kr/www/wpge/m_4178/co...
# 286                                                 NaN
# 287                                                 NaN
# 288                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# 293                                                 NaN
# 294                                                 NaN
# 299                                                 NaN
# 300                                                 NaN
# 301                                                 NaN
# 302                                                 NaN
# 304                                          *org4 확인필요
# 306                                                 NaN
# 307                                          *org4 확인필요
# 308                                          *org4 확인필요
# 310                                                 NaN
# 311                                          *org4 확인필요
# 313                                          *org4 확인필요
# 314                                                 NaN
# 323                                                 NaN
# 324                                                 NaN
# 335                                                 NaN
# 336                                                 NaN
# 339                                                 NaN
# 346                                                 NaN
# 351                                                 NaN
# 361                                                 NaN
# 377                                                 NaN
# 409                                                 NaN
# 421                                                 NaN
# 428                                                 NaN
# 435                                                 NaN
# 461                                                 NaN
# 469                                                 NaN
# 470                                                 NaN
# 483                                                 NaN
# 484                                                 NaN
# 495                                                 NaN
# 511                                                 NaN
# 515                                                 NaN
# 516                                                 NaN
# 531                                                 NaN
# 542                                        인민군에 속하는 당조직
# 561                                                 NaN
# 595                                                 NaN
# 597                                                 NaN
# 598                                                 NaN
# 599                                                 NaN
# 600                                                 NaN
# 603                                                 NaN
# 604                                                 NaN
# 606                                                 NaN
# 607                                                 NaN
# 608                                                 NaN
# 611                                                 NaN
# 612                                                 NaN
# 703                                                 NaN
# 781                                                 NaN
# 808                                                 NaN
# 829                                                 NaN
# 860                                                 NaN
# 869                                                 NaN
# 887                                                 NaN
# 891                                                 NaN
# 892                                                 NaN
# 894                                                 NaN
# 899                                                 NaN
# 903                                                 NaN
# 917                                                 NaN
# 922                                                 NaN
# 938                                                 NaN
# 943                                                 NaN
# 957                                                 NaN
# 965                                                 NaN
# 966                                                 NaN
# 967                                                 NaN
# 972                                                 NaN
# 976                                                 NaN
# 977                                                 NaN
# 982                                                 NaN
# 983                                                 NaN
# 988                                                 NaN
# 994                                                 NaN
# 1000                                                NaN
# 1009                                                NaN
# 1010                                                NaN
# 1014                                                NaN
# 1015                                                NaN
# 1016                                               민경대대
# 1034                                                NaN
# 1035                                                NaN
# 1036                                                NaN
# 1052                                                NaN
# 1059                                                NaN
# 1063                                       항공 및 반항공군 담당
# 1064                              해군부대, 동해사령부, 서해사령부 담당
# 1094                                                NaN
# 1102                                                NaN
# 1112                                                NaN
# 1115                                                NaN
# 1116                                                NaN
# 1117                                                NaN
# 1131                                                NaN
# 1132                                                NaN
# 1133                                                NaN
# 1134                                                NaN
# 1135                                                NaN
# 1136                                                NaN
# 1137                                                NaN
# 1138                                                NaN
# 1139                                                NaN
# 1140                                                NaN
# 1141                                                NaN
# 1142                                                NaN
# 1144                                                NaN
# 1145                                                NaN
# 1146                                                NaN
# 1147                                                NaN
# 1148                                                NaN
# 1149                                                NaN
# 1151                                                NaN
# 1152                                                NaN
# 1153                                                NaN
# 1154                                                NaN
# ...
# 290                                      NaN                          NaN
# 292                                      NaN                          NaN
# 293                                      NaN                          NaN
# 294                                      NaN                          NaN
# 299                                      NaN                          NaN
# 300                                      NaN                          NaN
# 301                                      NaN                          NaN
# 302                                      NaN                          NaN
# 304                                      NaN                          NaN
# 306                                      NaN                          NaN
# 307                                      NaN                          NaN
# 308                                      NaN                          NaN
# 310                                      NaN                          NaN
# 311                                      NaN                          NaN
# 313                                      NaN                          NaN
# 314                                      NaN                          NaN
# 323                                      NaN                          NaN
# 324                                      NaN                          NaN
# 335                                      NaN                          NaN
# 336                                      NaN                          NaN
# 339                                      NaN                          NaN
# 346                                      NaN                          NaN
# 351                                      NaN                          NaN
# 361                                      NaN                          NaN
# 377                                      NaN                          NaN
# 409                                      NaN                          NaN
# 421                                  Current                      Current
# 428                                  Current                      Current
# 435                                  Current                      Current
# 461                                  Current                      Current
# 469                                      NaN                          NaN
# 470                                      NaN                          NaN
# 483                                      NaN                          NaN
# 484                                      NaN                          NaN
# 495                                      NaN                          NaN
# 511                                      NaN                          NaN
# 515                                      NaN                          NaN
# 516                                      NaN                          NaN
# 531                                      NaN                          NaN
# 542                                      NaN                          NaN
# 561                                      NaN                          NaN
# 595                                      NaN                          NaN
# 597                                      NaN                          NaN
# 598                                  Current                      Current
# 599                                  Current                      Current
# 600                                      NaN                          NaN
# 603                                  Current                      Current
# 604                                  Current                      Current
# 606                                  Current                      Current
# 607                                  Current                      Current
# 608                                  Current                      Current
# 611                                      NaN                          NaN
# 612                                      NaN                          NaN
# 703                                      NaN                          NaN
# 781                                      NaN                          NaN
# 808                                      NaN                          NaN
# 829                                      NaN                          NaN
# 860                                      NaN                          NaN
# 869                                      NaN                          NaN
# 887                                      NaN                          NaN
# 891                                      NaN                          NaN
# 892                                      NaN                          NaN
# 894                                      NaN                          NaN
# 899                                      NaN                          NaN
# 903                                      NaN                          NaN
# 917                                      NaN                          NaN
# 922                                      NaN                          NaN
# 938                                      NaN                          NaN
# 943                                      NaN                          NaN
# 957                                      NaN                          NaN
# 965                                      NaN                          NaN
# 966                                      NaN                          NaN
# 967                                      NaN                          NaN
# 972                                      NaN                          NaN
# 976                                      NaN                          NaN
# 977                                      NaN                          NaN
# 982                                      NaN                          NaN
# 983                                      NaN                          NaN
# 988                                      NaN                          NaN
# 994                                      NaN                          NaN
# 1000                                     NaN                          NaN
# 1009                                     NaN                          NaN
# 1010                                     NaN                          NaN
# 1014                                     NaN                          NaN
# 1015                                     NaN                          NaN
# 1016                                     NaN                          NaN
# 1034                                     NaN                          NaN
# 1035                                     NaN                          NaN
# 1036                                     NaN                          NaN
# 1052                                     NaN                          NaN
# 1059                                     NaN                          NaN
# 1063                                     NaN                          NaN
# 1064                                     NaN                          NaN
# 1094                                     NaN                          NaN
# 1102                                     NaN                          NaN
# 1112                                     NaN                          NaN
# 1115                                     NaN                          NaN
# 1116                                     NaN                          NaN
# 1117                                     NaN                          NaN
# 1131                                     NaN                          NaN
# 1132                                 Current                      Current
# 1133                                     NaN                          NaN
# 1134                                 Current                      Current
# 1135                                 Current                      Current
# 1136                                 Current                      Current
# 1137                                     NaN                          NaN
# 1138                                 Current                      Current
# 1139                                 Current                      Current
# 1140                                 Current                      Current
# 1141                                 Current                      Current
# 1142                                 Current                      Current
# 1144                                     NaN                          NaN
# 1145                                     NAN                          NAN
# 1146                                     NaN                          NaN
# 1147                                 Current                      Current
# 1148                                 Current                      Current
# 1149                                 Current                      Current
# 1151                                 Current                      Current
# 1152                                     NaN                          NaN
# 1153                                 Current                      Current
# 1154                                 Current                      Current
# 1156                                 Current                      Current
# 1157                                     NaN                          NaN
# 1158                                     NaN                          NaN
# 1159                                     NaN                          NaN
# 1160                                     NaN                          NaN
# 1161                                     NaN                          NaN
#
#          _merge  DuplicateKey
# 17    left_only          True
# 20         both          True
# 43         both          True
# 44         both          True
# 91         both          True
# 92    left_only          True
# 112        both          True
# 113        both          True
# 116   left_only          True
# 120   left_only          True
# 121   left_only          True
# 126   left_only          True
# 131   left_only          True
# 132   left_only          True
# 137        both          True
# 138   left_only          True
# 139   left_only          True
# 146   left_only          True
# 148   left_only          True
# 207   left_only          True
# 210   left_only          True
# 213        both          True
# 214        both          True
# 217   left_only          True
# 218        both          True
# 219        both          True
# 220        both          True
# 221        both          True
# 222        both          True
# 223        both          True
# 224        both          True
# 229        both          True
# 230        both          True
# 231        both          True
# 232        both          True
# 233        both          True
# 234        both          True
# 235        both          True
# 236        both          True
# 237        both          True
# 238        both          True
# 239        both          True
# 240        both          True
# 241        both          True
# 242        both          True
# 243        both          True
# 244        both          True
# 245        both          True
# 246        both          True
# 248        both          True
# 249        both          True
# 250        both          True
# 251        both          True
# 252        both          True
# 259   left_only          True
# 262   left_only          True
# 265   left_only          True
# 269   left_only          True
# 270   left_only          True
# 272   left_only          True
# 277   left_only          True
# 284   left_only          True
# 285   left_only          True
# 286   left_only          True
# 287   left_only          True
# 288   left_only          True
# 290   left_only          True
# 292   left_only          True
# 293   left_only          True
# 294   left_only          True
# 299   left_only          True
# 300   left_only          True
# 301   left_only          True
# 302   left_only          True
# 304   left_only          True
# 306   left_only          True
# 307   left_only          True
# 308   left_only          True
# 310   left_only          True
# 311   left_only          True
# 313   left_only          True
# 314   left_only          True
# 323   left_only          True
# 324   left_only          True
# 335   left_only          True
# 336   left_only          True
# 339   left_only          True
# 346   left_only          True
# 351   left_only          True
# 361        both          True
# 377        both          True
# 409        both          True
# 421        both          True
# 428        both          True
# 435        both          True
# 461        both          True
# 469        both          True
# 470        both          True
# 483        both          True
# 484        both          True
# 495        both          True
# 511        both          True
# 515        both          True
# 516        both          True
# 531        both          True
# 542        both          True
# 561   left_only          True
# 595        both          True
# 597        both          True
# 598        both          True
# 599        both          True
# 600        both          True
# 603        both          True
# 604        both          True
# 606        both          True
# 607        both          True
# 608        both          True
# 611        both          True
# 612        both          True
# 703   left_only          True
# 781        both          True
# 808        both          True
# 829   left_only          True
# 860   left_only          True
# 869   left_only          True
# 887        both          True
# 891        both          True
# 892        both          True
# 894        both          True
# 899        both          True
# 903        both          True
# 917        both          True
# 922        both          True
# 938        both          True
# 943        both          True
# 957        both          True
# 965        both          True
# 966        both          True
# 967        both          True
# 972        both          True
# 976        both          True
# 977        both          True
# 982        both          True
# 983        both          True
# 988        both          True
# 994        both          True
# 1000       both          True
# 1009       both          True
# 1010       both          True
# 1014       both          True
# 1015       both          True
# 1016       both          True
# 1034       both          True
# 1035       both          True
# 1036       both          True
# 1052  left_only          True
# 1059  left_only          True
# 1063  left_only          True
# 1064  left_only          True
# 1094  left_only          True
# 1102  left_only          True
# 1112  left_only          True
# 1115  left_only          True
# 1116  left_only          True
# 1117  left_only          True
# 1131       both          True
# 1132       both          True
# 1133       both          True
# 1134       both          True
# 1135       both          True
# 1136       both          True
# 1137       both          True
# 1138       both          True
# 1139       both          True
# 1140       both          True
# 1141       both          True
# 1142       both          True
# 1144       both          True
# 1145       both          True
# 1146       both          True
# 1147       both          True
# 1148       both          True
# 1149       both          True
# 1151       both          True
# 1152       both          True
# 1153       both          True
# 1154       both          True
# 1156       both          True
# 1157       both          True
# 1158       both          True
# 1159       both          True
# 1160       both          True
# 1161       both          True

# %%
orgtree_columns
# Out:
# ['InsideGov',
#  'PrimaryInstitution',
#  'OrgName',
#  'ImmediateSuperiorOrg',
#  'SupervisesParent',
#  'LinkToCurrent_PrimaryInstitution',
#  'LinkToCurrent_OrgName',
#  '비고']

# %%
# save updated orgtree
orgtree = merged[["DuplicateKey"]+orgtree_columns]
orgtree[0:2]
# Out:
#    DuplicateKey  InsideGov      PrimaryInstitution OrgName  \
# 0         False      False  6.15공동선언실천남북공동위원회북측위원회   교직원분과
# 1         False      False  6.15공동선언실천남북공동위원회북측위원회   노동자분과
#
#   ImmediateSuperiorOrg  SupervisesParent LinkToCurrent_PrimaryInstitution  \
# 0                  NaN               NaN                          Current
# 1                  NaN               NaN                          Current
#
#   LinkToCurrent_OrgName   비고
# 0               Current  NaN
# 1               Current  NaN

# %%
orgtree.shape
# Out:
# (1033, 9)

# %%
# Check 1: drop NAs
orgtree.dropna()
orgtree.shape
# Out:
# (1033, 9)

# %%
# Check 2: duplicate rows
orgtree[orgtree.duplicated(keep=False)].shape
# Out:
# (44, 9)

# %%
orgtree = orgtree.drop_duplicates()
orgtree.shape
# Out:
# (1011, 9)

# %%
# Check 3: check duplicate keys. There were 112. Now there are 90. Leave these to process by hand.
orgtree[orgtree.duplicated(["PrimaryInstitution","OrgName"],keep=False)].shape
# Out:
# (154, 9)

# %%
# reset DuplicateKey = True
orgtree["DuplicateKey"]=False

# %%
orgtree.loc[orgtree.duplicated(["PrimaryInstitution","OrgName"],keep=False),"DuplicateKey"]=True

# %%
orgtree[orgtree.DuplicateKey==True].shape
# Out:
# (154, 9)

# %%
# update orgree_columns
orgtree_columns = list(orgtree.columns)
orgtree_columns
# Out:
# ['DuplicateKey',
#  'InsideGov',
#  'PrimaryInstitution',
#  'OrgName',
#  'ImmediateSuperiorOrg',
#  'SupervisesParent',
#  'LinkToCurrent_PrimaryInstitution',
#  'LinkToCurrent_OrgName',
#  '비고']

# %%
orgtree[orgtree.OrgName=="2군단"]
# Out:
# Empty DataFrame
# Columns: [DuplicateKey, InsideGov, PrimaryInstitution, OrgName, ImmediateSuperiorOrg, SupervisesParent, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName, 비고]
# Index: []

# %% [markdown]
# # left1: prep joborglink_left1

# %%
# joborglink_dtypes = {"OrgString":"str","_merged":"str","InOrgTree":"str","InsideGov":"str","PrimaryInstitution":"str","OrgName":"str","Orgtree_NeedToModify_PI":"str","Orgtree_NeedToModify_Orgname":"str","LinkToCurrent_PrimaryInstitution":"str","LinkToCurrent_OrgName":"str","Modify_LinkToCurrent_PrimaryInstitution":"str","Modify_LinkToCurrent_OrgName":"str","비고":"str"}
# joborglink = pd.read_excel(path_joborglink+filein_joborglink_right,dtype=joborglink_dtypes)
joborglink_left1 = pd.read_excel(path_joborglink+filein_joborglink_left1)
joborglink_left1.shape
# Out:
# (402, 11)

# %%
# list(joborglink_dtypes.keys())

# %%
joborglink_left1.columns
# Out:
# Index(['OrgString', 'Notes', '_merge', 'InOrgTree', 'PrimaryInstitution',
#        'OrgName', 'ChangeOrgTree', 'InsideGov',
#        'LinkToCurrent_PrimaryInstitution_y', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
columns_processing = ["PrimaryInstitution","OrgName"]
jol_left1_process = joborglink_left1[columns_processing]
jol_left1_process.shape
# Out:
# (402, 2)

# %%
# Check 1: No NAs
jol_left1_process.dropna()
jol_left1_process.shape
# Out:
# (402, 2)

# %%
# Check 2 & 3: Duplicate keys
jol_left1_process[jol_left1_process.duplicated()]
# Out:
#       PrimaryInstitution                         OrgName
# 1              4.15문화창작단                             NaN
# 2              4.15문화창작단                             NaN
# 6            강동지구탄광연합기업소                             NaN
# 11                개성방직공장                          3대혁명소조
# 17                 국무위원회                   국가체육지도위원회_제1부
# 28                 국방위원회                           호위사령부
# 29                 국방위원회                           호위사령부
# 30                 국방위원회                           호위사령부
# 37             김일성군사종합대학                             NaN
# 41             김책제철연합기업소                             NaN
# 44           남흥청년화학연합기업소                             NaN
# 45           남흥청년화학연합기업소                             NaN
# 46           남흥청년화학연합기업소                             NaN
# 48                    내각                            225국
# 50                    내각               간석지건설지도국_간석지설계사업소
# 52                    내각               강원도인민위원회_원산시인민위원회
# 54                    내각                        개성시인민위원회
# 57                    내각                           건재공업부
# 60                    내각                           공보위원회
# 64                    내각  교육위원회_고등교육성_김일성종합대학_계응상사리원농업대학
# 67                    내각                교육위원회_고등교육성_리과대학
# 73                    내각            교육위원회_고등교육성_평양국제관계대학
# 76                    내각             교육위원회_고등교육성_평양체육대학교
# 80                    내각              교육위원회_고등교육성_희천공업대학
# 84                    내각                         국가공보위원회
# 88                    내각                       국가수의방역위원회
# 91                    내각                         국가영화위원회
# 94                    내각                      국가학위직수여위원회
# 102                   내각                           대외봉사국
# 104                   내각                   도시경영성_수도건설지휘부
# 105                   내각                   도시경영성_수도건설지휘부
# 114                   내각                    외무성_X국_아태위원회
# 115                   내각                    외무성_X국_아태위원회
# 117                   내각                    외무성_X국_유고대사관
# 118                   내각                    외무성_X국_유고대사관
# 127                   내각        인민봉사총국_인민봉사지도국_평양시인민봉사총국
# 130                   내각                           자원개발부
# 137                   내각                         제2기계공업성
# 139                   내각                   조국평화통일위원회_서기국
# 142                   내각                 조국평화통일위원회_중앙위원회
# 144                   내각                         조선공보위원회
# 146                   내각                          중공업위원회
# 152                   내각                 철도성_청진화학공장_소다직장
# 160                   내각                      해운부_청년건설여단
# 164                  노동당                     남북경협제도실무협의회
# 166                  노동당                         대외정보조사부
# 168                  노동당                             영화부
# 175                  노동당                     중앙위원회_역사연구소
# 177                  노동당                       중앙위원회_행정부
# 179                  노동당                          청소년사업부
# 180                  노동당                          청소년사업부
# 183                농업과학원                             NaN
# 185              단천수산사업소                             NaN
# 188               대안전기공장                             NaN
# 196            무산광산연합기업소                             NaN
# 197            무산광산연합기업소                             NaN
# 198            무산광산연합기업소                             NaN
# 202             백두산건축연구원                             NaN
# 208           북조선임시인민위원회                             NaN
# 209           북조선임시인민위원회                             NaN
# 210           북조선임시인민위원회                             NaN
# 215                사회과학원                             NaN
# 220           사회주의노동청년동맹                             NaN
# 222          삼석구역장수원협동농장                             NaN
# 225           순천비날론연합기업소                             NaN
# 228           승리자동차연합기업소                             NaN
# 230                 신창탄광                             NaN
# 232              신포수산사업소                             NaN
# 236           양강도임업연합기업소                             NaN
# 238            용성기계연합기업소                             NaN
duplicated()]
# Out:
# Empty DataFrame
# Columns: [PrimaryInstitution, OrgName]
# Index: []

# %% [markdown]
# # left1: update orgtree using joborglink_left1

# %%
orgtree[0:2]
# Out:
#    DuplicateKey  InsideGov      PrimaryInstitution OrgName  \
# 0         False      False  6.15공동선언실천남북공동위원회북측위원회   교직원분과
# 1         False      False  6.15공동선언실천남북공동위원회북측위원회   노동자분과
#
#   ImmediateSuperiorOrg  SupervisesParent LinkToCurrent_PrimaryInstitution  \
# 0                  NaN               NaN                          Current
# 1                  NaN               NaN                          Current
#
#   LinkToCurrent_OrgName   비고
# 0               Current  NaN
# 1               Current  NaN

# %%
# these weren't cleaned up from the merge with joborglink_right
orgtree[orgtree.duplicated()].shape
# Out:
# (0, 9)

# %%
orgtree.shape
# Out:
# (1011, 9)

# %%
jol_left1_process.shape[0]
# Out:
# 256

# %%
# an outer join of the non-overlapping tables should simply add their two rows
orgtree.shape[0] + jol_left1_process.shape[0]
# Out:
# 1267

# %%
# merge and update
merged = orgtree.merge(jol_left1_process,how="outer",on=["PrimaryInstitution","OrgName"],suffixes=("","_y"),indicator=True)

# %%
# merged rows > orgtree rows
merged.shape
# Out:
# (1265, 10)

# %%
merged["_merge"].unique()
# Out:
# ['left_only', 'both', 'right_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
merged[merged["_merge"]=="left_only"].shape
# Out:
# (1008, 10)

# %%
merged[merged["_merge"]=="right_only"].shape
# Out:
# (254, 10)

# %%
merged[merged["_merge"]=="right_only"][0:5]
# Out:
#      DuplicateKey InsideGov PrimaryInstitution OrgName ImmediateSuperiorOrg  \
# 1011          NaN       NaN          4.15문화창작단     NaN                  NaN
# 1012          NaN       NaN           강건종합군관학교     NaN                  NaN
# 1013          NaN       NaN            강계고려약공장     NaN                  NaN
# 1014          NaN       NaN        강동지구탄광연합기업소     NaN                  NaN
# 1015          NaN       NaN         강서구역청산엽동농장     NaN                  NaN
#
#       SupervisesParent LinkToCurrent_PrimaryInstitution LinkToCurrent_OrgName  \
# 1011               NaN                              NaN                   NaN
# 1012               NaN                              NaN                   NaN
# 1013               NaN                              NaN                   NaN
# 1014               NaN                              NaN                   NaN
# 1015               NaN                              NaN                   NaN
#
#        비고      _merge
# 1011  NaN  right_only
# 1012  NaN  right_only
# 1013  NaN  right_only
# 1014  NaN  right_only
# 1015  NaN  right_only

# %%
merged[merged["_merge"]=="both"].shape
# Out:
# (3, 10)

# %%
merged[merged["_merge"]=="both"]
# Out:
#     DuplicateKey InsideGov PrimaryInstitution          OrgName  \
# 632        False      True               총참모부              NaN
# 799         True      True               총참모부  작전총국_보도처_판문점대표부
# 800         True      True               총참모부  작전총국_보도처_판문점대표부
#
#     ImmediateSuperiorOrg  SupervisesParent LinkToCurrent_PrimaryInstitution  \
# 632                  NaN               NaN                          Current
# 799                  NaN               NaN                          Current
# 800                  인민군               NaN                          Current
#
#     LinkToCurrent_OrgName   비고 _merge
# 632               Current  NaN   both
# 799               Current  NaN   both
# 800               Current  NaN   both

# %%
# verify no duplicates overall
merged[merged.duplicated()].shape
# Out:
# (0, 10)

# %%
# verify # of duplicate keys is the same as after updating with right: 155
merged.loc[merged.duplicated(["PrimaryInstitution","OrgName"],keep=False)].shape
# Out:
# (154, 10)

# %%
# update DuplicateKey=False for new additions, _merged == "right"
merged.loc[merged["_merge"]=="right","DuplicateKey"]=False

# %%
# select orgtree_columns
orgtree = merged[orgtree_columns]

# %% [markdown]
# # left2: prep joborglink_left2

# %%
# joborglink_dtypes = {"OrgString":"str","_merged":"str","InOrgTree":"str","InsideGov":"str","PrimaryInstitution":"str","OrgName":"str","Orgtree_NeedToModify_PI":"str","Orgtree_NeedToModify_Orgname":"str","LinkToCurrent_PrimaryInstitution":"str","LinkToCurrent_OrgName":"str","Modify_LinkToCurrent_PrimaryInstitution":"str","Modify_LinkToCurrent_OrgName":"str","비고":"str"}
# joborglink = pd.read_excel(path_joborglink+filein_joborglink_right,dtype=joborglink_dtypes)
joborglink_left2 = pd.read_excel(path_joborglink+filein_joborglink_left2)
joborglink_left2.shape
# Out:
# (373, 13)

# %%
# list(joborglink_dtypes.keys())

# %%
joborglink_left2.columns
# Out:
# Index(['OrgString', 'Notes', '_merge', 'InOrgTree', 'NeedToChange',
#        'InsideGov', 'InOrgTree_PI', 'InOrgTree_Orgname', 'PrimaryInstitution',
#        'OrgName', 'LinkToCurrent_PI', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
jol_left2_add = joborglink_left2[joborglink_left2["NeedToChange"]=="Add"]
jol_left2_add.shape
# Out:
# (241, 13)

# %%
columns_add = ["PrimaryInstitution","OrgName","LinkToCurrent_PI","LinkToCurrent_OrgName"]

# %%
jol_left2_add = jol_left2_add[columns_add]

# %%
# Check 1: NAs
jol_left2_add.dropna()
jol_left2_add.shape
# Out:
# (241, 4)

# %%
# Check 2: duplicate rows
jol_left2_add[jol_left2_add.duplicated()].shape
# Out:
# (91, 4)

# %%
jol_left2_add = jol_left2_add.drop_duplicates()
jol_left2_add.shape
# Out:
# (150, 4)

# %%
# Check 3: duplicate keys
jol_left2_add[jol_left2_add.duplicated(["PrimaryInstitution","OrgName"])].shape
# Out:
# (0, 4)

# %%
jol_left2_add[jol_left2_add.duplicated(["PrimaryInstitution","OrgName"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [PrimaryInstitution, OrgName, LinkToCurrent_PI, LinkToCurrent_OrgName]
# Index: []

# %%
jol_left2_change = joborglink_left2[joborglink_left2["NeedToChange"]=="Change"]
jol_left2_change.shape
# Out:
# (120, 13)

# %%
columns_change = ['InOrgTree_PI', 'InOrgTree_Orgname',
                  'PrimaryInstitution','OrgName',
                  'LinkToCurrent_PI','LinkToCurrent_OrgName'
                 ]

# %%
jol_left2_change = jol_left2_change[columns_change]
jol_left2_change.shape
# Out:
# (120, 6)

# %%
# Check 1: NAs
jol_left2_change.dropna()
jol_left2_change.shape
# Out:
# (120, 6)

# %%
# Check 2: duplicate rows
jol_left2_change[jol_left2_change.duplicated()].shape
# Out:
# (56, 6)

# %%
jol_left2_change = jol_left2_change.drop_duplicates()
jol_left2_change.shape
# Out:
# (64, 6)

# %%
# Check 3: duplicate keys
jol_left2_change[jol_left2_change.duplicated(['InOrgTree_PI','InOrgTree_Orgname',"PrimaryInstitution","OrgName"])].shape
# Out:
# (0, 6)

# %%
jol_left2_change[jol_left2_change.duplicated(['InOrgTree_PI','InOrgTree_Orgname',"PrimaryInstitution","OrgName"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [InOrgTree_PI, InOrgTree_Orgname, PrimaryInstitution, OrgName, LinkToCurrent_PI, LinkToCurrent_OrgName]
# Index: []

# %% [markdown]
# # left2: update orgtree using joborglink_left2_add

# %%
# orgtree
orgtree.shape
# Out:
# (1265, 9)

# %%
orgtree.columns
# Out:
# Index(['DuplicateKey', 'InsideGov', 'PrimaryInstitution', 'OrgName',
#        'ImmediateSuperiorOrg', 'SupervisesParent',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
# jol_left2_add
jol_left2_add.shape
# Out:
# (150, 4)

# %%
jol_left2_add.columns
# Out:
# Index(['PrimaryInstitution', 'OrgName', 'LinkToCurrent_PI',
#        'LinkToCurrent_OrgName'],
#       dtype='object')

# %%
jol_left2_add.columns = jol_left2_add.columns = ['PrimaryInstitution','OrgName','LinkToCurrent_PrimaryInstitution','LinkToCurrent_OrgName']
jol_left2_add.columns
# Out:
# Index(['PrimaryInstitution', 'OrgName', 'LinkToCurrent_PrimaryInstitution',
#        'LinkToCurrent_OrgName'],
#       dtype='object')

# %%
# outer join orgtree & jol_left2_add
merged = orgtree.merge(jol_left2_add,how="outer",on=list(jol_left2_add.columns),indicator=True)

# %%
orgtree.shape[0] + jol_left2_add.shape[0]
# Out:
# 1415

# %%
merged.shape
# Out:
# (1397, 10)

# %%
merged["_merge"].unique()
# Out:
# ['left_only', 'both', 'right_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
merged[merged["_merge"]=="left_only"].shape
# Out:
# (1246, 10)

# %%
merged[merged["_merge"]=="right_only"].shape
# Out:
# (132, 10)

# %%
merged[merged["_merge"]=="both"].shape
# Out:
# (19, 10)

# %%
# Check 1: NAs
merged.dropna()
merged.shape
# Out:
# (1397, 10)

# %%
# Check 2: duplicate rows
merged[merged.duplicated()].shape
# Out:
# (0, 10)

# %%
# Check 3: duplicate keys
merged[merged.duplicated(["PrimaryInstitution","OrgName"],keep=False)].shape
# Out:
# (192, 10)

# %%
# reset DuplicateKey
merged["DuplicateKey"]=False
merged.loc[merged.duplicated(["PrimaryInstitution","OrgName"],keep=False),"DuplicateKey"]=True
merged[merged.DuplicateKey==True].shape
# Out:
# (192, 10)

# %%
orgtree = merged[orgtree.columns]
orgtree.shape
# Out:
# (1397, 9)

# %% [markdown]
# # left2: update orgtree using joborglink_left2_change

# %%
# orgtree
orgtree.shape
# Out:
# (1397, 9)

# %%
orgtree.columns
# Out:
# Index(['DuplicateKey', 'InsideGov', 'PrimaryInstitution', 'OrgName',
#        'ImmediateSuperiorOrg', 'SupervisesParent',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
# jol_left2_change
jol_left2_change.shape
# Out:
# (64, 6)

# %%
jol_left2_change.columns
# Out:
# Index(['InOrgTree_PI', 'InOrgTree_Orgname', 'PrimaryInstitution', 'OrgName',
#        'LinkToCurrent_PI', 'LinkToCurrent_OrgName'],
#       dtype='object')

# %%
jol_left2_change.columns = ['InOrgTree_PI', 'InOrgTree_Orgname','PrimaryInstitution','OrgName','LinkToCurrent_PrimaryInstitution','LinkToCurrent_OrgName']
jol_left2_change.columns
# Out:
# Index(['InOrgTree_PI', 'InOrgTree_Orgname', 'PrimaryInstitution', 'OrgName',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName'],
#       dtype='object')

# %%
# inner join orgtree & jol_left2_change
merged = orgtree.merge(jol_left2_change,how="outer",
                       left_on=["PrimaryInstitution","OrgName"],
                       right_on=['InOrgTree_PI','InOrgTree_Orgname'],
                       suffixes = ["","_y"],
                       indicator=True)

# %%
orgtree.shape[0] + jol_left2_change.shape[0]
# Out:
# 1461

# %%
merged.shape
# Out:
# (1437, 16)

# %%
merged["_merge"].unique()
# Out:
# ['left_only', 'both', 'right_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
merged[merged["_merge"]=="left_only"].shape
# Out:
# (1371, 16)

# %%
merged[merged["_merge"]=="both"].shape
# Out:
# (26, 16)

# %%
# 0 right_only confirms that all jol_left2_change keys are contained in orgtree keys
merged[merged["_merge"]=="right_only"].shape
# Out:
# (40, 16)

# %%
# if _merge == right_only > 0
    # export _merge=="right_only"
    # compare these to orgtree
    # edit jol_left2_change accordingly
merged[merged["_merge"]=="right_only"][0:1]
#merged[merged["_merge"]=="right_only"].to_excel("jol_left2_change_rightonly.xlsx",index=False)
# Out:
#      DuplicateKey InsideGov PrimaryInstitution OrgName ImmediateSuperiorOrg  \
# 1397          NaN       NaN                NaN     NaN                  NaN
#
#       SupervisesParent LinkToCurrent_PrimaryInstitution LinkToCurrent_OrgName  \
# 1397               NaN                              NaN                   NaN
#
#        비고 InOrgTree_PI InOrgTree_Orgname PrimaryInstitution_y OrgName_y  \
# 1397  NaN      인민군총참모부           반항공군사령부                 총참모부  작전총국_제6처
#
#      LinkToCurrent_PrimaryInstitution_y LinkToCurrent_OrgName_y      _merge
# 1397                            Current                 Current  right_only

# %%
# confirm that  _merge == right_only keys ["InOrgTree_Orgname","InOrgTree_Orgname"]
# are all contained in 
# filein_joborglink_right = "joborglink_6_1_inorgtree_right_tocode_1_jeongsu.xlsx" keys ["PrimaryInstitution","OrgName"]

# ignore those which are contained in joborglink_6_1_inorgtree_right_tocode_1_jeongsu
# they have already been processed

# those which are not contained in joborglink_6_1_inorgtree_right_tocode_1_jeongsu
# should be confirmed in orgtree
# and edited in joborglink_6_1_left_2_tocode_jeongsu_x keys, ["InOrgTree_Orgname","InOrgTree_Orgname"]

# %%
merged_right = merged[merged["_merge"]=="right_only"]
merged_right.shape
# Out:
# (40, 16)

# %%
merged_right.columns
# Out:
# Index(['DuplicateKey', 'InsideGov', 'PrimaryInstitution', 'OrgName',
#        'ImmediateSuperiorOrg', 'SupervisesParent',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName', '비고',
#        'InOrgTree_PI', 'InOrgTree_Orgname', 'PrimaryInstitution_y',
#        'OrgName_y', 'LinkToCurrent_PrimaryInstitution_y',
#        'LinkToCurrent_OrgName_y', '_merge'],
#       dtype='object')

# %%
joborglink_right.shape
# Out:
# (843, 14)

# %%
joborglink_right.columns
# Out:
# Index(['OrgString', 'Notes', '_merged', 'InOrgTree', 'InsideGov',
#        'PrimaryInstitution', 'OrgName', 'Orgtree_NeedToModify_PI',
#        'Orgtree_NeedToModify_Orgname', 'LinkToCurrent_PrimaryInstitution',
#        'LinkToCurrent_OrgName', 'Modify_LinkToCurrent_PrimaryInstitution',
#        'Modify_LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
right_right = joborglink_right[["PrimaryInstitution","OrgName"]].merge(
    merged_right[["InOrgTree_PI","InOrgTree_Orgname"]],
    how="outer",
    left_on=["PrimaryInstitution","OrgName"],
    right_on=["InOrgTree_PI","InOrgTree_Orgname"],
    indicator=True)

# %%
right_right.shape
# Out:
# (843, 5)

# %%
# confirmed
# _merge == right_only keys ["InOrgTree_Orgname","InOrgTree_Orgname"]
#    are all contained in 
# filein_joborglink_right = "joborglink_6_1_inorgtree_right_tocode_1_jeongsu.xlsx" keys ["PrimaryInstitution","OrgName"]

right_right[right_right["_merge"]=="both"].shape
# Out:
# (40, 5)

# %%
# update data for "both"
merged[merged["_merge"]=="both"].shape
# Out:
# (26, 16)

# %%
merged[merged["_merge"]=="both"]
# Out:
# 457                 Current   both
# 459                 Current   both
# 463                 Current   both
# 464              당중앙위원회_경제부   both
# 465                 Current   both
# 466                 Current   both
# 478                 Current   both
# 480                 Current   both
# 481                 Current   both
# 488                 Current   both
# 491                 Current   both
# 492            당중앙위원회_근로단체부   both
# 524                 Current   both
# 913                 Current   both
# 914                 Current   both
# 915                 Current   both
# 916                 Current   both
# 933                 Current   both
# 934                 Current   both
# 935                 Current   both
# 937                 Current   both
# 939                 Current   both

# %%
# replace PrimaryInstitution
merged.loc[merged["_merge"]=="both","PrimaryInstitution"] = merged.loc[merged["_merge"]=="both","PrimaryInstitution_y"]

# %%
# replace OrgName
merged.loc[merged["_merge"]=="both","OrgName"] = merged.loc[merged["_merge"]=="both","OrgName_y"]

# %%
# replace LinkToCurrent_PrimaryInstitution
merged.loc[merged["_merge"]=="both","LinkToCurrent_PrimaryInstitution"] = merged.loc[merged["_merge"]=="both","LinkToCurrent_PrimaryInstitution_y"]

# %%
# replace LinkToCurrent_OrgName
merged.loc[merged["_merge"]=="both","LinkToCurrent_OrgName"] = merged.loc[merged["_merge"]=="both","LinkToCurrent_OrgName_y"]

# %%
# Check 1: NAs
merged.dropna()
merged.shape
# Out:
# (1437, 16)

# %%
# Check 2: duplicate rows
merged[merged.duplicated()].shape
# Out:
# (0, 16)

# %%
# Check 3: duplicate keys
merged[merged.duplicated(["PrimaryInstitution","OrgName"])].shape
# Out:
# (168, 16)

# %%
# reset DuplicateKey
merged["DuplicateKey"]=False
merged.loc[merged.duplicated(["PrimaryInstitution","OrgName"],keep=False),"DuplicateKey"]=True
merged[merged.DuplicateKey==True].shape
# Out:
# (263, 16)

# %%
orgtree = merged[orgtree.columns]
orgtree.shape
# Out:
# (1437, 9)

# %%
orgtree.columns
# Out:
# Index(['DuplicateKey', 'InsideGov', 'PrimaryInstitution', 'OrgName',
#        'ImmediateSuperiorOrg', 'SupervisesParent',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %% [markdown]
# # both: prep joborglink_both

# %%
# joborglink_dtypes = {"OrgString":"str","_merged":"str","InOrgTree":"str","InsideGov":"str","PrimaryInstitution":"str","OrgName":"str","Orgtree_NeedToModify_PI":"str","Orgtree_NeedToModify_Orgname":"str","LinkToCurrent_PrimaryInstitution":"str","LinkToCurrent_OrgName":"str","Modify_LinkToCurrent_PrimaryInstitution":"str","Modify_LinkToCurrent_OrgName":"str","비고":"str"}
# joborglink = pd.read_excel(path_joborglink+filein_joborglink_right,dtype=joborglink_dtypes)
joborglink_both = pd.read_excel(path_joborglink+filein_joborglink_both)
joborglink_both.shape
# Out:
# (831, 17)

# %%
# list(joborglink_dtypes.keys())

# %%
joborglink_both.columns
# Out:
# Index(['OrgString', 'Notes', '_merged', 'InOrgTree', 'InsideGov',
#        'PrimaryInstitution', 'OrgName', 'LinkToCurrent_PrimaryInstitution',
#        'LinkToCurrent_OrgName', 'Change_joborglink_PI',
#        'Change_joborglink_OrgName', 'Change_joborglink_Link_PI',
#        'Change_joborglink_Link_OrgName', 'ChangeOrgTree', 'OrgTree_PI',
#        'OrgTree_OrgName', '비고'],
#       dtype='object')

# %%
joborglink_both[joborglink_both["Change_joborglink_PI"].notna()].shape
# Out:
# (288, 17)

# %%
joborglink_both[joborglink_both["Change_joborglink_OrgName"].notna()].shape
# Out:
# (251, 17)

# %%
joborglink_both[joborglink_both["Change_joborglink_Link_PI"].notna()].shape
# Out:
# (259, 17)

# %%
joborglink_both[joborglink_both["Change_joborglink_Link_OrgName"].notna()].shape
# Out:
# (258, 17)

# %%
# update PrimaryInstitution', 'OrgName', 'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName
# with 'Change_joborglink_PI','Change_joborglink_OrgName', 'Change_joborglink_Link_PI','Change_joborglink_Link_OrgName'

# %%
rows_to_update = joborglink_both["Change_joborglink_PI"].notna() | joborglink_both["Change_joborglink_OrgName"].notna() | joborglink_both["Change_joborglink_Link_PI"].notna() | joborglink_both["Change_joborglink_Link_OrgName"].notna()

# %%
rows_to_update.value_counts()
# Out:
# False    543
# True     288
# dtype: int64

# %%
joborglink_both.loc[rows_to_update,"PrimaryInstitution"] = joborglink_both.loc[rows_to_update,"Change_joborglink_PI"]

# %%
joborglink_both.loc[rows_to_update,"OrgName"] = joborglink_both.loc[rows_to_update,"Change_joborglink_OrgName"]

# %%
joborglink_both.loc[rows_to_update,"LinkToCurrent_PrimaryInstitution"] = joborglink_both.loc[rows_to_update,"Change_joborglink_Link_PI"]

# %%
joborglink_both.loc[rows_to_update,"LinkToCurrent_OrgName"] = joborglink_both.loc[rows_to_update,"Change_joborglink_Link_OrgName"]

# %%
joborglink_both.shape
# Out:
# (831, 17)

# %%
# joborglink_both

# %% [markdown]
# # both: add to orgtree from joborglink_both

# %%
joborglink_both.columns
# Out:
# Index(['OrgString', 'Notes', '_merged', 'InOrgTree', 'InsideGov',
#        'PrimaryInstitution', 'OrgName', 'LinkToCurrent_PrimaryInstitution',
#        'LinkToCurrent_OrgName', 'Change_joborglink_PI',
#        'Change_joborglink_OrgName', 'Change_joborglink_Link_PI',
#        'Change_joborglink_Link_OrgName', 'ChangeOrgTree', 'OrgTree_PI',
#        'OrgTree_OrgName', '비고'],
#       dtype='object')

# %%
jol_both_add = joborglink_both[joborglink_both.ChangeOrgTree=="Add"]
jol_both_add.shape
# Out:
# (51, 17)

# %%
columns_add = ['PrimaryInstitution','OrgName','LinkToCurrent_PrimaryInstitution','LinkToCurrent_OrgName']

# %%
jol_both_add = jol_both_add[columns_add]
jol_both_add.shape
# Out:
# (51, 4)

# %%
# Check 1: NAs
jol_both_add.dropna()
jol_both_add.shape
# Out:
# (51, 4)

# %%
# Check 2: duplicate rows
jol_both_add[jol_both_add.duplicated()].shape
# Out:
# (23, 4)

# %%
jol_both_add = jol_both_add.drop_duplicates()
jol_both_add.shape
# Out:
# (28, 4)

# %%
# Check 3: duplicate keys
jol_both_add[jol_both_add.duplicated(["PrimaryInstitution","OrgName"],keep=False)].shape
# Out:
# (0, 4)

# %%
jol_both_add[jol_both_add.duplicated(["PrimaryInstitution","OrgName"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [PrimaryInstitution, OrgName, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName]
# Index: []

# %%
# merge orgtree with jol_both_add
merge = orgtree.merge(jol_both_add,how="outer",on=["PrimaryInstitution","OrgName"],suffixes=["","_y"],indicator=True)

# %%
orgtree.shape[0]
# Out:
# 1437

# %%
jol_both_add.shape[0]
# Out:
# 28

# %%
orgtree.shape[0] + jol_both_add.shape[0]
# Out:
# 1465

# %%
merge.shape[0]
# Out:
# 1461

# %%
merge["_merge"].unique()
# Out:
# ['left_only', 'both', 'right_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
merge[merge["_merge"]=="both"].shape
# Out:
# (4, 12)

# %%
merge[merge["_merge"]=="left_only"].shape
# Out:
# (1433, 12)

# %%
merge[merge["_merge"]=="right_only"].shape
# Out:
# (24, 12)

# %%
# double-check the "both"
merge[merge["_merge"]=="both"]
# Out:
#      DuplicateKey InsideGov PrimaryInstitution      OrgName  \
# 96          False      True              국방위원회   인민무력부_후방총국
# 123         False      True                 내각  교육위원회_고등교육부
# 1026        False      True              국방위원회        사회안전부
# 1212        False       NaN                정무원   문화예술부_영화총국
#
#      ImmediateSuperiorOrg  SupervisesParent LinkToCurrent_PrimaryInstitution  \
# 96                  인민무력부               NaN                            국무위원회
# 123                 교육위원회               NaN                               내각
# 1026                  NaN               NaN                            국무위원회
# 1212                  NaN               NaN                              NaN
#
#      LinkToCurrent_OrgName   비고 LinkToCurrent_PrimaryInstitution_y  \
# 96                국방성_후방총국  NaN                              국무위원회
# 123            교육위원회_고등교육성  NaN                                 내각
# 1026                 사회안전성  NaN                              국무위원회
# 1212                   NaN  NaN                                 내각
#
#      LinkToCurrent_OrgName_y _merge
# 96                  국방성_후방총국   both
# 123              교육위원회_고등교육성   both
# 1026                   사회안전성   both
# 1212                문화성_영화총국   both

# %%
# in "both", update LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName

# %%
merge.loc[merge["_merge"]=="both","LinkToCurrent_PrimaryInstitution"] = merge.loc[merge["_merge"]=="both","LinkToCurrent_PrimaryInstitution_y"]

# %%
merge.loc[merge["_merge"]=="both","LinkToCurrent_OrgName"] = merge.loc[merge["_merge"]=="both","LinkToCurrent_OrgName_y"]

# %%
merge[merge["_merge"]=="both"].shape
# Out:
# (4, 12)

# %%
# add the "right_only"
merge.loc[merge["_merge"]=="right_only","LinkToCurrent_PrimaryInstitution"] = merge.loc[merge["_merge"]=="right_only","LinkToCurrent_PrimaryInstitution_y"]

# %%
merge.loc[merge["_merge"]=="right_only","LinkToCurrent_OrgName"] = merge.loc[merge["_merge"]=="right_only","LinkToCurrent_OrgName_y"]

# %%
# recover orgtree from merge

# %%
# drop DuplicateKey & _merge
merge.drop("DuplicateKey",axis=1,inplace=True)
merge.drop("_merge",axis=1,inplace=True)

# %%
# Check 1: NAs
merge.dropna(how="all",inplace=True)
merge.shape
# Out:
# (1421, 10)

# %%
# Check 2: duplicate rows
merge[merge.duplicated()].shape
# Out:
# (3, 10)

# %%
merge = merge.drop_duplicates()

# %%
merge[merge.duplicated()].shape
# Out:
# (0, 10)

# %%
# Check 3: duplicate keys
merge[merge.duplicated(["PrimaryInstitution","OrgName"],keep=False)].shape
# Out:
# (218, 10)

# %%
# reset DuplicateKey
merge["DuplicateKey"]=False
merge.loc[merge.duplicated(["PrimaryInstitution","OrgName"],keep=False),"DuplicateKey"]=True
merge[merge.DuplicateKey==True].shape
# Out:
# (218, 11)

# %%
orgtree = merge[orgtree.columns]
orgtree.shape
# Out:
# (1418, 9)

# %%
orgtree.columns
# Out:
# Index(['DuplicateKey', 'InsideGov', 'PrimaryInstitution', 'OrgName',
#        'ImmediateSuperiorOrg', 'SupervisesParent',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %% [markdown]
# # both: change orgtree using joborglink_both

# %%
joborglink_both.columns
# Out:
# Index(['OrgString', 'Notes', '_merged', 'InOrgTree', 'InsideGov',
#        'PrimaryInstitution', 'OrgName', 'LinkToCurrent_PrimaryInstitution',
#        'LinkToCurrent_OrgName', 'Change_joborglink_PI',
#        'Change_joborglink_OrgName', 'Change_joborglink_Link_PI',
#        'Change_joborglink_Link_OrgName', 'ChangeOrgTree', 'OrgTree_PI',
#        'OrgTree_OrgName', '비고'],
#       dtype='object')

# %%
jol_both_change = joborglink_both[joborglink_both.ChangeOrgTree=="Change"]
jol_both_change.shape
# Out:
# (142, 17)

# %%
columns_change = ['OrgTree_PI','OrgTree_OrgName','PrimaryInstitution','OrgName','LinkToCurrent_PrimaryInstitution','LinkToCurrent_OrgName']

# %%
jol_both_change = jol_both_change[columns_change]
jol_both_change.shape
# Out:
# (142, 6)

# %%
# Check 1: NAs
jol_both_change.dropna(how="all",inplace=True)
jol_both_change.shape
# Out:
# (142, 6)

# %%
# Check 2: duplicate rows
jol_both_change[jol_both_change.duplicated()].shape
# Out:
# (82, 6)

# %%
jol_both_change = jol_both_change.drop_duplicates()
jol_both_change.shape
# Out:
# (60, 6)

# %%
# Check 3: duplicate keys
jol_both_change[jol_both_change.duplicated(["OrgTree_PI","OrgTree_OrgName","PrimaryInstitution","OrgName"],keep=False)].shape
# Out:
# (0, 6)

# %%
jol_both_change.sort_values(["PrimaryInstitution","OrgName"],inplace=True)
jol_both_change[jol_both_change.duplicated(["OrgTree_PI","OrgTree_OrgName","PrimaryInstitution","OrgName"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [OrgTree_PI, OrgTree_OrgName, PrimaryInstitution, OrgName, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName]
# Index: []

# %%
jol_both_change.columns
# Out:
# Index(['OrgTree_PI', 'OrgTree_OrgName', 'PrimaryInstitution', 'OrgName',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName'],
#       dtype='object')

# %%
# merge orgtree with jol_both_change
merge = orgtree.merge(jol_both_change,how="outer",
                      left_on=["PrimaryInstitution","OrgName"],
                      right_on=["OrgTree_PI","OrgTree_OrgName"],
                      suffixes=["","_y"],
                      indicator=True)

# %%
merge.columns
# Out:
# Index(['DuplicateKey', 'InsideGov', 'PrimaryInstitution', 'OrgName',
#        'ImmediateSuperiorOrg', 'SupervisesParent',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName', '비고',
#        'OrgTree_PI', 'OrgTree_OrgName', 'PrimaryInstitution_y', 'OrgName_y',
#        'LinkToCurrent_PrimaryInstitution_y', 'LinkToCurrent_OrgName_y',
#        '_merge'],
#       dtype='object')

# %%
orgtree.shape[0]
# Out:
# 1418

# %%
jol_both_change.shape[0]
# Out:
# 60

# %%
orgtree.shape[0] + jol_both_change.shape[0]
# Out:
# 1478

# %%
merge.shape[0]
# Out:
# 1449

# %%
merge["_merge"].unique()
# Out:
# ['left_only', 'both', 'right_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
merge[merge["_merge"]=="both"].shape
# Out:
# (31, 16)

# %%
merge[merge["_merge"]=="left_only"].shape
# Out:
# (1388, 16)

# %%
merge[merge["_merge"]=="right_only"].shape
# Out:
# (30, 16)

# %%
# confirm "right_only" were already changed
merge_right = merge.loc[merge["_merge"]=="right_only",["OrgTree_PI","OrgTree_OrgName"]].drop_duplicates()
merge_right.shape
# Out:
# (27, 2)

# %%
right_right = joborglink_right[["PrimaryInstitution","OrgName"]].merge(
    merge_right,
    how="outer",
    left_on=["PrimaryInstitution","OrgName"],
    right_on=["OrgTree_PI","OrgTree_OrgName"],
    indicator=True)

# %%
# 16 of 28 were added in joborglink_right
right_right[right_right["_merge"]=="both"].shape
# Out:
# (15, 5)

# %%
# display the 16 contained in joborglink_right
right_right[right_right["_merge"]=="both"]
# Out:
#     PrimaryInstitution          OrgName OrgTree_PI  OrgTree_OrgName _merge
# 164                 내각     외무성_X국_체코대사관         내각     외무성_X국_체코대사관   both
# 168                 내각    외무성_X국_스웨덴대사관         내각    외무성_X국_스웨덴대사관   both
# 171                 내각  외무성_X국_나이지리아대사관         내각  외무성_X국_나이지리아대사관   both
# 172                 내각     외무성_X국_네팔대사관         내각     외무성_X국_네팔대사관   both
# 175                 내각    외무성_X국_러시아대사관         내각    외무성_X국_러시아대사관   both
# 176                 내각   외무성_X국_루마니아대사관         내각   외무성_X국_루마니아대사관   both
# 181                 내각    외무성_X국_스위스대사관         내각    외무성_X국_스위스대사관   both
# 182                 내각   외무성_X국_싱가포르대사관         내각   외무성_X국_싱가포르대사관   both
# 280             당중앙위원회             총정치국     당중앙위원회             총정치국   both
# 281             당중앙위원회              정치국     당중앙위원회              정치국   both
# 285             당중앙위원회             경공업부     당중앙위원회             경공업부   both
# 348            인민군총참모부              NaN    인민군총참모부              NaN   both
# 352            인민군총참모부          1군단_1사단    인민군총참모부          1군단_1사단   both
# 836                NaN          국토환경보호성        NaN          국토환경보호성   both
# 838                NaN            노동행정부        NaN            노동행정부   both

# %%
right_right[right_right["_merge"]=="left_only"].shape
# Out:
# (828, 5)

# %%
# 12 are still unaccounted for
right_right[right_right["_merge"]=="right_only"].shape
# Out:
# (12, 5)

# %%
# I could also check left1 and left2

# %%
merge_right2 = right_right.loc[right_right["_merge"]=="right_only",merge_right.columns]

# %%
merge_right2.columns
# Out:
# Index(['OrgTree_PI', 'OrgTree_OrgName'], dtype='object')

# %%
merge_right2.shape
# Out:
# (12, 2)

# %%
# display the 12 contained in left2
merge_right2
# Out:
#     OrgTree_PI  OrgTree_OrgName
# 843        노동당            중앙위원회
# 844        노동당       중앙위원회_39호실
# 845        노동당       중앙위원회_경공업부
# 846        노동당      중앙위원회_계획재정부
# 847        노동당      중앙위원회_과학교육부
# 848        노동당        중앙위원회_국제부
# 849        노동당      중앙위원회_문서정리실
# 850        노동당        중앙위원회_비서국
# 851        노동당      중앙위원회_선전선동부
# 852        노동당      중앙위원회_재정경리부
# 853        노동당  중앙위원회_조직지도부_서기실
# 854        노동당      중앙위원회_청년사업부

# %%
# check joborglink_left2
joborglink_left2.columns
# Out:
# Index(['OrgString', 'Notes', '_merge', 'InOrgTree', 'NeedToChange',
#        'InsideGov', 'InOrgTree_PI', 'InOrgTree_Orgname', 'PrimaryInstitution',
#        'OrgName', 'LinkToCurrent_PI', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
right_right2 = joborglink_left2[['InOrgTree_PI', 'InOrgTree_Orgname']].merge(
    merge_right2,
    how="outer",
    left_on=['InOrgTree_PI', 'InOrgTree_Orgname'],
    right_on=['OrgTree_PI', 'OrgTree_OrgName'],
    indicator=True)

# %%
right_right2.shape
# Out:
# (373, 5)

# %%
right_right2["_merge"].unique()
# Out:
# ['left_only', 'both']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
# the remaining 12 were added in joborglink_left2
right_right2[right_right2["_merge"]=="right_only"].shape
# Out:
# (0, 5)

# %%
# all keys in jol_both_change have been accounted for

# %%
# update orgtree[]'PrimaryInstitution', 'OrgName']
# for orgs which match jol_both_change['OrgTree_PI', 'OrgTree_OrgName']

# %%
merge.columns
# Out:
# Index(['DuplicateKey', 'InsideGov', 'PrimaryInstitution', 'OrgName',
#        'ImmediateSuperiorOrg', 'SupervisesParent',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName', '비고',
#        'OrgTree_PI', 'OrgTree_OrgName', 'PrimaryInstitution_y', 'OrgName_y',
#        'LinkToCurrent_PrimaryInstitution_y', 'LinkToCurrent_OrgName_y',
#        '_merge'],
#       dtype='object')

# %%
merge.loc[merge["_merge"]=="both","PrimaryInstitution"] = merge.loc[merge["_merge"]=="both","PrimaryInstitution_y"]

# %%
merge.loc[merge["_merge"]=="both","OrgName"] = merge.loc[merge["_merge"]=="both","OrgName_y"]

# %%
merge.loc[merge["_merge"]=="both","LinkToCurrent_PrimaryInstitution"] = merge.loc[merge["_merge"]=="both","LinkToCurrent_PrimaryInstitution_y"]

# %%
merge.loc[merge["_merge"]=="both","LinkToCurrent_OrgName"] = merge.loc[merge["_merge"]=="both","LinkToCurrent_OrgName_y"]

# %%
merge.shape
# Out:
# (1449, 16)

# %%
# recover orgtree from merge

# %%
# drop DuplicateKey & _merge
merge.drop("DuplicateKey",axis=1,inplace=True)
merge.drop("_merge",axis=1,inplace=True)

# %%
# Check 1: NAs
merge.dropna(how="all",inplace=True)
merge.shape
# Out:
# (1449, 14)

# %%
# Check 2: duplicate rows
merge[merge.duplicated()].shape
# Out:
# (0, 14)

# %%
merge = merge.drop_duplicates()

# %%
merge[merge.duplicated()].shape
# Out:
# (0, 14)

# %%
# Check 3: duplicate keys
merge[merge.duplicated(["PrimaryInstitution","OrgName"],keep=False)].shape
# Out:
# (274, 14)

# %%
# reset DuplicateKey
merge["DuplicateKey"]=False
merge.loc[merge.duplicated(["PrimaryInstitution","OrgName"],keep=False),"DuplicateKey"]=True
merge[merge.DuplicateKey==True].shape
# Out:
# (274, 15)

# %%
orgtree = merge[orgtree.columns]
orgtree.shape
# Out:
# (1449, 9)

# %%
orgtree.columns
# Out:
# Index(['DuplicateKey', 'InsideGov', 'PrimaryInstitution', 'OrgName',
#        'ImmediateSuperiorOrg', 'SupervisesParent',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %% [markdown]
# # orgtree stats for jeongsu

# %%
orgtree.columns
# Out:
# Index(['DuplicateKey', 'InsideGov', 'PrimaryInstitution', 'OrgName',
#        'ImmediateSuperiorOrg', 'SupervisesParent',
#        'LinkToCurrent_PrimaryInstitution', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
orgtree[orgtree.DuplicateKey==True].shape
# Out:
# (274, 9)

# %%
orgtree.shape
# Out:
# (1449, 9)

# %%
orgtree.shape[0] - orgtree[orgtree.DuplicateKey==True].shape[0]
# Out:
# 1175

# %%
orgtree[orgtree.InsideGov.isna()].shape
# Out:
# (440, 9)

# %%
orgtree[orgtree.LinkToCurrent_PrimaryInstitution.isna()].shape
# Out:
# (292, 9)

# %%
orgtree[orgtree.LinkToCurrent_OrgName.isna()].shape
# Out:
# (325, 9)

# %%
# export orgtree

# %%
orgtree = orgtree.sort_values(["DuplicateKey","PrimaryInstitution","OrgName"],ascending=[False,True,True])

# %%
orgtree[0:10]
# Out:
#       DuplicateKey InsideGov PrimaryInstitution      OrgName  \
# 15            True      True              국무위원회        국가보위성
# 16            True       NaN              국무위원회        국가보위성
# 18            True      True              국무위원회          국방성
# 19            True       NaN              국무위원회          국방성
# 22            True      True              국무위원회  국방성_참모부_공병국
# 23            True      True              국무위원회  국방성_참모부_공병국
# 46            True      True              국무위원회  국방성_참모부_통신국
# 47            True      True              국무위원회  국방성_참모부_통신국
# 1043          True       NaN              국방위원회      국가안전보위부
# 1044          True       NaN              국방위원회      국가안전보위부
#
#      ImmediateSuperiorOrg  SupervisesParent LinkToCurrent_PrimaryInstitution  \
# 15                    NaN               NaN                          Current
# 16                    NaN               NaN                            국무위원회
# 18                    NaN               NaN                          Current
# 19                    NaN               NaN                            국무위원회
# 22                    국방성               NaN                          Current
# 23                    국방성               NaN                    Please_Revise
# 46                    국방성               NaN                          Current
# 47                    국방성               NaN                          Current
# 1043                  NaN               NaN                              NaN
# 1044                  NaN               NaN                            국무위원회
#
#      LinkToCurrent_OrgName      비고
# 15                 Current     NaN
# 16                   국가보위성     NaN
# 18                 Current     NaN
# 19                     국방성     NaN
# 22                 Current     NaN
# 23           Please_Revise     NaN
# 46                 Current     NaN
# 47                 Current  제258부대
# 1043                   NaN     NaN
# 1044                 국가보위성     NaN

# %%
orgtree.to_excel(path_orgtree+fileout_orgtree,index=False)

# %% [markdown]
# # joborglink: prep joborglink files for concat

# %%
columns_jol = ["OrgString","PrimaryInstitution","OrgName","Notes"]

# %%
# joborglink_right

# %%
# joborglink_right has no OrgStrings 
joborglink_right[joborglink_right.OrgString.notna()]
# Out:
# Empty DataFrame
# Columns: [OrgString, Notes, _merged, InOrgTree, InsideGov, PrimaryInstitution, OrgName, Orgtree_NeedToModify_PI, Orgtree_NeedToModify_Orgname, LinkToCurrent_PrimaryInstitution, LinkToCurrent_OrgName, Modify_LinkToCurrent_PrimaryInstitution, Modify_LinkToCurrent_OrgName, 비고]
# Index: []

# %%
# joborglink_left1

# %%
joborglink_left1.columns
# Out:
# Index(['OrgString', 'Notes', '_merge', 'InOrgTree', 'PrimaryInstitution',
#        'OrgName', 'ChangeOrgTree', 'InsideGov',
#        'LinkToCurrent_PrimaryInstitution_y', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
jol_left1_concat = joborglink_left1

# %%
jol_left1_concat["Notes"] = jol_left1_concat["Notes"] + "; 비고: " + jol_left1_concat["비고"]

# %%
jol_left1_concat = jol_left1_concat[columns_jol]

# %%
# confirm NO "right_only": all jol_left1_concat keys have matches in the orgtree
columns_key = ["PrimaryInstitution","OrgName"]
merged = orgtree[columns_key].merge(jol_left1_concat[columns_key],how="outer",on=columns_key,indicator=True)
merged["_merge"].unique()
# Out:
# ['left_only', 'both']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
# joborglink_left2

# %%
joborglink_left2.columns
# Out:
# Index(['OrgString', 'Notes', '_merge', 'InOrgTree', 'NeedToChange',
#        'InsideGov', 'InOrgTree_PI', 'InOrgTree_Orgname', 'PrimaryInstitution',
#        'OrgName', 'LinkToCurrent_PI', 'LinkToCurrent_OrgName', '비고'],
#       dtype='object')

# %%
jol_left2_concat = joborglink_left2

# %%
jol_left2_concat["Notes"] = jol_left2_concat["Notes"] + "; 비고: " + jol_left2_concat["비고"]

# %%
jol_left2_concat = jol_left2_concat[columns_jol]

# %%
# confirm NO "right_only": all jol_left2_concat keys have matches in the orgtree
# or confirm that the only "right_only" are "Uncertain"

columns_key = ["PrimaryInstitution","OrgName"]
merged = orgtree[columns_key].merge(jol_left2_concat[columns_key],how="outer",on=columns_key,indicator=True)
merged["_merge"].unique()
# Out:
# ['both', 'left_only', 'right_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
# also, some of the "right_only" could be LinkPI-LinkOrg records which haven't been added to PI-OrgName
# these are also fine, because I will add these to PI-OrgName later when I update orgtree
# for example:
# 호위사령부
# 당중앙위원회_근로단체부
# 호위사령부_제91수도방어군단
merged[merged["_merge"]=="right_only"]
# Out:
#      PrimaryInstitution          OrgName      _merge
# 1747              호위사령부              NaN  right_only
# 1748               총참모부  호위사령부_제91수도방어군단  right_only
# 1749               총참모부  호위사령부_제91수도방어군단  right_only
# 1750               총참모부  호위사령부_제91수도방어군단  right_only
# 1751          Uncertain        Uncertain  right_only
# 1752          Uncertain        Uncertain  right_only
# 1753          Uncertain        Uncertain  right_only
# 1754          Uncertain        Uncertain  right_only
# 1755          Uncertain        Uncertain  right_only
# 1756          Uncertain        Uncertain  right_only
# 1757          Uncertain        Uncertain  right_only
# 1758          Uncertain        Uncertain  right_only
# 1759          Uncertain        Uncertain  right_only

# %%
# joborglink_both

# %%
joborglink_both.columns
# Out:
# Index(['OrgString', 'Notes', '_merged', 'InOrgTree', 'InsideGov',
#        'PrimaryInstitution', 'OrgName', 'LinkToCurrent_PrimaryInstitution',
#        'LinkToCurrent_OrgName', 'Change_joborglink_PI',
#        'Change_joborglink_OrgName', 'Change_joborglink_Link_PI',
#        'Change_joborglink_Link_OrgName', 'ChangeOrgTree', 'OrgTree_PI',
#        'OrgTree_OrgName', '비고'],
#       dtype='object')

# %%
jol_both_concat = joborglink_both

# %%
jol_both_concat["Notes"] = jol_both_concat["Notes"] + "; 비고: " + jol_both_concat["비고"]

# %%
jol_both_concat = jol_both_concat[columns_jol]

# %%
# confirm NO "right_only": all jol_both_concat keys have matches in the orgtree
columns_key = ["PrimaryInstitution","OrgName"]
merged = orgtree[columns_key].merge(jol_both_concat[columns_key],how="outer",on=columns_key,indicator=True)
merged["_merge"].unique()
# Out:
# ['both', 'left_only', 'right_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
# address this one later

# 내각 사회안전성_경비국

merged[merged["_merge"]=="right_only"]
# Out:
#      PrimaryInstitution    OrgName      _merge
# 2147                 내각  사회안전성_경비국  right_only

# %% [markdown]
# # joborglink: concatenate & export

# %%
jol = pd.concat([jol_left1_concat,jol_left2_concat,jol_both_concat])
jol.shape
# Out:
# (1606, 4)

# %%
# Check 1: NAs
jol.dropna(how="all",inplace=True)
jol.shape
# Out:
# (1606, 4)

# %%
# drop all rows where OrgString is NA
jol = jol[jol.OrgString.notna()]
jol.shape
# Out:
# (1572, 4)

# %%
jol[jol.OrgString.isna()]
# Out:
# Empty DataFrame
# Columns: [OrgString, PrimaryInstitution, OrgName, Notes]
# Index: []

# %%
# for now I will leave the uncertain OrgStrings
jol[jol["PrimaryInstitution"]=="Uncertain"]
# Out:
#                 OrgString PrimaryInstitution    OrgName  \
# 364            노동당 기계공업협회          Uncertain  Uncertain
# 365              노동당 중공업부          Uncertain  Uncertain
# 366  노동당 중앙인민위원회 중공업부 제1부          Uncertain  Uncertain
# 367               당 기계공업부          Uncertain  Uncertain
# 368                당 중공업부          Uncertain  Uncertain
# 369            전자자동화공업위원회          Uncertain  Uncertain
# 370        전자자동화공업위원회 기술국          Uncertain  Uncertain
# 371        전자자동화공업위원회 제1부          Uncertain  Uncertain
# 372                 제2집단군          Uncertain  Uncertain
#
#                                                  Notes
# 364                                 기계공업부; 비고: 당중앙위원회?
# 365  중앙위원회->중앙인민위원회; 비고: 중앙인민위원회 is a PrimaryInstit...
# 366  1부 Not found; 비고: 중앙인민위원회 is a PrimaryInstitut...
# 367                                                NaN
# 368                                                NaN
# 369                                                NaN
# 
# 555                체육                 내각                  체육성   NaN
# 559               체육성                 내각                  체육성   NaN
# 575             화학공업성                 내각                화학공업성   NaN
# 598                 당                노동당                  NaN   NaN
# 649            조선피겨협회           조선빙상피겨협회                  NaN   NaN
# 653             통일전선부                노동당         당중앙위원회_통일선전부   NaN
# 696         음악가동맹 중앙위          조선문학예술총동맹        조선음악가동맹_중앙위원회   NaN
# 701     조선문학예술총동맹 중앙위          조선문학예술총동맹                중앙위원회   NaN
# 740       조선직업총동맹 중앙위            조선직업총동맹                중앙위원회   NaN
# 743              축구협회             조선축구협회                  NaN   NaN
# 746             법제위원회             최고인민회의                법제위원회   NaN
# 766         강원도 인민위원회             최고인민회의             강원도인민위원회   NaN
# 772             상임위원회             최고인민회의                상임위원회   NaN
# 776             예산위원회             최고인민회의                예산위원회   NaN
# 777             예산위원회             최고인민회의                예산위원회   NaN

# %%
jol = jol.drop_duplicates()
jol.shape
# Out:
# (1460, 4)

# %%
jol[jol.duplicated()]
# Out:
# Empty DataFrame
# Columns: [OrgString, PrimaryInstitution, OrgName, Notes]
# Index: []

# %%
# Check 3: duplicate keys
jol[jol.duplicated(["OrgString","PrimaryInstitution","OrgName"])].shape
# Out:
# (12, 4)

# %%
jol.sort_values(["OrgString","PrimaryInstitution","OrgName","Notes"],inplace=True)

# %%
jol[jol.duplicated(["OrgString","PrimaryInstitution","OrgName"],keep=False)]
# Out:
#            OrgString PrimaryInstitution                     OrgName  \
# 239               광업                 내각                         광업성
# 238               광업                 내각                         광업성
# 63   금속기계공업성 전기기계관리국                 내각                     금속기계공업성
# 64   금속기계공업성 전기기계관리국                 내각                     금속기계공업성
# 66           기계공업위원회                 내각                   금속기계공업위원회
# 65           기계공업위원회                 내각                   금속기계공업위원회
# 70     김일성종합대학 학생위원회                 내각   교육위원회_고등교육성_김일성종합대학_학생위원회
# 69     김일성종합대학 학생위원회                 내각   교육위원회_고등교육성_김일성종합대학_학생위원회
# 90       대외경제협력추진위원회                 내각         대외경제위원회_대외경제협력추진위원회
# 89       대외경제협력추진위원회                 내각         대외경제위원회_대외경제협력추진위원회
# 416           알제리 주재                 내각  외무성_아프리카-라틴아메리카-아랍국_알제리대사관
# 415           알제리 주재                 내각  외무성_아프리카-라틴아메리카-아랍국_알제리대사관
# 52          인민군 총정치국                노동당                 당중앙위원회_총정치국
# 324         인민군 총정치국                노동당                 당중앙위원회_총정치국
# 516        주 알제리 대사관                 내각  외무성_아프리카-라틴아메리카-아랍국_알제리대사관
# 515        주 알제리 대사관                 내각  외무성_아프리카-라틴아메리카-아랍국_알제리대사관
# 135            중앙인민위            중앙인민위원회                         NaN
# 747            중앙인민위            중앙인민위원회                         NaN
# 29           채취공업위원회                 내각                     채취공업위원회
# 30           채취공업위원회                 내각                     채취공업위원회
# 176        함경남도 당위원회                노동당             당중앙위원회_함경남도당위원회
# 175        함경남도 당위원회                노동당             당중앙위원회_함경남도당위원회
# 343            해군사령부               총참모부                    작전총국_제7처
# 344            해군사령부               총참모부                    작전총국_제7처
#
#                                                  Notes
# 239  내각 산하; 비고: 광업성+전력공업성+석탄공업성 => 전력석탄공업성 => 석탄공업성...
# 238                                                NaN
# 63           전기기계관리국 Not found; 비고: 금속공업부/성 + 기계공업부/성?
# 64                                                 NaN
# 66                             금속기계공업위원회; 비고: 금속기계공업성?
# 65                                                 NaN
# 70                내각-교육위원회-고등교육성; 비고: 교육위원회_고등교육성_...?
# 69                                                 NaN
# 90          대외경제위원회 산하; 비고: InOrgTree = 대외경제성_대외경제협의국?
# 89                                                 NaN
# 416  *orgtree에는 "알제이" 대사관으로 되어있음, 수정필요; 비고: 참고 : ht...
# 415                                                NaN
# 52               인민군 Not found; 비고: 총정치국은 조선인민군 소속 당기관
# 324                                   총정치국; 비고: 중앙위원회?
# 516  *orgtree에는 "알제이" 대사관으로 되어있음, 수정필요; 비고: 참고 : ht...
# 515                                                NaN
# 135  노동당 산하; 비고: 중앙인민위원회 is a PrimaryInstitution in...
# 747                                                NaN
# 29                                    내각 산하; 비고: 채취공업성
# 30                                                 NaN
# 176                           노동당-중앙위원회 산하; 비고: 중앙위원회?
# 175                                                NaN
# 343              인민군 총참모부 산하; 비고: 작전총국_제X처_제Y군단 vs Y군단
# 344              인민군-총참모부 산하; 비고: 작전총국_제X처_제Y군단 vs Y군단

# %%
jol = jol.drop_duplicates(["OrgString","PrimaryInstitution","OrgName"],keep="first")
jol.shape
# Out:
# (1448, 4)

# %%
jol[jol.duplicated(["OrgString","PrimaryInstitution","OrgName"])]
# Out:
# Empty DataFrame
# Columns: [OrgString, PrimaryInstitution, OrgName, Notes]
# Index: []

# %%
# Check 4: duplicate OrgString
jol.sort_values(["OrgString"],inplace=True)
jol[jol.duplicated(["OrgString"],keep=False)]
# Out:
#            OrgString PrimaryInstitution                    OrgName  \
# 82           국가건설위원회                 내각                    국가건설위원회
# 252          국가건설위원회                 내각                    국가계획위원회
# 283             기계공업                 내각                      기계공업성
# 284             기계공업                 내각                      기계공업부
# 314            내각사무국                 내각                        사무국
# 312            내각사무국                 내각                      내각사무국
# 315               노동                 내각                        노동성
# 582               노동                노동당                        NaN
# 346               무역                 내각                        무역부
# 345               무역                 내각                        무역성
# 358         문화재 보존총국                 내각                문화성_문화보존지도국
# 359         문화재 보존총국                 내각              문화예술부_문화재보존총국
# 363        민족경제협력연합회                 내각            대외경제성_민족경제협력위원회
# 362        민족경제협력연합회                 내각  대외경제성_민족경제협력위원회_민족경제협력연합회
# 372               보건                 내각                        보건부
# 371               보건                 내각                        보건성
# 103            수도건설부                 내각              도시경영성_수도건설지휘부
# 109            수도건설부                 내각              수도건설위원회_수도건설부
# 21           외무성 미국국                 내각                    외무성_미국국
# 22           외무성 미국국                 내각                    외무성_미주국
# 439             원유공업                 내각                      원유공업부
# 438             원유공업                 내각                      원유공업성
# 451             육해운부                 내각                       육해운부
# 450             육해운부                 내각                       육해운성
# 369       전자자동화공업위원회          Uncertain                  Uncertain
# 133       전자자동화공업위원회                 내각                 전자자동화공업위원회
# 249        정무원 고등교육부                정무원                      고등교육부
# 11         정무원 고등교육부                정무원                교육위원회_고등교육부
# 697        조선문학예술총동맹          조선문학예술총동맹                      중앙위원회
# 698        조선문학예술총동맹          조선문학예술총동맹                        NaN
# 315  조선민주여성동맹 양강도위원회           조선민주여성동맹                     양강도위원회
# 613  조선민주여성동맹 양강도위원회         조선사회주의여성동맹                     양강도위원회
# 557              체육부                 내각                        체육부
# 556              체육부                 내각                        체육성
# 16           체육지도위원회              국무위원회              국가체육지도위원회_제1부
# 202          체육지도위원회              국무위원회                  국가체육지도위원회
# 383   최고인민회의 통일정책위원회             최고인민회의                    통일정책위원회
# 381   최고인민회의 통일정책위원회             최고인민회의                  통일정책심의위원회
# 141           평안남도 당                노동당            당중앙위원회_평안남도당위원회
# 142           평안남도 당                노동당    당중앙위원회_평안남도당위원회_안주시당위원회
# 145        평안남도 당위원회                노동당    당중앙위원회_평안남도당위원회_안주시당위원회
# 144        평안남도 당위원회                노동당            당중앙위원회_평안남도당위원회
# 30             호위사령부              국방위원회                      호위사령부
# 345            호위사령부              호위사령부                        NaN
#
#                    Notes
# 82   내각 산하; 비고: 국가건설감독성?
# 252                  NaN
# 283                  NaN
# 284                  NaN
# 314                  NaN
# 312                  NaN
# 315                  NaN
# 582                  NaN
# 346                  NaN
# 345                  NaN
# 358                  NaN
# 359                  NaN
# 363                  NaN
# 362                  NaN
# 372                  NaN
# 371                  NaN
# 103                  NaN
# 109                  NaN
# 21                   NaN
# 22                   NaN
# 439                  NaN
# 438                  NaN
# 451                  NaN
# 450                  NaN
# 369                  NaN
# 133                  NaN
# 249                  NaN
# 11                   NaN
# 697                  NaN
# 698                  NaN
# 315                  NaN
# 613                  NaN
# 557                  NaN
# 556                  NaN
# 16                   NaN
# 202                  NaN
# 383                  NaN
# 381                  NaN
# 141                  NaN
# 142                  NaN
# 145                  NaN
# 144                  NaN
# 30                   NaN
# 345                  NaN

# %%
jol["DuplicateKey"]=False

# %%
jol.loc[jol.duplicated(["OrgString"],keep=False),"DuplicateKey"]=True

# %%
# jol.to_excel(path_joborglink+"joborglink_7_1_jeongsu.xlsx",index=False)

# %% [markdown]
# ### MANUALLY UPDATE DUPLICATE KEY ###

# %%
# jeongsu identified the correct record in joborglink_7_1_jeongsu_x

# %% [markdown]
# # double check joborglink_7_1_jeongsu_x

# %%
joltemp = pd.read_excel(path_joborglink + "joborglink_7_1_jeongsu_x.xlsx")

# %%
joltemp.shape
# Out:
# (1426, 5)

# %%
joltemp.sort_values(["OrgString","PrimaryInstitution","OrgName"],inplace=True)

# %%
joltemp[joltemp.duplicated(["OrgString"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [OrgString, PrimaryInstitution, OrgName, Notes, DuplicateKey]
# Index: []

# %% [markdown]
# ### Create joborglink_7_2

# %%
# update current jol  with with jeongsu's corrections
# delete DuplicateKey
# export as joborglink_7_2

# %%
joltemp_true = joltemp.loc[joltemp.DuplicateKey==True,["OrgString","PrimaryInstitution","OrgName"]]
joltemp_true.shape
# Out:
# (23, 3)

# %%
joltemp_true
# Out:
#           OrgString PrimaryInstitution                    OrgName
# 0           국가건설위원회                 내각                    국가건설위원회
# 1              기계공업                 내각                      기계공업성
# 2             내각사무국                 내각                      내각사무국
# 3                노동                 내각                        노동성
# 4                 당                노동당                  Uncertain
# 5                무역                 내각                        무역성
# 6          문화재 보존총국                 내각                문화성_문화보존지도국
# 1207          체육지도위원회              국무위원회              국가체육지도위원회_제1부
# 1277   최고인민회의 통일정책위원회             최고인민회의                  통일정책심의위원회
# 1276   최고인민회의 통일정책위원회             최고인민회의                    통일정책위원회
# 1295           평안남도 당                노동당            당중앙위원회_평안남도당위원회
# 1296           평안남도 당                노동당    당중앙위원회_평안남도당위원회_안주시당위원회
# 1299        평안남도 당위원회                노동당            당중앙위원회_평안남도당위원회
# 1298        평안남도 당위원회                노동당    당중앙위원회_평안남도당위원회_안주시당위원회
# 1408            호위사령부              국방위원회                      호위사령부
# 1409            호위사령부              호위사령부                        NaN
#
#                     Notes  DuplicateKey     _merge
# 82    내각 산하; 비고: 국가건설감독성?          True       both
# 83                    NaN          True  left_only
# 203                   NaN          True  left_only
# 202                   NaN          True       both
# 304                   NaN          True       both
# 303                   NaN          True  left_only
# 307                   NaN          True       both
# 308                   NaN          True  left_only
# 538                   NaN          True  left_only
# 539                   NaN          True       both
# 554                   NaN          True       both
# 555                   NaN          True  left_only
# 561                   NaN          True  left_only
# 562                   NaN          True       both
# 588                   NaN          True  left_only
# 589                   NaN          True       both
# 647                   NaN          True  left_only
# 648                   NaN          True       both
# 719                   NaN          True       both
# 720                   NaN          True  left_only
# 739                   NaN          True  left_only
# 740                   NaN          True       both
# 754                   NaN          True       both
# 755                   NaN          True  left_only
# 871                   NaN          True  left_only
# 872                   NaN          True       both
# 877                   NaN          True       both
# 878                   NaN          True  left_only
# 1023                  NaN          True  left_only
# 1024                  NaN          True       both
# 1034                  NaN          True       both
# 1035                  NaN          True  left_only
# 1201                  NaN          True       both
# 1202                  NaN          True  left_only
# 1208                  NaN          True       both
# 1207                  NaN          True  left_only
# 1277                  NaN          True       both
# 1276                  NaN          True  left_only
# 1295                  NaN          True       both
# 1296                  NaN          True  left_only
# 1299                  NaN          True       both
# 1298                  NaN          True  left_only
# 1408                  NaN          True       both
# 1409                  NaN          True  left_only

# %%
jolmerge2 = jolmerge[~((jolmerge["DuplicateKey"]==True) & (jolmerge["_merge"]=="both"))]
# jol[jol["DuplicateKey_x"]==True) and (jol["_merge"]=="left_only"))].shape

# %%
# check no duplicated keys
jolmerge2[jolmerge2.duplicated(["OrgString","PrimaryInstitution","OrgName"])]
# Out:
# Empty DataFrame
# Columns: [OrgString, PrimaryInstitution, OrgName, Notes, DuplicateKey, _merge]
# Index: []

# %%
# check no duplicated Orgstring
jolmerge2[jolmerge2.duplicated(["OrgString","PrimaryInstitution","OrgName"])]
# Out:
# Empty DataFrame
# Columns: [OrgString, PrimaryInstitution, OrgName, Notes, DuplicateKey, _merge]
# Index: []

# %%
jol = jolmerge2

# %%
jol.to_excel(path_joborglink+fileout_joborglink_3,index=False)

# %% [markdown]
# # double check orgtree_4_1_jeongsu

# %%
# orgtemp = pd.read_excel(path_orgtree + "orgtree_4_1_jeongsu-2.xlsx")

# %%
# orgtemp.shape

# %%
# orgtemp.sort_values(["PrimaryInstitution","OrgName"],inplace=True)

# %%
# orgtemp[orgtemp.duplicated(["PrimaryInstitution","OrgName"],keep=False)]
