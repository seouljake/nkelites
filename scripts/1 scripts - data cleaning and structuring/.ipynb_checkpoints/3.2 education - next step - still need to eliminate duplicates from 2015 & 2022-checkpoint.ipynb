# %%
import pandas as pd

# %% [markdown]
# # import education data - raw, merged, partially coded

# %%
ed_filename = "education_merge3_disambiguate_donebyhand.xlsx"

# %%
ed_filepath = "C:/Users/seoul/Dropbox/00 technical/github/nkelites/data/combined data/combined data - 1 cleaning/cleaning step 3 - education/"

# %%
ed = pd.read_excel(ed_filepath+ed_filename,header=0)

# %%
ed.shape
# Out:
# (252, 13)

# %%
# Out:
#     LeaderID  MOUID_2015 Name_2015   EducationString_2015  SchoolYear_2015  \
# 0        장성택         102       장성택          1969. 모스크바 유학           1969.0
# 1        장성택         102       장성택          1969. 모스크바 유학           1969.0
# 2        장성택         102       장성택           연도미상 김일성종합대학              NaN
# 3        장성택         102       장성택           연도미상 김일성종합대학              NaN
# 4        윤기정         103       윤기정     연도미상 경기여고, 김일성종합대학              NaN
# ..       ...         ...       ...                    ...              ...
# 247      권혁봉         783       권혁봉         연도미상김일성종합대학 졸업              NaN
# 248      강관주         807       강관주  1960. 김일성종합대학 역사학부 졸업           1960.0
# 249      강관주         807       강관주  1960. 김일성종합대학 역사학부 졸업           1960.0
# 250      강관주         807       강관주        연도미상김일성고급당학교 졸업              NaN
# 251      강관주         807       강관주        연도미상김일성고급당학교 졸업              NaN
#
#     SchoolName_2015 SchoolLevel_2015 SchoolRegion_2015  \
# ...
